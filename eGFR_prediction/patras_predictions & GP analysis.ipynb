# %%
import numpy as np
import scipy
import time
import copy
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
from utils_extended import *
import gpboost as gpb
from pdpbox import pdp
import pystan 
import arviz as az

# %%
run_number = 1

# %% [markdown]
# ## Data pre-processing

# %%
data_train_full_raw = pd.read_csv(f'Patras/train_test_sets/data_train_full_patras_{run_number}.csv').drop(columns=['site'])
test_extrapolation_raw = pd.read_csv(f'Patras/train_test_sets/test_extrapolation_patras_{run_number}.csv').drop(columns=['site'])
test_interpolation_raw = pd.read_csv(f'Patras/train_test_sets/test_interpolation_patras_{run_number}.csv').drop(columns=['site'])

# One-hot encode categorical features
data_train_full_raw2 = encode(data_train_full_raw)
test_extrapolation = encode(test_extrapolation_raw)
test_interpolation_raw2 = encode(test_interpolation_raw)

# Dummy encode categorical features for linear model
data_train_full2_raw2 = encode(data_train_full_raw, linear=True)
test_extrapolation2 = encode(test_extrapolation_raw, linear=True)
test_interpolation2_raw2 = encode(test_interpolation_raw, linear=True)

# Fix missing columns
test_extrapolation['disease_Obstructive'] = 0
data_train_full_raw2['gender_Unknown'] = 0
data_train_full_raw2['ethnicity_Asian'] = 0
data_train_full_raw2['disease_Vascular'] = 0
data_train_full = data_train_full_raw2[list(test_extrapolation.columns.values)]

test_interpolation_raw2['gender_Unknown'] = 0
test_interpolation_raw2['ethnicity_Asian'] = 0
test_interpolation_raw2['disease_Vascular'] = 0
test_interpolation = test_interpolation_raw2[list(test_extrapolation.columns.values)]

test_extrapolation2['disease_Obstructive'] = 0
data_train_full2_raw2['gender_Unknown'] = 0
data_train_full2_raw2['ethnicity_Caucasian'] = 0
data_train_full2_raw2['disease_Vascular'] = 0
data_train_full2 = data_train_full2_raw2[list(test_extrapolation2.columns.values)]

test_interpolation2_raw2['gender_Unknown'] = 0
test_interpolation2_raw2['ethnicity_Caucasian'] = 0
test_interpolation2_raw2['disease_Vascular'] = 0
test_interpolation2 = test_interpolation2_raw2[list(test_extrapolation2.columns.values)]

data_train_list, data_val_list = [], []

for i in range(5):
    train_raw = pd.read_csv('Patras/tuning_data/data_cv_train_patras_' + str(i+1) + '.csv').drop(columns=['site'])
    train = encode(train_raw)
    val_raw = pd.read_csv('Patras/tuning_data/data_cv_val_patras_' + str(i+1) + '.csv').drop(columns=['site'])
    val = encode(val_raw)
    data_train_list.append(train)
    data_val_list.append(val)

data_cv_list = [pd.concat([data_train_list[i], data_val_list[i]], ignore_index=True).reset_index(drop=True).fillna(0) for i in range(5)]

# Get indices of training and validation sets for cross-validation
data_cv_indices_list = []
for i in range(5):
    data_cv_indices_list.append((np.arange(len(data_train_list[i])), np.arange(len(data_train_list[i]), len(data_train_list[i])+len(data_val_list[i]))))

# Train/test split
train_X, train_y = data_train_full.drop(columns=['egfr']), data_train_full['egfr'].to_numpy(dtype=np.float64)
test_extrapolation_X, test_extrapolation_y = test_extrapolation.drop(columns=['egfr']), test_extrapolation['egfr'].to_numpy(dtype=np.float64)
test_interpolation_X, test_interpolation_y = test_interpolation.drop(columns=['egfr']), test_interpolation['egfr'].to_numpy(dtype=np.float64)
data_train_full_gpb = gpb.Dataset(data=train_X.drop(columns=['ID', 'times']), label=train_y)
data_train_full_gpb_cat = gpb.Dataset(data=train_X, label=train_y, categorical_feature=['ID'])


# For linear
train_X2 = data_train_full2.drop(columns=['egfr'])
test_extrapolation_X2 = test_extrapolation2.drop(columns=['egfr'])
test_interpolation_X2 = test_interpolation2.drop(columns=['egfr'])
data_train_full2_gpb = gpb.Dataset(data=train_X2.drop(columns=['ID', 'times']), label=train_y)


# CV sets
dataset_list , dataset_list_cat = [] , []
for i in range(5):
    cv_train_X, cv_train_y = data_cv_list[i].drop(columns=['egfr']), data_cv_list[i]['egfr'].to_numpy()
    dataset_list.append(gpb.Dataset(data=cv_train_X.drop(columns=['ID', 'times']), label=cv_train_y))
    dataset_list_cat.append(gpb.Dataset(data=cv_train_X, label=cv_train_y, categorical_feature=['ID']))

# %% [markdown]
# ## Tuning the Gradient Boosted tree with group as categorical variable

# %%
# Candidate parameter grid
param_grid = {'num_leaves': [10, 50, 200, 500, 1000, 5000], 
              'max_depth': [1, 3, 5, 10, 50],
              'min_data_in_leaf': [5, 20, 50, 100, 150], 
               'learning_rate' : [0.01, 0.1, 0.3, 0.5, 0.8, 1, 1.2, 1.5, 2]}

# Other parameters not contained in the grid of tuning parameters
params = {'objective': 'regression_l2',
          'verbose': 0}
          #'learning_rate' : 1.5}
          #'device_type' : 'gpu'}

opt_params = grid_search_tune_parameters_multiple(data_cv_list, dataset_list_cat, param_grid, params=params, num_try_random=None,
                                         num_boost_round=10_000,
                                         use_gp_model_for_validation=False, train_gp_model_cov_pars=False, folds_list=data_cv_indices_list, nfold=5, stratified=False, shuffle=False,
                                         metrics='rmse', fobj=None, feval=None, init_model=None,
                                         feature_name='auto', categorical_feature=['ID'],
                                         early_stopping_rounds=10, fpreproc=None,
                                         verbose_eval=1, seed=0, callbacks=None,
                                         gp_model_type=None)
                                                  
print('Best number of iterations: ', opt_params['best_iter'])
print('Best score: ', opt_params['best_score'])
print('Best parameters: ', opt_params['best_params'])
# Out:
# Starting deterministic grid search with 1350 parameter combinations...
# Trying parameter combination 1 of 1350: {'num_leaves': 10, 'max_depth': 1, 'min_data_in_leaf': 5, 'learning_rate': 0.01} ...
# ***** New best score (26.76008535189981) found for the following parameter combination:
# {'num_leaves': 10, 'max_depth': 1, 'min_data_in_leaf': 5, 'learning_rate': 0.01, 'num_boost_round': 17.2}
# Trying parameter combination 2 of 1350: {'num_leaves': 50, 'max_depth': 1, 'min_data_in_leaf': 5, 'learning_rate': 0.01} ...
# c:\Users\nick_\Anaconda3\lib\site-packages\gpboost\basic.py:1339: UserWarning: categorical_column in param dict is overridden.
#   _log_warning('{} in param dict is overridden.'.format(cat_alias))
# Trying parameter combination 3 of 1350: {'num_leaves': 200, 'max_depth': 1, 'min_data_in_leaf': 5, 'learning_rate': 0.01} ...
# Trying parameter combination 4 of 1350: {'num_leaves': 500, 'max_depth': 1, 'min_data_in_leaf': 5, 'learning_rate': 0.01} ...
# Trying parameter combination 5 of 1350: {'num_leaves': 1000, 'max_depth': 1, 'min_data_in_leaf': 5, 'learning_rate': 0.01} ...
# Trying parameter combination 6 of 1350: {'num_leaves': 5000, 'max_depth': 1, 'min_data_in_leaf': 5, 'learning_rate': 0.01} ...
# Trying parameter combination 7 of 1350: {'num_leaves': 10, 'max_depth': 3, 'min_data_in_leaf': 5, 'learning_rate': 0.01} ...
# ***** New best score (25.513218020196085) found for the following parameter combination:
# {'num_leaves': 10, 'max_depth': 3, 'min_data_in_leaf': 5, 'learning_rate': 0.01, 'num_boost_round': 119.4}
# Trying parameter combination 8 of 1350: {'num_leaves': 50, 'max_depth': 3, 'min_data_in_leaf': 5, 'learning_rate': 0.01} ...
# Trying parameter combination 9 of 1350: {'num_leaves': 200, 'max_depth': 3, 'min_data_in_leaf': 5, 'learning_rate': 0.01} ...
# Trying parameter combination 10 of 1350: {'num_leaves': 500, 'max_depth': 3, 'min_data_in_leaf': 5, 'learning_rate': 0.01} ...
# Trying parameter combination 11 of 1350: {'num_leaves': 1000, 'max_depth': 3, 'min_data_in_leaf': 5, 'learning_rate': 0.01} ...
# Trying parameter combination 12 of 1350: {'num_leaves': 5000, 'max_depth': 3, 'min_data_in_leaf': 5, 'learning_rate': 0.01} ...
# Trying parameter combination 13 of 1350: {'num_leaves': 10, 'max_depth': 5, 'min_data_in_leaf': 5, 'learning_rate': 0.01} ...
# ***** New best score (24.915382826252337) found for the following parameter combination:
# {'num_leaves': 10, 'max_depth': 5, 'min_data_in_leaf': 5, 'learning_rate': 0.01, 'num_boost_round': 110.0}
# Trying parameter combination 14 of 1350: {'num_leaves': 50, 'max_depth': 5, 'min_data_in_leaf': 5, 'learning_rate': 0.01} ...
# ***** New best score (24.855798062177065) found for the following parameter combination:
# {'num_leaves': 50, 'max_depth': 5, 'min_data_in_leaf': 5, 'learning_rate': 0.01, 'num_boost_round': 116.4}
# Trying parameter combination 15 of 1350: {'num_leaves': 200, 'max_depth': 5, 'min_data_in_leaf': 5, 'learning_rate': 0.01} ...
# ***** New best score (24.855309325996146) found for the following parameter combination:
# {'num_leaves': 200, 'max_depth': 5, 'min_data_in_leaf': 5, 'learning_rate': 0.01, 'num_boost_round': 116.4}
# Trying parameter combination 16 of 1350: {'num_leaves': 500, 'max_depth': 5, 'min_data_in_leaf': 5, 'learning_rate': 0.01} ...
# Trying parameter combination 17 of 1350: {'num_leaves': 1000, 'max_depth': 5, 'min_data_in_leaf': 5, 'learning_rate': 0.01} ...
# Trying parameter combination 18 of 1350: {'num_leaves': 5000, 'max_depth': 5, 'min_data_in_leaf': 5, 'learning_rate': 0.01} ...
# Trying parameter combination 19 of 1350: {'num_leaves': 10, 'max_depth': 10, 'min_data_in_leaf': 5, 'learning_rate': 0.01} ...
# Trying parameter combination 20 of 1350: {'num_leaves': 50, 'max_depth': 10, 'min_data_in_leaf': 5, 'learning_rate': 0.01} ...
# ***** New best score (24.62696276124149) found for the following parameter combination:
# {'num_leaves': 50, 'max_depth': 10, 'min_data_in_leaf': 5, 'learning_rate': 0.01, 'num_boost_round': 97.4}
# Trying parameter combination 21 of 1350: {'num_leaves': 200, 'max_depth': 10, 'min_data_in_leaf': 5, 'learning_rate': 0.01} ...
# Trying parameter combination 22 of 1350: {'num_leaves': 500, 'max_depth': 10, 'min_data_in_leaf': 5, 'learning_rate': 0.01} ...
# Trying parameter combination 23 of 1350: {'num_leaves': 1000, 'max_depth': 10, 'min_data_in_leaf': 5, 'learning_rate': 0.01} ...
# Trying parameter combination 24 of 1350: {'num_leaves': 5000, 'max_depth': 10, 'min_data_in_leaf': 5, 'learning_rate': 0.01} ...
# Trying parameter combination 25 of 1350: {'num_leaves': 10, 'max_depth': 50, 'min_data_in_leaf': 5, 'learning_rate': 0.01} ...
# Trying parameter combination 26 of 1350: {'num_leaves': 50, 'max_depth': 50, 'min_data_in_leaf': 5, 'learning_rate': 0.01} ...
# Trying parameter combination 27 of 1350: {'num_leaves': 200, 'max_depth': 50, 'min_data_in_leaf': 5, 'learning_rate': 0.01} ...
# Trying parameter combination 28 of 1350: {'num_leaves': 500, 'max_depth': 50, 'min_data_in_leaf': 5, 'learning_rate': 0.01} ...
# Trying parameter combination 29 of 1350: {'num_leaves': 1000, 'max_depth': 50, 'min_data_in_leaf': 5, 'learning_rate': 0.01} ...
# Trying parameter combination 30 of 1350: {'num_leaves': 5000, 'max_depth': 50, 'min_data_in_leaf': 5, 'learning_rate': 0.01} ...
# Trying parameter combination 31 of 1350: {'num_leaves': 10, 'max_depth': 1, 'min_data_in_leaf': 20, 'learning_rate': 0.01} ...
# Trying parameter combination 32 of 1350: {'num_leaves': 50, 'max_depth': 1, 'min_data_in_leaf': 20, 'learning_rate': 0.01} ...
# Trying parameter combination 33 of 1350: {'num_leaves': 200, 'max_depth': 1, 'min_data_in_leaf': 20, 'learning_rate': 0.01} ...
# Trying parameter combination 34 of 1350: {'num_leaves': 500, 'max_depth': 1, 'min_data_in_leaf': 20, 'learning_rate': 0.01} ...
# Trying parameter combination 35 of 1350: {'num_leaves': 1000, 'max_depth': 1, 'min_data_in_leaf': 20, 'learning_rate': 0.01} ...
# Trying parameter combination 36 of 1350: {'num_leaves': 5000, 'max_depth': 1, 'min_data_in_leaf': 20, 'learning_rate': 0.01} ...
# Trying parameter combination 37 of 1350: {'num_leaves': 10, 'max_depth': 3, 'min_data_in_leaf': 20, 'learning_rate': 0.01} ...
# Trying parameter combination 38 of 1350: {'num_leaves': 50, 'max_depth': 3, 'min_data_in_leaf': 20, 'learning_rate': 0.01} ...
# Trying parameter combination 39 of 1350: {'num_leaves': 200, 'max_depth': 3, 'min_data_in_leaf': 20, 'learning_rate': 0.01} ...
# Trying parameter combination 40 of 1350: {'num_leaves': 500, 'max_depth': 3, 'min_data_in_leaf': 20, 'learning_rate': 0.01} ...
# Trying parameter combination 41 of 1350: {'num_leaves': 1000, 'max_depth': 3, 'min_data_in_leaf': 20, 'learning_rate': 0.01} ...
# Trying parameter combination 42 of 1350: {'num_leaves': 5000, 'max_depth': 3, 'min_data_in_leaf': 20, 'learning_rate': 0.01} ...
# Trying parameter combination 43 of 1350: {'num_leaves': 10, 'max_depth': 5, 'min_data_in_leaf': 20, 'learning_rate': 0.01} ...
# Trying parameter combination 44 of 1350: {'num_leaves': 50, 'max_depth': 5, 'min_data_in_leaf': 20, 'learning_rate': 0.01} ...
# Trying parameter combination 45 of 1350: {'num_leaves': 200, 'max_depth': 5, 'min_data_in_leaf': 20, 'learning_rate': 0.01} ...
# Trying parameter combination 46 of 1350: {'num_leaves': 500, 'max_depth': 5, 'min_data_in_leaf': 20, 'learning_rate': 0.01} ...
# Trying parameter combination 47 of 1350: {'num_leaves': 1000, 'max_depth': 5, 'min_data_in_leaf': 20, 'learning_rate': 0.01} ...
# Trying parameter combination 48 of 1350: {'num_leaves': 5000, 'max_depth': 5, 'min_data_in_leaf': 20, 'learning_rate': 0.01} ...
# Trying parameter combination 49 of 1350: {'num_leaves': 10, 'max_depth': 10, 'min_data_in_leaf': 20, 'learning_rate': 0.01} ...
# Trying parameter combination 50 of 1350: {'num_leaves': 50, 'max_depth': 10, 'min_data_in_leaf': 20, 'learning_rate': 0.01} ...
# ***** New best score (24.526532488028224) found for the following parameter combination:
# {'num_leaves': 50, 'max_depth': 10, 'min_data_in_leaf': 20, 'learning_rate': 0.01, 'num_boost_round': 99.6}
# Trying parameter combination 51 of 1350: {'num_leaves': 200, 'max_depth': 10, 'min_data_in_leaf': 20, 'learning_rate': 0.01} ...
# ***** New best score (24.469134611610272) found for the following parameter combination:
# {'num_leaves': 200, 'max_depth': 10, 'min_data_in_leaf': 20, 'learning_rate': 0.01, 'num_boost_round': 103.6}
# Trying parameter combination 52 of 1350: {'num_leaves': 500, 'max_depth': 10, 'min_data_in_leaf': 20, 'learning_rate': 0.01} ...
# Trying parameter combination 53 of 1350: {'num_leaves': 1000, 'max_depth': 10, 'min_data_in_leaf': 20, 'learning_rate': 0.01} ...
# Trying parameter combination 54 of 1350: {'num_leaves': 5000, 'max_depth': 10, 'min_data_in_leaf': 20, 'learning_rate': 0.01} ...
# Trying parameter combination 55 of 1350: {'num_leaves': 10, 'max_depth': 50, 'min_data_in_leaf': 20, 'learning_rate': 0.01} ...
# Trying parameter combination 56 of 1350: {'num_leaves': 50, 'max_depth': 50, 'min_data_in_leaf': 20, 'learning_rate': 0.01} ...
# Trying parameter combination 57 of 1350: {'num_leaves': 200, 'max_depth': 50, 'min_data_in_leaf': 20, 'learning_rate': 0.01} ...
# Trying parameter combination 58 of 1350: {'num_leaves': 500, 'max_depth': 50, 'min_data_in_leaf': 20, 'learning_rate': 0.01} ...
# Trying parameter combination 59 of 1350: {'num_leaves': 1000, 'max_depth': 50, 'min_data_in_leaf': 20, 'learning_rate': 0.01} ...
# Trying parameter combination 60 of 1350: {'num_leaves': 5000, 'max_depth': 50, 'min_data_in_leaf': 20, 'learning_rate': 0.01} ...
# Trying parameter combination 61 of 1350: {'num_leaves': 10, 'max_depth': 1, 'min_data_in_leaf': 50, 'learning_rate': 0.01} ...
# Trying parameter combination 62 of 1350: {'num_leaves': 50, 'max_depth': 1, 'min_data_in_leaf': 50, 'learning_rate': 0.01} ...
# Trying parameter combination 63 of 1350: {'num_leaves': 200, 'max_depth': 1, 'min_data_in_leaf': 50, 'learning_rate': 0.01} ...
# Trying parameter combination 64 of 1350: {'num_leaves': 500, 'max_depth': 1, 'min_data_in_leaf': 50, 'learning_rate': 0.01} ...
# Trying parameter combination 65 of 1350: {'num_leaves': 1000, 'max_depth': 1, 'min_data_in_leaf': 50, 'learning_rate': 0.01} ...
# Trying parameter combination 66 of 1350: {'num_leaves': 5000, 'max_depth': 1, 'min_data_in_leaf': 50, 'learning_rate': 0.01} ...
# Trying parameter combination 67 of 1350: {'num_leaves': 10, 'max_depth': 3, 'min_data_in_leaf': 50, 'learning_rate': 0.01} ...
# Trying parameter combination 68 of 1350: {'num_leaves': 50, 'max_depth': 3, 'min_data_in_leaf': 50, 'learning_rate': 0.01} ...
# Trying parameter combination 69 of 1350: {'num_leaves': 200, 'max_depth': 3, 'min_data_in_leaf': 50, 'learning_rate': 0.01} ...
# Trying parameter combination 70 of 1350: {'num_leaves': 500, 'max_depth': 3, 'min_data_in_leaf': 50, 'learning_rate': 0.01} ...
# Trying parameter combination 71 of 1350: {'num_leaves': 1000, 'max_depth': 3, 'min_data_in_leaf': 50, 'learning_rate': 0.01} ...
# Trying parameter combination 72 of 1350: {'num_leaves': 5000, 'max_depth': 3, 'min_data_in_leaf': 50, 'learning_rate': 0.01} ...
# Trying parameter combination 73 of 1350: {'num_leaves': 10, 'max_depth': 5, 'min_data_in_leaf': 50, 'learning_rate': 0.01} ...
# Trying parameter combination 74 of 1350: {'num_leaves': 50, 'max_depth': 5, 'min_data_in_leaf': 50, 'learning_rate': 0.01} ...
# Trying parameter combination 75 of 1350: {'num_leaves': 200, 'max_depth': 5, 'min_data_in_leaf': 50, 'learning_rate': 0.01} ...
# Trying parameter combination 76 of 1350: {'num_leaves': 500, 'max_depth': 5, 'min_data_in_leaf': 50, 'learning_rate': 0.01} ...
# Trying parameter combination 77 of 1350: {'num_leaves': 1000, 'max_depth': 5, 'min_data_in_leaf': 50, 'learning_rate': 0.01} ...
# Trying parameter combination 78 of 1350: {'num_leaves': 5000, 'max_depth': 5, 'min_data_in_leaf': 50, 'learning_rate': 0.01} ...
# Trying parameter combination 79 of 1350: {'num_leaves': 10, 'max_depth': 10, 'min_data_in_leaf': 50, 'learning_rate': 0.01} ...
# Trying parameter combination 80 of 1350: {'num_leaves': 50, 'max_depth': 10, 'min_data_in_leaf': 50, 'learning_rate': 0.01} ...
# ***** New best score (24.429208335022015) found for the following parameter combination:
# {'num_leaves': 50, 'max_depth': 10, 'min_data_in_leaf': 50, 'learning_rate': 0.01, 'num_boost_round': 111.8}
# Trying parameter combination 81 of 1350: {'num_leaves': 200, 'max_depth': 10, 'min_data_in_leaf': 50, 'learning_rate': 0.01} ...
# ***** New best score (24.429061492158628) found for the following parameter combination:
# {'num_leaves': 200, 'max_depth': 10, 'min_data_in_leaf': 50, 'learning_rate': 0.01, 'num_boost_round': 111.8}
# Trying parameter combination 82 of 1350: {'num_leaves': 500, 'max_depth': 10, 'min_data_in_leaf': 50, 'learning_rate': 0.01} ...
# Trying parameter combination 83 of 1350: {'num_leaves': 1000, 'max_depth': 10, 'min_data_in_leaf': 50, 'learning_rate': 0.01} ...
# Trying parameter combination 84 of 1350: {'num_leaves': 5000, 'max_depth': 10, 'min_data_in_leaf': 50, 'learning_rate': 0.01} ...
# Trying parameter combination 85 of 1350: {'num_leaves': 10, 'max_depth': 50, 'min_data_in_leaf': 50, 'learning_rate': 0.01} ...
# Trying parameter combination 86 of 1350: {'num_leaves': 50, 'max_depth': 50, 'min_data_in_leaf': 50, 'learning_rate': 0.01} ...
# ***** New best score (24.37491226607692) found for the following parameter combination:
# {'num_leaves': 50, 'max_depth': 50, 'min_data_in_leaf': 50, 'learning_rate': 0.01, 'num_boost_round': 123.6}
# Trying parameter combination 87 of 1350: {'num_leaves': 200, 'max_depth': 50, 'min_data_in_leaf': 50, 'learning_rate': 0.01} ...
# ***** New best score (24.37348955046103) found for the following parameter combination:
# {'num_leaves': 200, 'max_depth': 50, 'min_data_in_leaf': 50, 'learning_rate': 0.01, 'num_boost_round': 123.6}
# Trying parameter combination 88 of 1350: {'num_leaves': 500, 'max_depth': 50, 'min_data_in_leaf': 50, 'learning_rate': 0.01} ...
# Trying parameter combination 89 of 1350: {'num_leaves': 1000, 'max_depth': 50, 'min_data_in_leaf': 50, 'learning_rate': 0.01} ...
# Trying parameter combination 90 of 1350: {'num_leaves': 5000, 'max_depth': 50, 'min_data_in_leaf': 50, 'learning_rate': 0.01} ...
# Trying parameter combination 91 of 1350: {'num_leaves': 10, 'max_depth': 1, 'min_data_in_leaf': 100, 'learning_rate': 0.01} ...
# Trying parameter combination 92 of 1350: {'num_leaves': 50, 'max_depth': 1, 'min_data_in_leaf': 100, 'learning_rate': 0.01} ...
# Trying parameter combination 93 of 1350: {'num_leaves': 200, 'max_depth': 1, 'min_data_in_leaf': 100, 'learning_rate': 0.01} ...
# Trying parameter combination 94 of 1350: {'num_leaves': 500, 'max_depth': 1, 'min_data_in_leaf': 100, 'learning_rate': 0.01} ...
# Trying parameter combination 95 of 1350: {'num_leaves': 1000, 'max_depth': 1, 'min_data_in_leaf': 100, 'learning_rate': 0.01} ...
# Trying parameter combination 96 of 1350: {'num_leaves': 5000, 'max_depth': 1, 'min_data_in_leaf': 100, 'learning_rate': 0.01} ...
# Trying parameter combination 97 of 1350: {'num_leaves': 10, 'max_depth': 3, 'min_data_in_leaf': 100, 'learning_rate': 0.01} ...
# ***** New best score (24.372038351892755) found for the following parameter combination:
# {'num_leaves': 10, 'max_depth': 3, 'min_data_in_leaf': 100, 'learning_rate': 0.01, 'num_boost_round': 302.8}
# Trying parameter combination 98 of 1350: {'num_leaves': 50, 'max_depth': 3, 'min_data_in_leaf': 100, 'learning_rate': 0.01} ...
# Trying parameter combination 99 of 1350: {'num_leaves': 200, 'max_depth': 3, 'min_data_in_leaf': 100, 'learning_rate': 0.01} ...
# Trying parameter combination 100 of 1350: {'num_leaves': 500, 'max_depth': 3, 'min_data_in_leaf': 100, 'learning_rate': 0.01} ...
# Trying parameter combination 101 of 1350: {'num_leaves': 1000, 'max_depth': 3, 'min_data_in_leaf': 100, 'learning_rate': 0.01} ...
# Trying parameter combination 102 of 1350: {'num_leaves': 5000, 'max_depth': 3, 'min_data_in_leaf': 100, 'learning_rate': 0.01} ...
# Trying parameter combination 103 of 1350: {'num_leaves': 10, 'max_depth': 5, 'min_data_in_leaf': 100, 'learning_rate': 0.01} ...
# ***** New best score (24.33526585292158) found for the following parameter combination:
# {'num_leaves': 10, 'max_depth': 5, 'min_data_in_leaf': 100, 'learning_rate': 0.01, 'num_boost_round': 161.2}
# Trying parameter combination 104 of 1350: {'num_leaves': 50, 'max_depth': 5, 'min_data_in_leaf': 100, 'learning_rate': 0.01} ...
# ***** New best score (24.311399574437285) found for the following parameter combination:
# {'num_leaves': 50, 'max_depth': 5, 'min_data_in_leaf': 100, 'learning_rate': 0.01, 'num_boost_round': 151.8}
# Trying parameter combination 105 of 1350: {'num_leaves': 200, 'max_depth': 5, 'min_data_in_leaf': 100, 'learning_rate': 0.01} ...
# Trying parameter combination 106 of 1350: {'num_leaves': 500, 'max_depth': 5, 'min_data_in_leaf': 100, 'learning_rate': 0.01} ...
# Trying parameter combination 107 of 1350: {'num_leaves': 1000, 'max_depth': 5, 'min_data_in_leaf': 100, 'learning_rate': 0.01} ...
# Trying parameter combination 108 of 1350: {'num_leaves': 5000, 'max_depth': 5, 'min_data_in_leaf': 100, 'learning_rate': 0.01} ...
# Trying parameter combination 109 of 1350: {'num_leaves': 10, 'max_depth': 10, 'min_data_in_leaf': 100, 'learning_rate': 0.01} ...
# Trying parameter combination 110 of 1350: {'num_leaves': 50, 'max_depth': 10, 'min_data_in_leaf': 100, 'learning_rate': 0.01} ...
# Trying parameter combination 111 of 1350: {'num_leaves': 200, 'max_depth': 10, 'min_data_in_leaf': 100, 'learning_rate': 0.01} ...
# Trying parameter combination 112 of 1350: {'num_leaves': 500, 'max_depth': 10, 'min_data_in_leaf': 100, 'learning_rate': 0.01} ...
# Trying parameter combination 113 of 1350: {'num_leaves': 1000, 'max_depth': 10, 'min_data_in_leaf': 100, 'learning_rate': 0.01} ...
# Trying parameter combination 114 of 1350: {'num_leaves': 5000, 'max_depth': 10, 'min_data_in_leaf': 100, 'learning_rate': 0.01} ...
# Trying parameter combination 115 of 1350: {'num_leaves': 10, 'max_depth': 50, 'min_data_in_leaf': 100, 'learning_rate': 0.01} ...
# Trying parameter combination 116 of 1350: {'num_leaves': 50, 'max_depth': 50, 'min_data_in_leaf': 100, 'learning_rate': 0.01} ...
# Trying parameter combination 117 of 1350: {'num_leaves': 200, 'max_depth': 50, 'min_data_in_leaf': 100, 'learning_rate': 0.01} ...
# Trying parameter combination 118 of 1350: {'num_leaves': 500, 'max_depth': 50, 'min_data_in_leaf': 100, 'learning_rate': 0.01} ...
# Trying parameter combination 119 of 1350: {'num_leaves': 1000, 'max_depth': 50, 'min_data_in_leaf': 100, 'learning_rate': 0.01} ...
# Trying parameter combination 120 of 1350: {'num_leaves': 5000, 'max_depth': 50, 'min_data_in_leaf': 100, 'learning_rate': 0.01} ...
# Trying parameter combination 121 of 1350: {'num_leaves': 10, 'max_depth': 1, 'min_data_in_leaf': 150, 'learning_rate': 0.01} ...
# Trying parameter combination 122 of 1350: {'num_leaves': 50, 'max_depth': 1, 'min_data_in_leaf': 150, 'learning_rate': 0.01} ...
# Trying parameter combination 123 of 1350: {'num_leaves': 200, 'max_depth': 1, 'min_data_in_leaf': 150, 'learning_rate': 0.01} ...
# Trying parameter combination 124 of 1350: {'num_leaves': 500, 'max_depth': 1, 'min_data_in_leaf': 150, 'learning_rate': 0.01} ...
# Trying parameter combination 125 of 1350: {'num_leaves': 1000, 'max_depth': 1, 'min_data_in_leaf': 150, 'learning_rate': 0.01} ...
# Trying parameter combination 126 of 1350: {'num_leaves': 5000, 'max_depth': 1, 'min_data_in_leaf': 150, 'learning_rate': 0.01} ...
# Trying parameter combination 127 of 1350: {'num_leaves': 10, 'max_depth': 3, 'min_data_in_leaf': 150, 'learning_rate': 0.01} ...
# ***** New best score (24.18850915171169) found for the following parameter combination:
# {'num_leaves': 10, 'max_depth': 3, 'min_data_in_leaf': 150, 'learning_rate': 0.01, 'num_boost_round': 304.2}
# Trying parameter combination 128 of 1350: {'num_leaves': 50, 'max_depth': 3, 'min_data_in_leaf': 150, 'learning_rate': 0.01} ...
# Trying parameter combination 129 of 1350: {'num_leaves': 200, 'max_depth': 3, 'min_data_in_leaf': 150, 'learning_rate': 0.01} ...
# Trying parameter combination 130 of 1350: {'num_leaves': 500, 'max_depth': 3, 'min_data_in_leaf': 150, 'learning_rate': 0.01} ...
# ***** New best score (24.188509151711685) found for the following parameter combination:
# {'num_leaves': 500, 'max_depth': 3, 'min_data_in_leaf': 150, 'learning_rate': 0.01, 'num_boost_round': 304.2}
# Trying parameter combination 131 of 1350: {'num_leaves': 1000, 'max_depth': 3, 'min_data_in_leaf': 150, 'learning_rate': 0.01} ...
# Trying parameter combination 132 of 1350: {'num_leaves': 5000, 'max_depth': 3, 'min_data_in_leaf': 150, 'learning_rate': 0.01} ...
# Trying parameter combination 133 of 1350: {'num_leaves': 10, 'max_depth': 5, 'min_data_in_leaf': 150, 'learning_rate': 0.01} ...
# Trying parameter combination 134 of 1350: {'num_leaves': 50, 'max_depth': 5, 'min_data_in_leaf': 150, 'learning_rate': 0.01} ...
# ***** New best score (24.172819761213184) found for the following parameter combination:
# {'num_leaves': 50, 'max_depth': 5, 'min_data_in_leaf': 150, 'learning_rate': 0.01, 'num_boost_round': 246.6}
# Trying parameter combination 135 of 1350: {'num_leaves': 200, 'max_depth': 5, 'min_data_in_leaf': 150, 'learning_rate': 0.01} ...
# Trying parameter combination 136 of 1350: {'num_leaves': 500, 'max_depth': 5, 'min_data_in_leaf': 150, 'learning_rate': 0.01} ...
# Trying parameter combination 137 of 1350: {'num_leaves': 1000, 'max_depth': 5, 'min_data_in_leaf': 150, 'learning_rate': 0.01} ...
# Trying parameter combination 138 of 1350: {'num_leaves': 5000, 'max_depth': 5, 'min_data_in_leaf': 150, 'learning_rate': 0.01} ...
# Trying parameter combination 139 of 1350: {'num_leaves': 10, 'max_depth': 10, 'min_data_in_leaf': 150, 'learning_rate': 0.01} ...
# Trying parameter combination 140 of 1350: {'num_leaves': 50, 'max_depth': 10, 'min_data_in_leaf': 150, 'learning_rate': 0.01} ...
# Trying parameter combination 141 of 1350: {'num_leaves': 200, 'max_depth': 10, 'min_data_in_leaf': 150, 'learning_rate': 0.01} ...
# Trying parameter combination 142 of 1350: {'num_leaves': 500, 'max_depth': 10, 'min_data_in_leaf': 150, 'learning_rate': 0.01} ...
# Trying parameter combination 143 of 1350: {'num_leaves': 1000, 'max_depth': 10, 'min_data_in_leaf': 150, 'learning_rate': 0.01} ...
# Trying parameter combination 144 of 1350: {'num_leaves': 5000, 'max_depth': 10, 'min_data_in_leaf': 150, 'learning_rate': 0.01} ...
# Trying parameter combination 145 of 1350: {'num_leaves': 10, 'max_depth': 50, 'min_data_in_leaf': 150, 'learning_rate': 0.01} ...
# Trying parameter combination 146 of 1350: {'num_leaves': 50, 'max_depth': 50, 'min_data_in_leaf': 150, 'learning_rate': 0.01} ...
# Trying parameter combination 147 of 1350: {'num_leaves': 200, 'max_depth': 50, 'min_data_in_leaf': 150, 'learning_rate': 0.01} ...
# Trying parameter combination 148 of 1350: {'num_leaves': 500, 'max_depth': 50, 'min_data_in_leaf': 150, 'learning_rate': 0.01} ...
# Trying parameter combination 149 of 1350: {'num_leaves': 1000, 'max_depth': 50, 'min_data_in_leaf': 150, 'learning_rate': 0.01} ...
# Trying parameter combination 150 of 1350: {'num_leaves': 5000, 'max_depth': 50, 'min_data_in_leaf': 150, 'learning_rate': 0.01} ...
# Trying parameter combination 151 of 1350: {'num_leaves': 10, 'max_depth': 1, 'min_data_in_leaf': 5, 'learning_rate': 0.1} ...
# Trying parameter combination 152 of 1350: {'num_leaves': 50, 'max_depth': 1, 'min_data_in_leaf': 5, 'learning_rate': 0.1} ...
# Trying parameter combination 153 of 1350: {'num_leaves': 200, 'max_depth': 1, 'min_data_in_leaf': 5, 'learning_rate': 0.1} ...
# Trying parameter combination 154 of 1350: {'num_leaves': 500, 'max_depth': 1, 'min_data_in_leaf': 5, 'learning_rate': 0.1} ...
# Trying parameter combination 155 of 1350: {'num_leaves': 1000, 'max_depth': 1, 'min_data_in_leaf': 5, 'learning_rate': 0.1} ...
# Trying parameter combination 156 of 1350: {'num_leaves': 5000, 'max_depth': 1, 'min_data_in_leaf': 5, 'learning_rate': 0.1} ...
# Trying parameter combination 157 of 1350: {'num_leaves': 10, 'max_depth': 3, 'min_data_in_leaf': 5, 'learning_rate': 0.1} ...
# Trying parameter combination 158 of 1350: {'num_leaves': 50, 'max_depth': 3, 'min_data_in_leaf': 5, 'learning_rate': 0.1} ...
# Trying parameter combination 159 of 1350: {'num_leaves': 200, 'max_depth': 3, 'min_data_in_leaf': 5, 'learning_rate': 0.1} ...
# Trying parameter combination 160 of 1350: {'num_leaves': 500, 'max_depth': 3, 'min_data_in_leaf': 5, 'learning_rate': 0.1} ...
# Trying parameter combination 161 of 1350: {'num_leaves': 1000, 'max_depth': 3, 'min_data_in_leaf': 5, 'learning_rate': 0.1} ...
# Trying parameter combination 162 of 1350: {'num_leaves': 5000, 'max_depth': 3, 'min_data_in_leaf': 5, 'learning_rate': 0.1} ...
# Trying parameter combination 163 of 1350: {'num_leaves': 10, 'max_depth': 5, 'min_data_in_leaf': 5, 'learning_rate': 0.1} ...
# Trying parameter combination 164 of 1350: {'num_leaves': 50, 'max_depth': 5, 'min_data_in_leaf': 5, 'learning_rate': 0.1} ...
# Trying parameter combination 165 of 1350: {'num_leaves': 200, 'max_depth': 5, 'min_data_in_leaf': 5, 'learning_rate': 0.1} ...
# Trying parameter combination 166 of 1350: {'num_leaves': 500, 'max_depth': 5, 'min_data_in_leaf': 5, 'learning_rate': 0.1} ...
# Trying parameter combination 167 of 1350: {'num_leaves': 1000, 'max_depth': 5, 'min_data_in_leaf': 5, 'learning_rate': 0.1} ...
# Trying parameter combination 168 of 1350: {'num_leaves': 5000, 'max_depth': 5, 'min_data_in_leaf': 5, 'learning_rate': 0.1} ...
# Trying parameter combination 169 of 1350: {'num_leaves': 10, 'max_depth': 10, 'min_data_in_leaf': 5, 'learning_rate': 0.1} ...
# Trying parameter combination 170 of 1350: {'num_leaves': 50, 'max_depth': 10, 'min_data_in_leaf': 5, 'learning_rate': 0.1} ...
# Trying parameter combination 171 of 1350: {'num_leaves': 200, 'max_depth': 10, 'min_data_in_leaf': 5, 'learning_rate': 0.1} ...
# Trying parameter combination 172 of 1350: {'num_leaves': 500, 'max_depth': 10, 'min_data_in_leaf': 5, 'learning_rate': 0.1} ...
# Trying parameter combination 173 of 1350: {'num_leaves': 1000, 'max_depth': 10, 'min_data_in_leaf': 5, 'learning_rate': 0.1} ...
# Trying parameter combination 174 of 1350: {'num_leaves': 5000, 'max_depth': 10, 'min_data_in_leaf': 5, 'learning_rate': 0.1} ...
# Trying parameter combination 175 of 1350: {'num_leaves': 10, 'max_depth': 50, 'min_data_in_leaf': 5, 'learning_rate': 0.1} ...
# Trying parameter combination 176 of 1350: {'num_leaves': 50, 'max_depth': 50, 'min_data_in_leaf': 5, 'learning_rate': 0.1} ...
# Trying parameter combination 177 of 1350: {'num_leaves': 200, 'max_depth': 50, 'min_data_in_leaf': 5, 'learning_rate': 0.1} ...
# Trying parameter combination 178 of 1350: {'num_leaves': 500, 'max_depth': 50, 'min_data_in_leaf': 5, 'learning_rate': 0.1} ...
# Trying parameter combination 179 of 1350: {'num_leaves': 1000, 'max_depth': 50, 'min_data_in_leaf': 5, 'learning_rate': 0.1} ...
# Trying parameter combination 180 of 1350: {'num_leaves': 5000, 'max_depth': 50, 'min_data_in_leaf': 5, 'learning_rate': 0.1} ...
# Trying parameter combination 181 of 1350: {'num_leaves': 10, 'max_depth': 1, 'min_data_in_leaf': 20, 'learning_rate': 0.1} ...
# Trying parameter combination 182 of 1350: {'num_leaves': 50, 'max_depth': 1, 'min_data_in_leaf': 20, 'learning_rate': 0.1} ...
# Trying parameter combination 183 of 1350: {'num_leaves': 200, 'max_depth': 1, 'min_data_in_leaf': 20, 'learning_rate': 0.1} ...
# Trying parameter combination 184 of 1350: {'num_leaves': 500, 'max_depth': 1, 'min_data_in_leaf': 20, 'learning_rate': 0.1} ...
# Trying parameter combination 185 of 1350: {'num_leaves': 1000, 'max_depth': 1, 'min_data_in_leaf': 20, 'learning_rate': 0.1} ...
# Trying parameter combination 186 of 1350: {'num_leaves': 5000, 'max_depth': 1, 'min_data_in_leaf': 20, 'learning_rate': 0.1} ...
# Trying parameter combination 187 of 1350: {'num_leaves': 10, 'max_depth': 3, 'min_data_in_leaf': 20, 'learning_rate': 0.1} ...
# Trying parameter combination 188 of 1350: {'num_leaves': 50, 'max_depth': 3, 'min_data_in_leaf': 20, 'learning_rate': 0.1} ...
# Trying parameter combination 189 of 1350: {'num_leaves': 200, 'max_depth': 3, 'min_data_in_leaf': 20, 'learning_rate': 0.1} ...
# Trying parameter combination 190 of 1350: {'num_leaves': 500, 'max_depth': 3, 'min_data_in_leaf': 20, 'learning_rate': 0.1} ...
# Trying parameter combination 191 of 1350: {'num_leaves': 1000, 'max_depth': 3, 'min_data_in_leaf': 20, 'learning_rate': 0.1} ...
# Trying parameter combination 192 of 1350: {'num_leaves': 5000, 'max_depth': 3, 'min_data_in_leaf': 20, 'learning_rate': 0.1} ...
# Trying parameter combination 193 of 1350: {'num_leaves': 10, 'max_depth': 5, 'min_data_in_leaf': 20, 'learning_rate': 0.1} ...
# Trying parameter combination 194 of 1350: {'num_leaves': 50, 'max_depth': 5, 'min_data_in_leaf': 20, 'learning_rate': 0.1} ...
# Trying parameter combination 195 of 1350: {'num_leaves': 200, 'max_depth': 5, 'min_data_in_leaf': 20, 'learning_rate': 0.1} ...
# Trying parameter combination 196 of 1350: {'num_leaves': 500, 'max_depth': 5, 'min_data_in_leaf': 20, 'learning_rate': 0.1} ...
# Trying parameter combination 197 of 1350: {'num_leaves': 1000, 'max_depth': 5, 'min_data_in_leaf': 20, 'learning_rate': 0.1} ...
# Trying parameter combination 198 of 1350: {'num_leaves': 5000, 'max_depth': 5, 'min_data_in_leaf': 20, 'learning_rate': 0.1} ...
# Trying parameter combination 199 of 1350: {'num_leaves': 10, 'max_depth': 10, 'min_data_in_leaf': 20, 'learning_rate': 0.1} ...
# Trying parameter combination 200 of 1350: {'num_leaves': 50, 'max_depth': 10, 'min_data_in_leaf': 20, 'learning_rate': 0.1} ...
# Trying parameter combination 201 of 1350: {'num_leaves': 200, 'max_depth': 10, 'min_data_in_leaf': 20, 'learning_rate': 0.1} ...
# Trying parameter combination 202 of 1350: {'num_leaves': 500, 'max_depth': 10, 'min_data_in_leaf': 20, 'learning_rate': 0.1} ...
# Trying parameter combination 203 of 1350: {'num_leaves': 1000, 'max_depth': 10, 'min_data_in_leaf': 20, 'learning_rate': 0.1} ...
# Trying parameter combination 204 of 1350: {'num_leaves': 5000, 'max_depth': 10, 'min_data_in_leaf': 20, 'learning_rate': 0.1} ...
# Trying parameter combination 205 of 1350: {'num_leaves': 10, 'max_depth': 50, 'min_data_in_leaf': 20, 'learning_rate': 0.1} ...
# Trying parameter combination 206 of 1350: {'num_leaves': 50, 'max_depth': 50, 'min_data_in_leaf': 20, 'learning_rate': 0.1} ...
# Trying parameter combination 207 of 1350: {'num_leaves': 200, 'max_depth': 50, 'min_data_in_leaf': 20, 'learning_rate': 0.1} ...
# Trying parameter combination 208 of 1350: {'num_leaves': 500, 'max_depth': 50, 'min_data_in_leaf': 20, 'learning_rate': 0.1} ...
# Trying parameter combination 209 of 1350: {'num_leaves': 1000, 'max_depth': 50, 'min_data_in_leaf': 20, 'learning_rate': 0.1} ...
# Trying parameter combination 210 of 1350: {'num_leaves': 5000, 'max_depth': 50, 'min_data_in_leaf': 20, 'learning_rate': 0.1} ...
# Trying parameter combination 211 of 1350: {'num_leaves': 10, 'max_depth': 1, 'min_data_in_leaf': 50, 'learning_rate': 0.1} ...
# Trying parameter combination 212 of 1350: {'num_leaves': 50, 'max_depth': 1, 'min_data_in_leaf': 50, 'learning_rate': 0.1} ...
# Trying parameter combination 213 of 1350: {'num_leaves': 200, 'max_depth': 1, 'min_data_in_leaf': 50, 'learning_rate': 0.1} ...
# Trying parameter combination 214 of 1350: {'num_leaves': 500, 'max_depth': 1, 'min_data_in_leaf': 50, 'learning_rate': 0.1} ...
# Trying parameter combination 215 of 1350: {'num_leaves': 1000, 'max_depth': 1, 'min_data_in_leaf': 50, 'learning_rate': 0.1} ...
# Trying parameter combination 216 of 1350: {'num_leaves': 5000, 'max_depth': 1, 'min_data_in_leaf': 50, 'learning_rate': 0.1} ...
# Trying parameter combination 217 of 1350: {'num_leaves': 10, 'max_depth': 3, 'min_data_in_leaf': 50, 'learning_rate': 0.1} ...
# Trying parameter combination 218 of 1350: {'num_leaves': 50, 'max_depth': 3, 'min_data_in_leaf': 50, 'learning_rate': 0.1} ...
# Trying parameter combination 219 of 1350: {'num_leaves': 200, 'max_depth': 3, 'min_data_in_leaf': 50, 'learning_rate': 0.1} ...
# Trying parameter combination 220 of 1350: {'num_leaves': 500, 'max_depth': 3, 'min_data_in_leaf': 50, 'learning_rate': 0.1} ...
# Trying parameter combination 221 of 1350: {'num_leaves': 1000, 'max_depth': 3, 'min_data_in_leaf': 50, 'learning_rate': 0.1} ...
# Trying parameter combination 222 of 1350: {'num_leaves': 5000, 'max_depth': 3, 'min_data_in_leaf': 50, 'learning_rate': 0.1} ...
# Trying parameter combination 223 of 1350: {'num_leaves': 10, 'max_depth': 5, 'min_data_in_leaf': 50, 'learning_rate': 0.1} ...
# Trying parameter combination 224 of 1350: {'num_leaves': 50, 'max_depth': 5, 'min_data_in_leaf': 50, 'learning_rate': 0.1} ...
# Trying parameter combination 225 of 1350: {'num_leaves': 200, 'max_depth': 5, 'min_data_in_leaf': 50, 'learning_rate': 0.1} ...
# Trying parameter combination 226 of 1350: {'num_leaves': 500, 'max_depth': 5, 'min_data_in_leaf': 50, 'learning_rate': 0.1} ...
# Trying parameter combination 227 of 1350: {'num_leaves': 1000, 'max_depth': 5, 'min_data_in_leaf': 50, 'learning_rate': 0.1} ...
# Trying parameter combination 228 of 1350: {'num_leaves': 5000, 'max_depth': 5, 'min_data_in_leaf': 50, 'learning_rate': 0.1} ...
# Trying parameter combination 229 of 1350: {'num_leaves': 10, 'max_depth': 10, 'min_data_in_leaf': 50, 'learning_rate': 0.1} ...
# Trying parameter combination 230 of 1350: {'num_leaves': 50, 'max_depth': 10, 'min_data_in_leaf': 50, 'learning_rate': 0.1} ...
# Trying parameter combination 231 of 1350: {'num_leaves': 200, 'max_depth': 10, 'min_data_in_leaf': 50, 'learning_rate': 0.1} ...
# Trying parameter combination 232 of 1350: {'num_leaves': 500, 'max_depth': 10, 'min_data_in_leaf': 50, 'learning_rate': 0.1} ...
# Trying parameter combination 233 of 1350: {'num_leaves': 1000, 'max_depth': 10, 'min_data_in_leaf': 50, 'learning_rate': 0.1} ...
# Trying parameter combination 234 of 1350: {'num_leaves': 5000, 'max_depth': 10, 'min_data_in_leaf': 50, 'learning_rate': 0.1} ...
# Trying parameter combination 235 of 1350: {'num_leaves': 10, 'max_depth': 50, 'min_data_in_leaf': 50, 'learning_rate': 0.1} ...
# Trying parameter combination 236 of 1350: {'num_leaves': 50, 'max_depth': 50, 'min_data_in_leaf': 50, 'learning_rate': 0.1} ...
# Trying parameter combination 237 of 1350: {'num_leaves': 200, 'max_depth': 50, 'min_data_in_leaf': 50, 'learning_rate': 0.1} ...
# Trying parameter combination 238 of 1350: {'num_leaves': 500, 'max_depth': 50, 'min_data_in_leaf': 50, 'learning_rate': 0.1} ...
# Trying parameter combination 239 of 1350: {'num_leaves': 1000, 'max_depth': 50, 'min_data_in_leaf': 50, 'learning_rate': 0.1} ...
# Trying parameter combination 240 of 1350: {'num_leaves': 5000, 'max_depth': 50, 'min_data_in_leaf': 50, 'learning_rate': 0.1} ...
# Trying parameter combination 241 of 1350: {'num_leaves': 10, 'max_depth': 1, 'min_data_in_leaf': 100, 'learning_rate': 0.1} ...
# Trying parameter combination 242 of 1350: {'num_leaves': 50, 'max_depth': 1, 'min_data_in_leaf': 100, 'learning_rate': 0.1} ...
# Trying parameter combination 243 of 1350: {'num_leaves': 200, 'max_depth': 1, 'min_data_in_leaf': 100, 'learning_rate': 0.1} ...
# Trying parameter combination 244 of 1350: {'num_leaves': 500, 'max_depth': 1, 'min_data_in_leaf': 100, 'learning_rate': 0.1} ...
# Trying parameter combination 245 of 1350: {'num_leaves': 1000, 'max_depth': 1, 'min_data_in_leaf': 100, 'learning_rate': 0.1} ...
# Trying parameter combination 246 of 1350: {'num_leaves': 5000, 'max_depth': 1, 'min_data_in_leaf': 100, 'learning_rate': 0.1} ...
# Trying parameter combination 247 of 1350: {'num_leaves': 10, 'max_depth': 3, 'min_data_in_leaf': 100, 'learning_rate': 0.1} ...
# Trying parameter combination 248 of 1350: {'num_leaves': 50, 'max_depth': 3, 'min_data_in_leaf': 100, 'learning_rate': 0.1} ...
# Trying parameter combination 249 of 1350: {'num_leaves': 200, 'max_depth': 3, 'min_data_in_leaf': 100, 'learning_rate': 0.1} ...
# Trying parameter combination 250 of 1350: {'num_leaves': 500, 'max_depth': 3, 'min_data_in_leaf': 100, 'learning_rate': 0.1} ...
# Trying parameter combination 251 of 1350: {'num_leaves': 1000, 'max_depth': 3, 'min_data_in_leaf': 100, 'learning_rate': 0.1} ...
# Trying parameter combination 252 of 1350: {'num_leaves': 5000, 'max_depth': 3, 'min_data_in_leaf': 100, 'learning_rate': 0.1} ...
# Trying parameter combination 253 of 1350: {'num_leaves': 10, 'max_depth': 5, 'min_data_in_leaf': 100, 'learning_rate': 0.1} ...
# Trying parameter combination 254 of 1350: {'num_leaves': 50, 'max_depth': 5, 'min_data_in_leaf': 100, 'learning_rate': 0.1} ...
# ***** New best score (24.136120260301464) found for the following parameter combination:
# {'num_leaves': 50, 'max_depth': 5, 'min_data_in_leaf': 100, 'learning_rate': 0.1, 'num_boost_round': 28.4}
# Trying parameter combination 255 of 1350: {'num_leaves': 200, 'max_depth': 5, 'min_data_in_leaf': 100, 'learning_rate': 0.1} ...
# Trying parameter combination 256 of 1350: {'num_leaves': 500, 'max_depth': 5, 'min_data_in_leaf': 100, 'learning_rate': 0.1} ...
# Trying parameter combination 257 of 1350: {'num_leaves': 1000, 'max_depth': 5, 'min_data_in_leaf': 100, 'learning_rate': 0.1} ...
# Trying parameter combination 258 of 1350: {'num_leaves': 5000, 'max_depth': 5, 'min_data_in_leaf': 100, 'learning_rate': 0.1} ...
# Trying parameter combination 259 of 1350: {'num_leaves': 10, 'max_depth': 10, 'min_data_in_leaf': 100, 'learning_rate': 0.1} ...
# Trying parameter combination 260 of 1350: {'num_leaves': 50, 'max_depth': 10, 'min_data_in_leaf': 100, 'learning_rate': 0.1} ...
# Trying parameter combination 261 of 1350: {'num_leaves': 200, 'max_depth': 10, 'min_data_in_leaf': 100, 'learning_rate': 0.1} ...
# Trying parameter combination 262 of 1350: {'num_leaves': 500, 'max_depth': 10, 'min_data_in_leaf': 100, 'learning_rate': 0.1} ...
# Trying parameter combination 263 of 1350: {'num_leaves': 1000, 'max_depth': 10, 'min_data_in_leaf': 100, 'learning_rate': 0.1} ...
# Trying parameter combination 264 of 1350: {'num_leaves': 5000, 'max_depth': 10, 'min_data_in_leaf': 100, 'learning_rate': 0.1} ...
# Trying parameter combination 265 of 1350: {'num_leaves': 10, 'max_depth': 50, 'min_data_in_leaf': 100, 'learning_rate': 0.1} ...
# Trying parameter combination 266 of 1350: {'num_leaves': 50, 'max_depth': 50, 'min_data_in_leaf': 100, 'learning_rate': 0.1} ...
# Trying parameter combination 267 of 1350: {'num_leaves': 200, 'max_depth': 50, 'min_data_in_leaf': 100, 'learning_rate': 0.1} ...
# Trying parameter combination 268 of 1350: {'num_leaves': 500, 'max_depth': 50, 'min_data_in_leaf': 100, 'learning_rate': 0.1} ...
# Trying parameter combination 269 of 1350: {'num_leaves': 1000, 'max_depth': 50, 'min_data_in_leaf': 100, 'learning_rate': 0.1} ...
# Trying parameter combination 270 of 1350: {'num_leaves': 5000, 'max_depth': 50, 'min_data_in_leaf': 100, 'learning_rate': 0.1} ...
# Trying parameter combination 271 of 1350: {'num_leaves': 10, 'max_depth': 1, 'min_data_in_leaf': 150, 'learning_rate': 0.1} ...
# Trying parameter combination 272 of 1350: {'num_leaves': 50, 'max_depth': 1, 'min_data_in_leaf': 150, 'learning_rate': 0.1} ...
# Trying parameter combination 273 of 1350: {'num_leaves': 200, 'max_depth': 1, 'min_data_in_leaf': 150, 'learning_rate': 0.1} ...
# Trying parameter combination 274 of 1350: {'num_leaves': 500, 'max_depth': 1, 'min_data_in_leaf': 150, 'learning_rate': 0.1} ...
# Trying parameter combination 275 of 1350: {'num_leaves': 1000, 'max_depth': 1, 'min_data_in_leaf': 150, 'learning_rate': 0.1} ...
# Trying parameter combination 276 of 1350: {'num_leaves': 5000, 'max_depth': 1, 'min_data_in_leaf': 150, 'learning_rate': 0.1} ...
# Trying parameter combination 277 of 1350: {'num_leaves': 10, 'max_depth': 3, 'min_data_in_leaf': 150, 'learning_rate': 0.1} ...
# ***** New best score (24.072337778038822) found for the following parameter combination:
# {'num_leaves': 10, 'max_depth': 3, 'min_data_in_leaf': 150, 'learning_rate': 0.1, 'num_boost_round': 33.0}
# Trying parameter combination 278 of 1350: {'num_leaves': 50, 'max_depth': 3, 'min_data_in_leaf': 150, 'learning_rate': 0.1} ...
# Trying parameter combination 279 of 1350: {'num_leaves': 200, 'max_depth': 3, 'min_data_in_leaf': 150, 'learning_rate': 0.1} ...
# Trying parameter combination 280 of 1350: {'num_leaves': 500, 'max_depth': 3, 'min_data_in_leaf': 150, 'learning_rate': 0.1} ...
# Trying parameter combination 281 of 1350: {'num_leaves': 1000, 'max_depth': 3, 'min_data_in_leaf': 150, 'learning_rate': 0.1} ...
# Trying parameter combination 282 of 1350: {'num_leaves': 5000, 'max_depth': 3, 'min_data_in_leaf': 150, 'learning_rate': 0.1} ...
# Trying parameter combination 283 of 1350: {'num_leaves': 10, 'max_depth': 5, 'min_data_in_leaf': 150, 'learning_rate': 0.1} ...
# Trying parameter combination 284 of 1350: {'num_leaves': 50, 'max_depth': 5, 'min_data_in_leaf': 150, 'learning_rate': 0.1} ...
# Trying parameter combination 285 of 1350: {'num_leaves': 200, 'max_depth': 5, 'min_data_in_leaf': 150, 'learning_rate': 0.1} ...
# Trying parameter combination 286 of 1350: {'num_leaves': 500, 'max_depth': 5, 'min_data_in_leaf': 150, 'learning_rate': 0.1} ...
# Trying parameter combination 287 of 1350: {'num_leaves': 1000, 'max_depth': 5, 'min_data_in_leaf': 150, 'learning_rate': 0.1} ...
# Trying parameter combination 288 of 1350: {'num_leaves': 5000, 'max_depth': 5, 'min_data_in_leaf': 150, 'learning_rate': 0.1} ...
# Trying parameter combination 289 of 1350: {'num_leaves': 10, 'max_depth': 10, 'min_data_in_leaf': 150, 'learning_rate': 0.1} ...
# Trying parameter combination 290 of 1350: {'num_leaves': 50, 'max_depth': 10, 'min_data_in_leaf': 150, 'learning_rate': 0.1} ...
# Trying parameter combination 291 of 1350: {'num_leaves': 200, 'max_depth': 10, 'min_data_in_leaf': 150, 'learning_rate': 0.1} ...
# Trying parameter combination 292 of 1350: {'num_leaves': 500, 'max_depth': 10, 'min_data_in_leaf': 150, 'learning_rate': 0.1} ...
# Trying parameter combination 293 of 1350: {'num_leaves': 1000, 'max_depth': 10, 'min_data_in_leaf': 150, 'learning_rate': 0.1} ...
# Trying parameter combination 294 of 1350: {'num_leaves': 5000, 'max_depth': 10, 'min_data_in_leaf': 150, 'learning_rate': 0.1} ...
# Trying parameter combination 295 of 1350: {'num_leaves': 10, 'max_depth': 50, 'min_data_in_leaf': 150, 'learning_rate': 0.1} ...
# Trying parameter combination 296 of 1350: {'num_leaves': 50, 'max_depth': 50, 'min_data_in_leaf': 150, 'learning_rate': 0.1} ...
# Trying parameter combination 297 of 1350: {'num_leaves': 200, 'max_depth': 50, 'min_data_in_leaf': 150, 'learning_rate': 0.1} ...
# Trying parameter combination 298 of 1350: {'num_leaves': 500, 'max_depth': 50, 'min_data_in_leaf': 150, 'learning_rate': 0.1} ...
# Trying parameter combination 299 of 1350: {'num_leaves': 1000, 'max_depth': 50, 'min_data_in_leaf': 150, 'learning_rate': 0.1} ...
# Trying parameter combination 300 of 1350: {'num_leaves': 5000, 'max_depth': 50, 'min_data_in_leaf': 150, 'learning_rate': 0.1} ...
# Trying parameter combination 301 of 1350: {'num_leaves': 10, 'max_depth': 1, 'min_data_in_leaf': 5, 'learning_rate': 0.3} ...
# Trying parameter combination 302 of 1350: {'num_leaves': 50, 'max_depth': 1, 'min_data_in_leaf': 5, 'learning_rate': 0.3} ...
# Trying parameter combination 303 of 1350: {'num_leaves': 200, 'max_depth': 1, 'min_data_in_leaf': 5, 'learning_rate': 0.3} ...
# Trying parameter combination 304 of 1350: {'num_leaves': 500, 'max_depth': 1, 'min_data_in_leaf': 5, 'learning_rate': 0.3} ...
# Trying parameter combination 305 of 1350: {'num_leaves': 1000, 'max_depth': 1, 'min_data_in_leaf': 5, 'learning_rate': 0.3} ...
# Trying parameter combination 306 of 1350: {'num_leaves': 5000, 'max_depth': 1, 'min_data_in_leaf': 5, 'learning_rate': 0.3} ...
# Trying parameter combination 307 of 1350: {'num_leaves': 10, 'max_depth': 3, 'min_data_in_leaf': 5, 'learning_rate': 0.3} ...
# Trying parameter combination 308 of 1350: {'num_leaves': 50, 'max_depth': 3, 'min_data_in_leaf': 5, 'learning_rate': 0.3} ...
# Trying parameter combination 309 of 1350: {'num_leaves': 200, 'max_depth': 3, 'min_data_in_leaf': 5, 'learning_rate': 0.3} ...
# Trying parameter combination 310 of 1350: {'num_leaves': 500, 'max_depth': 3, 'min_data_in_leaf': 5, 'learning_rate': 0.3} ...
# Trying parameter combination 311 of 1350: {'num_leaves': 1000, 'max_depth': 3, 'min_data_in_leaf': 5, 'learning_rate': 0.3} ...
# Trying parameter combination 312 of 1350: {'num_leaves': 5000, 'max_depth': 3, 'min_data_in_leaf': 5, 'learning_rate': 0.3} ...
# Trying parameter combination 313 of 1350: {'num_leaves': 10, 'max_depth': 5, 'min_data_in_leaf': 5, 'learning_rate': 0.3} ...
# Trying parameter combination 314 of 1350: {'num_leaves': 50, 'max_depth': 5, 'min_data_in_leaf': 5, 'learning_rate': 0.3} ...
# Trying parameter combination 315 of 1350: {'num_leaves': 200, 'max_depth': 5, 'min_data_in_leaf': 5, 'learning_rate': 0.3} ...
# Trying parameter combination 316 of 1350: {'num_leaves': 500, 'max_depth': 5, 'min_data_in_leaf': 5, 'learning_rate': 0.3} ...
# Trying parameter combination 317 of 1350: {'num_leaves': 1000, 'max_depth': 5, 'min_data_in_leaf': 5, 'learning_rate': 0.3} ...
# Trying parameter combination 318 of 1350: {'num_leaves': 5000, 'max_depth': 5, 'min_data_in_leaf': 5, 'learning_rate': 0.3} ...
# Trying parameter combination 319 of 1350: {'num_leaves': 10, 'max_depth': 10, 'min_data_in_leaf': 5, 'learning_rate': 0.3} ...
# Trying parameter combination 320 of 1350: {'num_leaves': 50, 'max_depth': 10, 'min_data_in_leaf': 5, 'learning_rate': 0.3} ...
# Trying parameter combination 321 of 1350: {'num_leaves': 200, 'max_depth': 10, 'min_data_in_leaf': 5, 'learning_rate': 0.3} ...
# Trying parameter combination 322 of 1350: {'num_leaves': 500, 'max_depth': 10, 'min_data_in_leaf': 5, 'learning_rate': 0.3} ...
# Trying parameter combination 323 of 1350: {'num_leaves': 1000, 'max_depth': 10, 'min_data_in_leaf': 5, 'learning_rate': 0.3} ...
# Trying parameter combination 324 of 1350: {'num_leaves': 5000, 'max_depth': 10, 'min_data_in_leaf': 5, 'learning_rate': 0.3} ...
# Trying parameter combination 325 of 1350: {'num_leaves': 10, 'max_depth': 50, 'min_data_in_leaf': 5, 'learning_rate': 0.3} ...
# Trying parameter combination 326 of 1350: {'num_leaves': 50, 'max_depth': 50, 'min_data_in_leaf': 5, 'learning_rate': 0.3} ...
# Trying parameter combination 327 of 1350: {'num_leaves': 200, 'max_depth': 50, 'min_data_in_leaf': 5, 'learning_rate': 0.3} ...
# Trying parameter combination 328 of 1350: {'num_leaves': 500, 'max_depth': 50, 'min_data_in_leaf': 5, 'learning_rate': 0.3} ...
# Trying parameter combination 329 of 1350: {'num_leaves': 1000, 'max_depth': 50, 'min_data_in_leaf': 5, 'learning_rate': 0.3} ...
# Trying parameter combination 330 of 1350: {'num_leaves': 5000, 'max_depth': 50, 'min_data_in_leaf': 5, 'learning_rate': 0.3} ...
# Trying parameter combination 331 of 1350: {'num_leaves': 10, 'max_depth': 1, 'min_data_in_leaf': 20, 'learning_rate': 0.3} ...
# Trying parameter combination 332 of 1350: {'num_leaves': 50, 'max_depth': 1, 'min_data_in_leaf': 20, 'learning_rate': 0.3} ...
# Trying parameter combination 333 of 1350: {'num_leaves': 200, 'max_depth': 1, 'min_data_in_leaf': 20, 'learning_rate': 0.3} ...
# Trying parameter combination 334 of 1350: {'num_leaves': 500, 'max_depth': 1, 'min_data_in_leaf': 20, 'learning_rate': 0.3} ...
# Trying parameter combination 335 of 1350: {'num_leaves': 1000, 'max_depth': 1, 'min_data_in_leaf': 20, 'learning_rate': 0.3} ...
# Trying parameter combination 336 of 1350: {'num_leaves': 5000, 'max_depth': 1, 'min_data_in_leaf': 20, 'learning_rate': 0.3} ...
# Trying parameter combination 337 of 1350: {'num_leaves': 10, 'max_depth': 3, 'min_data_in_leaf': 20, 'learning_rate': 0.3} ...
# Trying parameter combination 338 of 1350: {'num_leaves': 50, 'max_depth': 3, 'min_data_in_leaf': 20, 'learning_rate': 0.3} ...
# Trying parameter combination 339 of 1350: {'num_leaves': 200, 'max_depth': 3, 'min_data_in_leaf': 20, 'learning_rate': 0.3} ...
# Trying parameter combination 340 of 1350: {'num_leaves': 500, 'max_depth': 3, 'min_data_in_leaf': 20, 'learning_rate': 0.3} ...
# ...
# Trying parameter combination 1230 of 1350: {'num_leaves': 5000, 'max_depth': 50, 'min_data_in_leaf': 5, 'learning_rate': 2.0} ...
# Trying parameter combination 1231 of 1350: {'num_leaves': 10, 'max_depth': 1, 'min_data_in_leaf': 20, 'learning_rate': 2.0} ...
# Trying parameter combination 1232 of 1350: {'num_leaves': 50, 'max_depth': 1, 'min_data_in_leaf': 20, 'learning_rate': 2.0} ...
# Trying parameter combination 1233 of 1350: {'num_leaves': 200, 'max_depth': 1, 'min_data_in_leaf': 20, 'learning_rate': 2.0} ...
# Trying parameter combination 1234 of 1350: {'num_leaves': 500, 'max_depth': 1, 'min_data_in_leaf': 20, 'learning_rate': 2.0} ...
# Trying parameter combination 1235 of 1350: {'num_leaves': 1000, 'max_depth': 1, 'min_data_in_leaf': 20, 'learning_rate': 2.0} ...
# Trying parameter combination 1236 of 1350: {'num_leaves': 5000, 'max_depth': 1, 'min_data_in_leaf': 20, 'learning_rate': 2.0} ...
# Trying parameter combination 1237 of 1350: {'num_leaves': 10, 'max_depth': 3, 'min_data_in_leaf': 20, 'learning_rate': 2.0} ...
# Trying parameter combination 1238 of 1350: {'num_leaves': 50, 'max_depth': 3, 'min_data_in_leaf': 20, 'learning_rate': 2.0} ...
# Trying parameter combination 1239 of 1350: {'num_leaves': 200, 'max_depth': 3, 'min_data_in_leaf': 20, 'learning_rate': 2.0} ...
# Trying parameter combination 1240 of 1350: {'num_leaves': 500, 'max_depth': 3, 'min_data_in_leaf': 20, 'learning_rate': 2.0} ...
# Trying parameter combination 1241 of 1350: {'num_leaves': 1000, 'max_depth': 3, 'min_data_in_leaf': 20, 'learning_rate': 2.0} ...
# Trying parameter combination 1242 of 1350: {'num_leaves': 5000, 'max_depth': 3, 'min_data_in_leaf': 20, 'learning_rate': 2.0} ...
# Trying parameter combination 1243 of 1350: {'num_leaves': 10, 'max_depth': 5, 'min_data_in_leaf': 20, 'learning_rate': 2.0} ...
# Trying parameter combination 1244 of 1350: {'num_leaves': 50, 'max_depth': 5, 'min_data_in_leaf': 20, 'learning_rate': 2.0} ...
# Trying parameter combination 1245 of 1350: {'num_leaves': 200, 'max_depth': 5, 'min_data_in_leaf': 20, 'learning_rate': 2.0} ...
# Trying parameter combination 1246 of 1350: {'num_leaves': 500, 'max_depth': 5, 'min_data_in_leaf': 20, 'learning_rate': 2.0} ...
# Trying parameter combination 1247 of 1350: {'num_leaves': 1000, 'max_depth': 5, 'min_data_in_leaf': 20, 'learning_rate': 2.0} ...
# Trying parameter combination 1248 of 1350: {'num_leaves': 5000, 'max_depth': 5, 'min_data_in_leaf': 20, 'learning_rate': 2.0} ...
# Trying parameter combination 1249 of 1350: {'num_leaves': 10, 'max_depth': 10, 'min_data_in_leaf': 20, 'learning_rate': 2.0} ...
# Trying parameter combination 1250 of 1350: {'num_leaves': 50, 'max_depth': 10, 'min_data_in_leaf': 20, 'learning_rate': 2.0} ...
# Trying parameter combination 1251 of 1350: {'num_leaves': 200, 'max_depth': 10, 'min_data_in_leaf': 20, 'learning_rate': 2.0} ...
# Trying parameter combination 1252 of 1350: {'num_leaves': 500, 'max_depth': 10, 'min_data_in_leaf': 20, 'learning_rate': 2.0} ...
# Trying parameter combination 1253 of 1350: {'num_leaves': 1000, 'max_depth': 10, 'min_data_in_leaf': 20, 'learning_rate': 2.0} ...
# Trying parameter combination 1254 of 1350: {'num_leaves': 5000, 'max_depth': 10, 'min_data_in_leaf': 20, 'learning_rate': 2.0} ...
# Trying parameter combination 1255 of 1350: {'num_leaves': 10, 'max_depth': 50, 'min_data_in_leaf': 20, 'learning_rate': 2.0} ...
# Trying parameter combination 1256 of 1350: {'num_leaves': 50, 'max_depth': 50, 'min_data_in_leaf': 20, 'learning_rate': 2.0} ...
# Trying parameter combination 1257 of 1350: {'num_leaves': 200, 'max_depth': 50, 'min_data_in_leaf': 20, 'learning_rate': 2.0} ...
# Trying parameter combination 1258 of 1350: {'num_leaves': 500, 'max_depth': 50, 'min_data_in_leaf': 20, 'learning_rate': 2.0} ...
# Trying parameter combination 1259 of 1350: {'num_leaves': 1000, 'max_depth': 50, 'min_data_in_leaf': 20, 'learning_rate': 2.0} ...
# Trying parameter combination 1260 of 1350: {'num_leaves': 5000, 'max_depth': 50, 'min_data_in_leaf': 20, 'learning_rate': 2.0} ...
# Trying parameter combination 1261 of 1350: {'num_leaves': 10, 'max_depth': 1, 'min_data_in_leaf': 50, 'learning_rate': 2.0} ...
# Trying parameter combination 1262 of 1350: {'num_leaves': 50, 'max_depth': 1, 'min_data_in_leaf': 50, 'learning_rate': 2.0} ...
# Trying parameter combination 1263 of 1350: {'num_leaves': 200, 'max_depth': 1, 'min_data_in_leaf': 50, 'learning_rate': 2.0} ...
# Trying parameter combination 1264 of 1350: {'num_leaves': 500, 'max_depth': 1, 'min_data_in_leaf': 50, 'learning_rate': 2.0} ...
# Trying parameter combination 1265 of 1350: {'num_leaves': 1000, 'max_depth': 1, 'min_data_in_leaf': 50, 'learning_rate': 2.0} ...
# Trying parameter combination 1266 of 1350: {'num_leaves': 5000, 'max_depth': 1, 'min_data_in_leaf': 50, 'learning_rate': 2.0} ...
# Trying parameter combination 1267 of 1350: {'num_leaves': 10, 'max_depth': 3, 'min_data_in_leaf': 50, 'learning_rate': 2.0} ...
# Trying parameter combination 1268 of 1350: {'num_leaves': 50, 'max_depth': 3, 'min_data_in_leaf': 50, 'learning_rate': 2.0} ...
# Trying parameter combination 1269 of 1350: {'num_leaves': 200, 'max_depth': 3, 'min_data_in_leaf': 50, 'learning_rate': 2.0} ...
# Trying parameter combination 1270 of 1350: {'num_leaves': 500, 'max_depth': 3, 'min_data_in_leaf': 50, 'learning_rate': 2.0} ...
# Trying parameter combination 1271 of 1350: {'num_leaves': 1000, 'max_depth': 3, 'min_data_in_leaf': 50, 'learning_rate': 2.0} ...
# Trying parameter combination 1272 of 1350: {'num_leaves': 5000, 'max_depth': 3, 'min_data_in_leaf': 50, 'learning_rate': 2.0} ...
# Trying parameter combination 1273 of 1350: {'num_leaves': 10, 'max_depth': 5, 'min_data_in_leaf': 50, 'learning_rate': 2.0} ...
# Trying parameter combination 1274 of 1350: {'num_leaves': 50, 'max_depth': 5, 'min_data_in_leaf': 50, 'learning_rate': 2.0} ...
# Trying parameter combination 1275 of 1350: {'num_leaves': 200, 'max_depth': 5, 'min_data_in_leaf': 50, 'learning_rate': 2.0} ...
# Trying parameter combination 1276 of 1350: {'num_leaves': 500, 'max_depth': 5, 'min_data_in_leaf': 50, 'learning_rate': 2.0} ...
# Trying parameter combination 1277 of 1350: {'num_leaves': 1000, 'max_depth': 5, 'min_data_in_leaf': 50, 'learning_rate': 2.0} ...
# Trying parameter combination 1278 of 1350: {'num_leaves': 5000, 'max_depth': 5, 'min_data_in_leaf': 50, 'learning_rate': 2.0} ...
# Trying parameter combination 1279 of 1350: {'num_leaves': 10, 'max_depth': 10, 'min_data_in_leaf': 50, 'learning_rate': 2.0} ...
# Trying parameter combination 1280 of 1350: {'num_leaves': 50, 'max_depth': 10, 'min_data_in_leaf': 50, 'learning_rate': 2.0} ...
# Trying parameter combination 1281 of 1350: {'num_leaves': 200, 'max_depth': 10, 'min_data_in_leaf': 50, 'learning_rate': 2.0} ...
# Trying parameter combination 1282 of 1350: {'num_leaves': 500, 'max_depth': 10, 'min_data_in_leaf': 50, 'learning_rate': 2.0} ...
# Trying parameter combination 1283 of 1350: {'num_leaves': 1000, 'max_depth': 10, 'min_data_in_leaf': 50, 'learning_rate': 2.0} ...
# Trying parameter combination 1284 of 1350: {'num_leaves': 5000, 'max_depth': 10, 'min_data_in_leaf': 50, 'learning_rate': 2.0} ...
# Trying parameter combination 1285 of 1350: {'num_leaves': 10, 'max_depth': 50, 'min_data_in_leaf': 50, 'learning_rate': 2.0} ...
# Trying parameter combination 1286 of 1350: {'num_leaves': 50, 'max_depth': 50, 'min_data_in_leaf': 50, 'learning_rate': 2.0} ...
# Trying parameter combination 1287 of 1350: {'num_leaves': 200, 'max_depth': 50, 'min_data_in_leaf': 50, 'learning_rate': 2.0} ...
# Trying parameter combination 1288 of 1350: {'num_leaves': 500, 'max_depth': 50, 'min_data_in_leaf': 50, 'learning_rate': 2.0} ...
# Trying parameter combination 1289 of 1350: {'num_leaves': 1000, 'max_depth': 50, 'min_data_in_leaf': 50, 'learning_rate': 2.0} ...
# Trying parameter combination 1290 of 1350: {'num_leaves': 5000, 'max_depth': 50, 'min_data_in_leaf': 50, 'learning_rate': 2.0} ...
# Trying parameter combination 1291 of 1350: {'num_leaves': 10, 'max_depth': 1, 'min_data_in_leaf': 100, 'learning_rate': 2.0} ...
# Trying parameter combination 1292 of 1350: {'num_leaves': 50, 'max_depth': 1, 'min_data_in_leaf': 100, 'learning_rate': 2.0} ...
# Trying parameter combination 1293 of 1350: {'num_leaves': 200, 'max_depth': 1, 'min_data_in_leaf': 100, 'learning_rate': 2.0} ...
# Trying parameter combination 1294 of 1350: {'num_leaves': 500, 'max_depth': 1, 'min_data_in_leaf': 100, 'learning_rate': 2.0} ...
# Trying parameter combination 1295 of 1350: {'num_leaves': 1000, 'max_depth': 1, 'min_data_in_leaf': 100, 'learning_rate': 2.0} ...
# Trying parameter combination 1296 of 1350: {'num_leaves': 5000, 'max_depth': 1, 'min_data_in_leaf': 100, 'learning_rate': 2.0} ...
# Trying parameter combination 1297 of 1350: {'num_leaves': 10, 'max_depth': 3, 'min_data_in_leaf': 100, 'learning_rate': 2.0} ...
# Trying parameter combination 1298 of 1350: {'num_leaves': 50, 'max_depth': 3, 'min_data_in_leaf': 100, 'learning_rate': 2.0} ...
# Trying parameter combination 1299 of 1350: {'num_leaves': 200, 'max_depth': 3, 'min_data_in_leaf': 100, 'learning_rate': 2.0} ...
# Trying parameter combination 1300 of 1350: {'num_leaves': 500, 'max_depth': 3, 'min_data_in_leaf': 100, 'learning_rate': 2.0} ...
# Trying parameter combination 1301 of 1350: {'num_leaves': 1000, 'max_depth': 3, 'min_data_in_leaf': 100, 'learning_rate': 2.0} ...
# Trying parameter combination 1302 of 1350: {'num_leaves': 5000, 'max_depth': 3, 'min_data_in_leaf': 100, 'learning_rate': 2.0} ...
# Trying parameter combination 1303 of 1350: {'num_leaves': 10, 'max_depth': 5, 'min_data_in_leaf': 100, 'learning_rate': 2.0} ...
# Trying parameter combination 1304 of 1350: {'num_leaves': 50, 'max_depth': 5, 'min_data_in_leaf': 100, 'learning_rate': 2.0} ...
# Trying parameter combination 1305 of 1350: {'num_leaves': 200, 'max_depth': 5, 'min_data_in_leaf': 100, 'learning_rate': 2.0} ...
# Trying parameter combination 1306 of 1350: {'num_leaves': 500, 'max_depth': 5, 'min_data_in_leaf': 100, 'learning_rate': 2.0} ...
# Trying parameter combination 1307 of 1350: {'num_leaves': 1000, 'max_depth': 5, 'min_data_in_leaf': 100, 'learning_rate': 2.0} ...
# Trying parameter combination 1308 of 1350: {'num_leaves': 5000, 'max_depth': 5, 'min_data_in_leaf': 100, 'learning_rate': 2.0} ...
# Trying parameter combination 1309 of 1350: {'num_leaves': 10, 'max_depth': 10, 'min_data_in_leaf': 100, 'learning_rate': 2.0} ...
# Trying parameter combination 1310 of 1350: {'num_leaves': 50, 'max_depth': 10, 'min_data_in_leaf': 100, 'learning_rate': 2.0} ...
# Trying parameter combination 1311 of 1350: {'num_leaves': 200, 'max_depth': 10, 'min_data_in_leaf': 100, 'learning_rate': 2.0} ...
# Trying parameter combination 1312 of 1350: {'num_leaves': 500, 'max_depth': 10, 'min_data_in_leaf': 100, 'learning_rate': 2.0} ...
# Trying parameter combination 1313 of 1350: {'num_leaves': 1000, 'max_depth': 10, 'min_data_in_leaf': 100, 'learning_rate': 2.0} ...
# Trying parameter combination 1314 of 1350: {'num_leaves': 5000, 'max_depth': 10, 'min_data_in_leaf': 100, 'learning_rate': 2.0} ...
# Trying parameter combination 1315 of 1350: {'num_leaves': 10, 'max_depth': 50, 'min_data_in_leaf': 100, 'learning_rate': 2.0} ...
# Trying parameter combination 1316 of 1350: {'num_leaves': 50, 'max_depth': 50, 'min_data_in_leaf': 100, 'learning_rate': 2.0} ...
# Trying parameter combination 1317 of 1350: {'num_leaves': 200, 'max_depth': 50, 'min_data_in_leaf': 100, 'learning_rate': 2.0} ...
# Trying parameter combination 1318 of 1350: {'num_leaves': 500, 'max_depth': 50, 'min_data_in_leaf': 100, 'learning_rate': 2.0} ...
# Trying parameter combination 1319 of 1350: {'num_leaves': 1000, 'max_depth': 50, 'min_data_in_leaf': 100, 'learning_rate': 2.0} ...
# Trying parameter combination 1320 of 1350: {'num_leaves': 5000, 'max_depth': 50, 'min_data_in_leaf': 100, 'learning_rate': 2.0} ...
# Trying parameter combination 1321 of 1350: {'num_leaves': 10, 'max_depth': 1, 'min_data_in_leaf': 150, 'learning_rate': 2.0} ...
# Trying parameter combination 1322 of 1350: {'num_leaves': 50, 'max_depth': 1, 'min_data_in_leaf': 150, 'learning_rate': 2.0} ...
# Trying parameter combination 1323 of 1350: {'num_leaves': 200, 'max_depth': 1, 'min_data_in_leaf': 150, 'learning_rate': 2.0} ...
# Trying parameter combination 1324 of 1350: {'num_leaves': 500, 'max_depth': 1, 'min_data_in_leaf': 150, 'learning_rate': 2.0} ...
# Trying parameter combination 1325 of 1350: {'num_leaves': 1000, 'max_depth': 1, 'min_data_in_leaf': 150, 'learning_rate': 2.0} ...
# Trying parameter combination 1326 of 1350: {'num_leaves': 5000, 'max_depth': 1, 'min_data_in_leaf': 150, 'learning_rate': 2.0} ...
# Trying parameter combination 1327 of 1350: {'num_leaves': 10, 'max_depth': 3, 'min_data_in_leaf': 150, 'learning_rate': 2.0} ...
# Trying parameter combination 1328 of 1350: {'num_leaves': 50, 'max_depth': 3, 'min_data_in_leaf': 150, 'learning_rate': 2.0} ...
# Trying parameter combination 1329 of 1350: {'num_leaves': 200, 'max_depth': 3, 'min_data_in_leaf': 150, 'learning_rate': 2.0} ...
# Trying parameter combination 1330 of 1350: {'num_leaves': 500, 'max_depth': 3, 'min_data_in_leaf': 150, 'learning_rate': 2.0} ...
# Trying parameter combination 1331 of 1350: {'num_leaves': 1000, 'max_depth': 3, 'min_data_in_leaf': 150, 'learning_rate': 2.0} ...
# Trying parameter combination 1332 of 1350: {'num_leaves': 5000, 'max_depth': 3, 'min_data_in_leaf': 150, 'learning_rate': 2.0} ...
# Trying parameter combination 1333 of 1350: {'num_leaves': 10, 'max_depth': 5, 'min_data_in_leaf': 150, 'learning_rate': 2.0} ...
# Trying parameter combination 1334 of 1350: {'num_leaves': 50, 'max_depth': 5, 'min_data_in_leaf': 150, 'learning_rate': 2.0} ...
# Trying parameter combination 1335 of 1350: {'num_leaves': 200, 'max_depth': 5, 'min_data_in_leaf': 150, 'learning_rate': 2.0} ...
# Trying parameter combination 1336 of 1350: {'num_leaves': 500, 'max_depth': 5, 'min_data_in_leaf': 150, 'learning_rate': 2.0} ...
# Trying parameter combination 1337 of 1350: {'num_leaves': 1000, 'max_depth': 5, 'min_data_in_leaf': 150, 'learning_rate': 2.0} ...
# Trying parameter combination 1338 of 1350: {'num_leaves': 5000, 'max_depth': 5, 'min_data_in_leaf': 150, 'learning_rate': 2.0} ...
# Trying parameter combination 1339 of 1350: {'num_leaves': 10, 'max_depth': 10, 'min_data_in_leaf': 150, 'learning_rate': 2.0} ...
# Trying parameter combination 1340 of 1350: {'num_leaves': 50, 'max_depth': 10, 'min_data_in_leaf': 150, 'learning_rate': 2.0} ...
# Trying parameter combination 1341 of 1350: {'num_leaves': 200, 'max_depth': 10, 'min_data_in_leaf': 150, 'learning_rate': 2.0} ...
# Trying parameter combination 1342 of 1350: {'num_leaves': 500, 'max_depth': 10, 'min_data_in_leaf': 150, 'learning_rate': 2.0} ...
# Trying parameter combination 1343 of 1350: {'num_leaves': 1000, 'max_depth': 10, 'min_data_in_leaf': 150, 'learning_rate': 2.0} ...
# Trying parameter combination 1344 of 1350: {'num_leaves': 5000, 'max_depth': 10, 'min_data_in_leaf': 150, 'learning_rate': 2.0} ...
# Trying parameter combination 1345 of 1350: {'num_leaves': 10, 'max_depth': 50, 'min_data_in_leaf': 150, 'learning_rate': 2.0} ...
# Trying parameter combination 1346 of 1350: {'num_leaves': 50, 'max_depth': 50, 'min_data_in_leaf': 150, 'learning_rate': 2.0} ...
# Trying parameter combination 1347 of 1350: {'num_leaves': 200, 'max_depth': 50, 'min_data_in_leaf': 150, 'learning_rate': 2.0} ...
# Trying parameter combination 1348 of 1350: {'num_leaves': 500, 'max_depth': 50, 'min_data_in_leaf': 150, 'learning_rate': 2.0} ...
# Trying parameter combination 1349 of 1350: {'num_leaves': 1000, 'max_depth': 50, 'min_data_in_leaf': 150, 'learning_rate': 2.0} ...
# Trying parameter combination 1350 of 1350: {'num_leaves': 5000, 'max_depth': 50, 'min_data_in_leaf': 150, 'learning_rate': 2.0} ...
# Best number of iterations:  3.0
# Best score:  23.770723975211503
# Best parameters:  {'num_leaves': 1000, 'max_depth': 3, 'min_data_in_leaf': 150, 'learning_rate': 1.5}

# %% [markdown]
# ## NOTE: Vecchia approximation can't be used with grouped random effects (ie. can't have a random intercept in the random effects model)

# %% [markdown]
# ## Tuning the GPBoost model with a shared GP using the Vecchia approximation

# %%
# Candidate parameter grid
param_grid = {'num_leaves': [50, 1000, 5000], 
              'max_depth': [3, 10, 50, 100],
              'min_data_in_leaf': [5, 10, 50, 100], 
               'learning_rate' : [1.5, 2]}

# Other parameters not contained in the grid of tuning parameters
params = {'objective': 'regression_l2',
          'verbose': 0}
          #'learning_rate' : 1.5}
          #'device_type' : 'gpu'}

n_neighbors = 30
ordering = 'random'
pred_type = 'order_pred_first'
n_neighbors_pred = 30

opt_params = grid_search_tune_parameters_multiple(data_cv_list, dataset_list, param_grid, params=params, num_try_random=None,
                                         num_boost_round=5000,
                                         use_gp_model_for_validation=True, train_gp_model_cov_pars=False, folds_list=data_cv_indices_list, nfold=5, stratified=False, shuffle=False,
                                         metrics='rmse', fobj=None, feval=None, init_model=None,
                                         feature_name='auto',
                                         early_stopping_rounds=10, fpreproc=None,
                                         verbose_eval=1, seed=0, callbacks=None,
                                         gp_model_type='Shared GP', 
                                         num_neighbors=n_neighbors, 
                                         vecchia_ordering=ordering, 
                                         vecchia_pred_type=pred_type, 
                                         num_neighbors_pred=n_neighbors_pred)
                                                  

print('Best number of iterations: ', opt_params['best_iter'])
print('Best score: ', opt_params['best_score'])
print('Best parameters: ', opt_params['best_params'])
# Out:
# Starting deterministic grid search with 96 parameter combinations...
# Trying parameter combination 1 of 96: {'num_leaves': 50, 'max_depth': 3, 'min_data_in_leaf': 5, 'learning_rate': 1.5} ...
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# ***** New best score (25.740279589035246) found for the following parameter combination:
# {'num_leaves': 50, 'max_depth': 3, 'min_data_in_leaf': 5, 'learning_rate': 1.5, 'num_boost_round': 785.0}
# Trying parameter combination 2 of 96: {'num_leaves': 1000, 'max_depth': 3, 'min_data_in_leaf': 5, 'learning_rate': 1.5} ...
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# Trying parameter combination 3 of 96: {'num_leaves': 5000, 'max_depth': 3, 'min_data_in_leaf': 5, 'learning_rate': 1.5} ...
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# Trying parameter combination 4 of 96: {'num_leaves': 50, 'max_depth': 10, 'min_data_in_leaf': 5, 'learning_rate': 1.5} ...
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# Trying parameter combination 5 of 96: {'num_leaves': 1000, 'max_depth': 10, 'min_data_in_leaf': 5, 'learning_rate': 1.5} ...
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# Trying parameter combination 6 of 96: {'num_leaves': 5000, 'max_depth': 10, 'min_data_in_leaf': 5, 'learning_rate': 1.5} ...
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# Trying parameter combination 7 of 96: {'num_leaves': 50, 'max_depth': 50, 'min_data_in_leaf': 5, 'learning_rate': 1.5} ...
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# Trying parameter combination 8 of 96: {'num_leaves': 1000, 'max_depth': 50, 'min_data_in_leaf': 5, 'learning_rate': 1.5} ...
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# Trying parameter combination 9 of 96: {'num_leaves': 5000, 'max_depth': 50, 'min_data_in_leaf': 5, 'learning_rate': 1.5} ...
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# Trying parameter combination 10 of 96: {'num_leaves': 50, 'max_depth': 100, 'min_data_in_leaf': 5, 'learning_rate': 1.5} ...
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# Trying parameter combination 11 of 96: {'num_leaves': 1000, 'max_depth': 100, 'min_data_in_leaf': 5, 'learning_rate': 1.5} ...
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# Trying parameter combination 12 of 96: {'num_leaves': 5000, 'max_depth': 100, 'min_data_in_leaf': 5, 'learning_rate': 1.5} ...
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# Trying parameter combination 13 of 96: {'num_leaves': 50, 'max_depth': 3, 'min_data_in_leaf': 10, 'learning_rate': 1.5} ...
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# Trying parameter combination 14 of 96: {'num_leaves': 1000, 'max_depth': 3, 'min_data_in_leaf': 10, 'learning_rate': 1.5} ...
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# Trying parameter combination 15 of 96: {'num_leaves': 5000, 'max_depth': 3, 'min_data_in_leaf': 10, 'learning_rate': 1.5} ...
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# Trying parameter combination 16 of 96: {'num_leaves': 50, 'max_depth': 10, 'min_data_in_leaf': 10, 'learning_rate': 1.5} ...
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# Trying parameter combination 17 of 96: {'num_leaves': 1000, 'max_depth': 10, 'min_data_in_leaf': 10, 'learning_rate': 1.5} ...
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# Trying parameter combination 18 of 96: {'num_leaves': 5000, 'max_depth': 10, 'min_data_in_leaf': 10, 'learning_rate': 1.5} ...
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# Trying parameter combination 19 of 96: {'num_leaves': 50, 'max_depth': 50, 'min_data_in_leaf': 10, 'learning_rate': 1.5} ...
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# Trying parameter combination 20 of 96: {'num_leaves': 1000, 'max_depth': 50, 'min_data_in_leaf': 10, 'learning_rate': 1.5} ...
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# Trying parameter combination 21 of 96: {'num_leaves': 5000, 'max_depth': 50, 'min_data_in_leaf': 10, 'learning_rate': 1.5} ...
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# Trying parameter combination 22 of 96: {'num_leaves': 50, 'max_depth': 100, 'min_data_in_leaf': 10, 'learning_rate': 1.5} ...
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# Trying parameter combination 23 of 96: {'num_leaves': 1000, 'max_depth': 100, 'min_data_in_leaf': 10, 'learning_rate': 1.5} ...
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# Trying parameter combination 24 of 96: {'num_leaves': 5000, 'max_depth': 100, 'min_data_in_leaf': 10, 'learning_rate': 1.5} ...
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# Trying parameter combination 25 of 96: {'num_leaves': 50, 'max_depth': 3, 'min_data_in_leaf': 50, 'learning_rate': 1.5} ...
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# Trying parameter combination 26 of 96: {'num_leaves': 1000, 'max_depth': 3, 'min_data_in_leaf': 50, 'learning_rate': 1.5} ...
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# Trying parameter combination 27 of 96: {'num_leaves': 5000, 'max_depth': 3, 'min_data_in_leaf': 50, 'learning_rate': 1.5} ...
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# Trying parameter combination 28 of 96: {'num_leaves': 50, 'max_depth': 10, 'min_data_in_leaf': 50, 'learning_rate': 1.5} ...
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# ***** New best score (25.370976880274004) found for the following parameter combination:
# {'num_leaves': 50, 'max_depth': 10, 'min_data_in_leaf': 50, 'learning_rate': 1.5, 'num_boost_round': 718.8}
# Trying parameter combination 29 of 96: {'num_leaves': 1000, 'max_depth': 10, 'min_data_in_leaf': 50, 'learning_rate': 1.5} ...
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# ***** New best score (25.37073454815853) found for the following parameter combination:
# {'num_leaves': 1000, 'max_depth': 10, 'min_data_in_leaf': 50, 'learning_rate': 1.5, 'num_boost_round': 718.8}
# Trying parameter combination 30 of 96: {'num_leaves': 5000, 'max_depth': 10, 'min_data_in_leaf': 50, 'learning_rate': 1.5} ...
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# Trying parameter combination 31 of 96: {'num_leaves': 50, 'max_depth': 50, 'min_data_in_leaf': 50, 'learning_rate': 1.5} ...
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# ...
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# Trying parameter combination 87 of 96: {'num_leaves': 5000, 'max_depth': 3, 'min_data_in_leaf': 100, 'learning_rate': 2.0} ...
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# Trying parameter combination 88 of 96: {'num_leaves': 50, 'max_depth': 10, 'min_data_in_leaf': 100, 'learning_rate': 2.0} ...
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# Trying parameter combination 89 of 96: {'num_leaves': 1000, 'max_depth': 10, 'min_data_in_leaf': 100, 'learning_rate': 2.0} ...
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# Trying parameter combination 90 of 96: {'num_leaves': 5000, 'max_depth': 10, 'min_data_in_leaf': 100, 'learning_rate': 2.0} ...
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# Trying parameter combination 91 of 96: {'num_leaves': 50, 'max_depth': 50, 'min_data_in_leaf': 100, 'learning_rate': 2.0} ...
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# Trying parameter combination 92 of 96: {'num_leaves': 1000, 'max_depth': 50, 'min_data_in_leaf': 100, 'learning_rate': 2.0} ...
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# Trying parameter combination 93 of 96: {'num_leaves': 5000, 'max_depth': 50, 'min_data_in_leaf': 100, 'learning_rate': 2.0} ...
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# Trying parameter combination 94 of 96: {'num_leaves': 50, 'max_depth': 100, 'min_data_in_leaf': 100, 'learning_rate': 2.0} ...
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# Trying parameter combination 95 of 96: {'num_leaves': 1000, 'max_depth': 100, 'min_data_in_leaf': 100, 'learning_rate': 2.0} ...
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# Trying parameter combination 96 of 96: {'num_leaves': 5000, 'max_depth': 100, 'min_data_in_leaf': 100, 'learning_rate': 2.0} ...
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found
# Best number of iterations:  967.2
# Best score:  25.146487926969264
# Best parameters:  {'num_leaves': 1000, 'max_depth': 50, 'min_data_in_leaf': 100, 'learning_rate': 1.5}

# %%
print('Best number of iterations: ', opt_params['best_iter'])
print('Best score: ', opt_params['best_score'])
print('Best parameters: ', opt_params['best_params'])
# Out:
# Best number of iterations:  967.2
# Best score:  25.146487926969264
# Best parameters:  {'num_leaves': 1000, 'max_depth': 50, 'min_data_in_leaf': 100, 'learning_rate': 1.5}

# %% [markdown]
# # Obtaining test set scores for the different models

# %%
train_X_features = train_X.drop(columns=['ID', 'times'])
test_extrapolation_X_features = test_extrapolation_X.drop(columns=['ID', 'times'])
test_interpolation_X_features = test_interpolation_X.drop(columns=['ID', 'times'])

train_X2_features = train_X2.drop(columns=['ID', 'times'])
test_extrapolation_X2_features = test_extrapolation_X2.drop(columns=['ID', 'times'])
test_interpolation_X2_features = test_interpolation_X2.drop(columns=['ID', 'times'])
train_X2_linear = np.column_stack((np.ones(len(train_X2_features)), train_X2_features))
test_extrapolation_X2_linear = np.column_stack((np.ones(len(test_extrapolation_X2_features)), test_extrapolation_X2_features))
test_interpolation_X2_linear = np.column_stack((np.ones(len(test_interpolation_X2_features)), test_interpolation_X2_features))

# %%
# Create results dataframe
results = pd.DataFrame(columns=['RMSE_interpolation', 'RMSE_extrapolation', 'Time'],
                       index=['Linear Mixed Effects Model with no fixed features (random intercept)',
                              'Linear Mixed Effects Model with Random Intercept',
                              'Linear Mixed Effects Model with Shared Gaussian Process',
                              'Linear Mixed Effects Model with Independent Gaussian Process',
                              'Gradient-boosted tree with group as categorical variable (no random effects)',
                              'GPBoost with Random Intercept',
                              'GPBoost with Shared Gaussian Process using Vecchia',
                              'GPBoost with Independent Gaussian Process'])

# %%
# 1. Linear Mixed Effects Model with no fixed features (random intercept)
np.random.seed(1)
model = gpb.GPModel(group_data=np.column_stack((train_X2['ID'], train_X2['times'])))
model.set_optim_params(params={'optimizer_cov': 'gradient_descent', 'lr_cov': 0.01, 'use_nesterov_acc': True})

start_time = time.time()
model.fit(y=train_y, X=np.ones(len(train_X2)))
results.loc['Linear Mixed Effects Model with no fixed features (random intercept)', 'Time'] = time.time() - start_time

y_pred_extrapolation = model.predict(group_data_pred=np.column_stack((test_extrapolation_X2['ID'], test_extrapolation_X2['times'])),
                                     X_pred=np.ones(len(test_extrapolation_X2)))
results.loc['Linear Mixed Effects Model with no fixed features (random intercept)', 'RMSE_extrapolation'] = np.sqrt(np.mean((test_extrapolation_y-y_pred_extrapolation['mu'])**2))

y_pred_interpolation = model.predict(group_data_pred=np.column_stack((test_interpolation_X2['ID'], test_interpolation_X2['times'])),
                                     X_pred=np.ones(len(test_interpolation_X2)))
results.loc['Linear Mixed Effects Model with no fixed features (random intercept)', 'RMSE_interpolation'] = np.sqrt(np.mean((test_interpolation_y-y_pred_interpolation['mu'])**2))

# %%
# 2. Linear Mixed Effects Model with Random Intercept
np.random.seed(1)
model = gpb.GPModel(group_data=np.column_stack((train_X2['ID'], train_X2['times'])))
model.set_optim_params(params={'optimizer_cov': 'gradient_descent', 'lr_cov': 0.01, 'use_nesterov_acc': True})

start_time = time.time()
model.fit(y=train_y, X=train_X2_linear)
results.loc['Linear Mixed Effects Model with Random Intercept', 'Time'] = time.time() - start_time

y_pred_extrapolation = model.predict(group_data_pred=np.column_stack((test_extrapolation_X2['ID'], test_extrapolation_X2['times'])),
                                     X_pred=test_extrapolation_X2_linear)
results.loc['Linear Mixed Effects Model with Random Intercept', 'RMSE_extrapolation'] = np.sqrt(np.mean((test_extrapolation_y-y_pred_extrapolation['mu'])**2))

y_pred_interpolation = model.predict(group_data_pred=np.column_stack((test_interpolation_X2['ID'], test_interpolation_X2['times'])),
                                     X_pred=test_interpolation_X2_linear)
results.loc['Linear Mixed Effects Model with Random Intercept', 'RMSE_interpolation'] = np.sqrt(np.mean((test_interpolation_y-y_pred_interpolation['mu'])**2))

# %%
# 3. Linear Mixed Effects Model with Shared Gaussian Process
np.random.seed(1)
model = gpb.GPModel(group_data=train_X2['ID'], gp_coords=train_X2['times'], cov_function='exponential')
model.set_optim_params(params={'optimizer_cov': 'fisher_scoring'})

start_time = time.time()
model.fit(y=train_y, X=train_X2_linear)
results.loc['Linear Mixed Effects Model with Shared Gaussian Process', 'Time'] = time.time() - start_time

y_pred_extrapolation = model.predict(group_data_pred=test_extrapolation_X2['ID'],
                                     gp_coords_pred=test_extrapolation_X2['times'],
                                     X_pred=test_extrapolation_X2_linear)
results.loc['Linear Mixed Effects Model with Shared Gaussian Process', 'RMSE_extrapolation'] = np.sqrt(np.mean((test_extrapolation_y-y_pred_extrapolation['mu'])**2))

y_pred_interpolation = model.predict(group_data_pred=test_interpolation_X2['ID'],
                                     gp_coords_pred=test_interpolation_X2['times'],
                                     X_pred=test_interpolation_X2_linear)
results.loc['Linear Mixed Effects Model with Shared Gaussian Process', 'RMSE_interpolation'] = np.sqrt(np.mean((test_interpolation_y-y_pred_interpolation['mu'])**2))

# %%
# 4. Linear Mixed Effects Model with Independent Gaussian Process
np.random.seed(1)
model = gpb.GPModel(group_data=train_X2['ID'], gp_coords=train_X2['times'], cluster_ids=train_X2['ID'].values.astype(int), cov_function='exponential')
model.set_optim_params(params={'optimizer_cov': 'gradient_descent', 'lr_cov': 0.01, 'use_nesterov_acc': True})

start_time = time.time()
model.fit(y=train_y, X=train_X2_linear)
results.loc['Linear Mixed Effects Model with Independent Gaussian Process', 'Time'] = time.time() - start_time

y_pred_extrapolation = model.predict(group_data_pred=test_extrapolation_X2['ID'],
                                     gp_coords_pred=test_extrapolation_X2['times'],
                                     cluster_ids_pred=test_extrapolation_X2['ID'].values.astype(int),
                                     X_pred=test_extrapolation_X2_linear)
results.loc['Linear Mixed Effects Model with Independent Gaussian Process', 'RMSE_extrapolation'] = np.sqrt(np.mean((test_extrapolation_y-y_pred_extrapolation['mu'])**2))

y_pred_interpolation = model.predict(group_data_pred=test_interpolation_X2['ID'],
                                     gp_coords_pred=test_interpolation_X2['times'],
                                     cluster_ids_pred=test_interpolation_X2['ID'].values.astype(int),
                                     X_pred=test_interpolation_X2_linear)
results.loc['Linear Mixed Effects Model with Independent Gaussian Process', 'RMSE_interpolation'] = np.sqrt(np.mean((test_interpolation_y-y_pred_interpolation['mu'])**2))

# %%
# 5. CatBoost
np.random.seed(1)
params = {'objective': 'regression_l2',
          'learning_rate': 1.5,
          'max_depth': 3,
          'min_data_in_leaf': 150,
          'num_leaves': 1000,
          'verbose': 0}

start_time = time.time()
bst = gpb.train(params=params,
                train_set=data_train_full_gpb_cat,
                gp_model=None,
                num_boost_round=30, 
                categorical_feature=['ID'])

results.loc['Gradient-boosted tree with group as categorical variable (no random effects)', 'Time'] = time.time() - start_time
y_pred_extrapolation = bst.predict(data=test_extrapolation_X)
results.loc['Gradient-boosted tree with group as categorical variable (no random effects)', 'RMSE_extrapolation'] = np.sqrt(np.mean((test_extrapolation_y-y_pred_extrapolation)**2))


y_pred_interpolation = bst.predict(data=test_interpolation_X)
results.loc['Gradient-boosted tree with group as categorical variable (no random effects)', 'RMSE_interpolation'] = np.sqrt(np.mean((test_interpolation_y-y_pred_interpolation)**2))

# %%
# 6. GPBoost with Random Intercept
np.random.seed(1)
gp_model = gpb.GPModel(group_data=np.column_stack((train_X['ID'], train_X['times'])))
gp_model.set_optim_params(params={'optimizer_cov': 'gradient_descent', 'use_nesterov_acc': True})
params = {'objective': 'regression_l2',
          'learning_rate': 1.5,
          'max_depth': 5,
          'min_data_in_leaf': 100,
          'verbose': 0}

start_time = time.time()
bst = gpb.train(params=params,
                train_set=data_train_full_gpb,
                gp_model=gp_model,
                num_boost_round=1007)
results.loc['GPBoost with Random Intercept', 'Time'] = time.time() - start_time

pred_extrapolation = bst.predict(data=test_extrapolation_X_features, group_data_pred=np.column_stack((test_extrapolation_X['ID'], test_extrapolation_X['times'])), pred_latent=True)
y_pred_extrapolation = pred_extrapolation['fixed_effect'] + pred_extrapolation['random_effect_mean']
results.loc['GPBoost with Random Intercept', 'RMSE_extrapolation'] = np.sqrt(np.mean((test_extrapolation_y-y_pred_extrapolation)**2))

pred_interpolation = bst.predict(data=test_interpolation_X_features, group_data_pred=np.column_stack((test_interpolation_X['ID'], test_interpolation_X['times'])), pred_latent=True)
y_pred_interpolation = pred_interpolation['fixed_effect'] + pred_interpolation['random_effect_mean']
results.loc['GPBoost with Random Intercept', 'RMSE_interpolation'] = np.sqrt(np.mean((test_interpolation_y-y_pred_interpolation)**2))

# %%
# 7. GPBoost with Shared Gaussian Process using Vecchia approximation
np.random.seed(1)

n_neighbors = 15
num_bst_round = 634
params = {'objective': 'regression_l2',
          'learning_rate': 2.0,
          'max_depth': 50,
          'min_data_in_leaf': 50,
          'verbose': 0}

gp_model = gpb.GPModel(gp_coords=train_X['times'], vecchia_approx=True, num_neighbors=n_neighbors, vecchia_ordering='random', 
                                                                    vecchia_pred_type='order_pred_first', num_neighbors_pred=n_neighbors)
gp_model.set_optim_params(params={'optimizer_cov': 'gradient_descent', 'use_nesterov_acc': True})


start_time = time.time()
bst = gpb.train(params=params,
                train_set=data_train_full_gpb,
                gp_model=gp_model,
                num_boost_round=num_bst_round)

results.loc['GPBoost with Shared Gaussian Process using Vecchia', 'Time'] = time.time() - start_time
pred_extrapolation = bst.predict(data=test_extrapolation_X_features,
                                 gp_coords_pred=test_extrapolation_X['times'], pred_latent=True)

y_pred_extrapolation = pred_extrapolation['fixed_effect'] + pred_extrapolation['random_effect_mean']
results.loc['GPBoost with Shared Gaussian Process using Vecchia', 'RMSE_extrapolation'] = np.sqrt(np.mean((test_extrapolation_y-y_pred_extrapolation)**2))

pred_interpolation = bst.predict(data=test_interpolation_X_features,
                                 gp_coords_pred=test_interpolation_X['times'], pred_latent=True)

y_pred_interpolation = pred_interpolation['fixed_effect'] + pred_interpolation['random_effect_mean']
results.loc['GPBoost with Shared Gaussian Process using Vecchia', 'RMSE_interpolation'] = np.sqrt(np.mean((test_interpolation_y-y_pred_interpolation)**2))
# Out:
# [GPBoost] [Info] Starting nearest neighbor search for Vecchia approximation
# [GPBoost] [Info] Nearest neighbors for Vecchia approximation found

# %%
# 8. GPBoost with Independent Gaussian Process
np.random.seed(1)
gp_model = gpb.GPModel(group_data=train_X['ID'], gp_coords=train_X['times'], cluster_ids=train_X['ID'].values.astype(int))
gp_model.set_optim_params(params={'optimizer_cov': 'gradient_descent', 'use_nesterov_acc': True})
params = {'objective': 'regression_l2',
          'learning_rate': 1.5,
          'max_depth': 10,
          'min_data_in_leaf': 120,
          'verbose': 0}

start_time = time.time()
bst = gpb.train(params=params,
                train_set=data_train_full_gpb,
                gp_model=gp_model,
                num_boost_round=1238)
results.loc['GPBoost with Independent Gaussian Process', 'Time'] = time.time() - start_time

pred_extrapolation = bst.predict(data=test_extrapolation_X_features,
                                 group_data_pred=test_extrapolation_X['ID'],
                                 gp_coords_pred=test_extrapolation_X['times'],
                                 cluster_ids_pred=test_extrapolation_X['ID'].values.astype(int), pred_latent=True)
y_pred_extrapolation = pred_extrapolation['fixed_effect'] + pred_extrapolation['random_effect_mean']
results.loc['GPBoost with Independent Gaussian Process', 'RMSE_extrapolation'] = np.sqrt(np.mean((test_extrapolation_y-y_pred_extrapolation)**2))

pred_interpolation = bst.predict(data=test_interpolation_X_features,
                                 group_data_pred=test_interpolation_X['ID'],
                                 gp_coords_pred=test_interpolation_X['times'],
                                 cluster_ids_pred=test_interpolation_X['ID'].values.astype(int), pred_latent=True)
y_pred_interpolation = pred_interpolation['fixed_effect'] + pred_interpolation['random_effect_mean']
results.loc['GPBoost with Independent Gaussian Process', 'RMSE_interpolation'] = np.sqrt(np.mean((test_interpolation_y-y_pred_interpolation)**2))

# %%
results
# Out:
#                                                    RMSE_interpolation  \
# Linear Mixed Effects Model with no fixed featur...          13.247823
# Linear Mixed Effects Model with Random Intercept            10.833203
# Linear Mixed Effects Model with Shared Gaussian...          10.827012
# Linear Mixed Effects Model with Independent Gau...           10.58029
# Gradient-boosted tree with group as categorical...          14.955562
# GPBoost with Random Intercept                               10.787687
# GPBoost with Shared Gaussian Process using Vecchia          13.933796
# GPBoost with Independent Gaussian Process                   10.613937
#
#                                                    RMSE_extrapolation  \
# Linear Mixed Effects Model with no fixed featur...          26.455168
# Linear Mixed Effects Model with Random Intercept             20.23939
# Linear Mixed Effects Model with Shared Gaussian...          19.978539
# Linear Mixed Effects Model with Independent Gau...          21.671387
# Gradient-boosted tree with group as categorical...          17.878521
# GPBoost with Random Intercept                               19.662098
# GPBoost with Shared Gaussian Process using Vecchia          17.693776
# GPBoost with Independent Gaussian Process                   19.775157
#
#                                                          Time
# Linear Mixed Effects Model with no fixed featur...   0.788998
# Linear Mixed Effects Model with Random Intercept     2.566871
# Linear Mixed Effects Model with Shared Gaussian...  77.074547
# Linear Mixed Effects Model with Independent Gau...   0.065443
# Gradient-boosted tree with group as categorical...   0.040436
# GPBoost with Random Intercept                       24.096764
# GPBoost with Shared Gaussian Process using Vecchia  46.124753
# GPBoost with Independent Gaussian Process           21.224172

# %% [markdown]
# ### Model interpratation

# %% [markdown]
# Let's now delve deeper into interpreting these models and try to understand how they work. In particular, we will focus on the GPBoost model with an independent gaussian process component since the Gradient Boosted tree part of the model offers feature importance functionality.

# %%
gp_model = gpb.GPModel(group_data=train_X['ID'], gp_coords=train_X['times'], cluster_ids=train_X['ID'].values.astype(int))
gp_model.set_optim_params(params={'optimizer_cov': 'gradient_descent', 'use_nesterov_acc': True})

params = {'objective': 'regression_l2',
          'learning_rate': 1.5,
          'max_depth': 10,
          'min_data_in_leaf': 120,
          'verbose': 0}

bst = gpb.train(params=params,
                train_set=data_train_full_gpb,
                gp_model=gp_model,
                num_boost_round=1238)

# Plotting feature importances
gpb.plot_importance(bst, figsize=(12, 5));

# %% [markdown]
# According to the above plot, blood urea nitrogen level ('bun') seems to be by far the most important feature in predicting eGFR values. Therefore, we will try to get a more intuitive understanding of their relationship using a partial dependence plot. In our case, a partial dependence plot shows the marginal effects of the feature 'bun' on the eGFR values. From the plot below, we can see that eGFR values decrease in a smooth non-linear trend with increasing bun levels, until the curve eventually flattens out at values of around 150. This is not suprising as it is a well known fact that high levels of urea in the blood could be a sign of reduced kidney functionality.

# %%
# Single variable plots (takes a few seconds to compute)
pdp_dist = pdp.pdp_isolate(model=bst, dataset=train_X_features,      
                           model_features=train_X_features.columns,
                           feature='bun', 
                           num_grid_points=50,
                           predict_kwds={"ignore_gp_model": True});

pdp.pdp_plot(pdp_dist, 'bun', plot_lines=False, figsize=(12, 8));

# %%
# Single variable plots (takes a few seconds to compute)
pdp_dist = pdp.pdp_isolate(model=bst, dataset=train_X_features,      
                           model_features=train_X_features.columns,
                           feature='age', 
                           num_grid_points=50,
                           predict_kwds={"ignore_gp_model": True});

pdp.pdp_plot(pdp_dist, 'age', plot_lines=False, figsize=(12, 8));

# %% [markdown]
# ## Stan analysis of the kernel hyperparameters of GPBoost with independent GPs

# %%
# 8. GPBoost with Independent Gaussian Process
np.random.seed(1)
gp_model = gpb.GPModel(group_data=train_X['ID'], gp_coords=train_X['times'], cluster_ids=train_X['ID'].values.astype(int))
gp_model.set_optim_params(params={'optimizer_cov': 'gradient_descent', 'use_nesterov_acc': True})
params = {'objective': 'regression_l2',
          'learning_rate': 1.5,
          'max_depth': 10,
          'min_data_in_leaf': 120,
          'verbose': 0}

start_time = time.time()
bst = gpb.train(params=params,
                train_set=data_train_full_gpb,
                gp_model=gp_model,
                num_boost_round=1238)

pred_training = bst.predict(data=train_X_features,
                                 group_data_pred=train_X['ID'],
                                 gp_coords_pred=train_X['times'],
                                 cluster_ids_pred=train_X['ID'].values.astype(int), pred_latent=True, predict_var=True)

y_pred_training = pred_training['fixed_effect'] + pred_training['random_effect_mean']

# %%
# Let's see the uncertainty in the predicted random effects; most predictions seem to have roughly similar levels of uncertainty 
pred_std = np.sqrt(pred_training['random_effect_cov'])
sns.kdeplot(pred_std);

# %%
gp_model.get_cov_pars()
# Out:
#         Error_term         ID      GP_var     GP_range
# Param.   22.274094  19.507333  332.627684  15685.93493

# %%
gp_code = """
// Fit a Gaussian process's hyperparameters
// for squared exponential prior

data {
  int<lower=1> N;
  vector[N] x;
  vector[N] y;
}
transformed data {
  vector[N] mu;
  for (i in 1:N) 
    mu[i] <- 0;

}
parameters {

  real<lower=10000> rho; // kernel lengthscale
  real<lower=0> sigma_sq; // kernel marginal variance
  
}
model {
  matrix[N, N] L_K;
  matrix[N,N] K;

  // off-diagonal elements
  for (i in 1:(N-1)) {
    for (j in (i+1):N) {
      K[i,j] <- sigma_sq * exp(- 1/rho * pow(x[i] - x[j],2));
      K[j,i] <- K[i,j];
    }
  }

  // diagonal elements
  for (k in 1:N)
    K[k,k] <- 0.25 + sigma_sq; // assume known error term variance is 0.25 (then K[k, k] = sigma_sq + error term variance)
  
  L_K = cholesky_decompose(K);
  
    // Sigma[k,k] <- eta_sq + sigma_sq; // + jitter

  
  rho ~ normal(20000, 5000);
  sigma_sq ~ normal(500, 100);

  y ~ multi_normal_cholesky(mu, L_K);
}
"""

# %%
# Obtain the posterior of the kernel hyperparameters using MCMC over a subset of the training data for computational reasons
np.random.seed(1)
subset_index = np.random.choice(a=len(train_y), size=1000, replace=False)
y_mcmc = train_y[subset_index] - pred_training['fixed_effect'][subset_index]
x_mcmc = train_X['times'][subset_index].values

gp_data = {'N': len(subset_index), 'y': y_mcmc, 'x': x_mcmc}

gp_fit = pystan.stan(model_code=gp_code, data=gp_data,
                  iter=1500, chains=2, warmup=300, n_jobs=-1, seed=1)

# Print a summary 
print(gp_fit.stansummary(pars=['rho', 'sigma_sq'], probs = (0.025, 0.975)))

# Let's visualize the posteriors
ax = az.plot_trace(gp_fit, var_names = ["rho", "sigma_sq"])
# Out:
# WARNING:pystan:DeprecationWarning: pystan.stan was deprecated in version 2.17 and will be removed in version 3.0. Compile and use a Stan program in separate steps.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_46f83442b54668f1f86b1a7e1a9c409e NOW.
# Inference for Stan model: anon_model_46f83442b54668f1f86b1a7e1a9c409e.
# 1 chains, each with iter=1500; warmup=300; thin=1;
# post-warmup draws per chain=1200, total post-warmup draws=1200.
#
#            mean se_mean     sd   2.5%  97.5%  n_eff   Rhat
# rho       1.0e4    0.02   0.67  1.0e4  1.0e4    781    1.0
# sigma_sq 3765.5    2.65  75.85 3616.3 3916.2    820    1.0
#
# Samples were drawn using NUTS at Sat Jul  2 18:09:10 2022.
# For each parameter, n_eff is a crude measure of effective sample size,
# and Rhat is the potential scale reduction factor on split chains (at
# convergence, Rhat=1).

# %% [markdown]
# ## Investigating if the learned hyperparameter posteriors could improve the learning process in GPBoost

# %% [markdown]
# Let's see how test set performance would be if one was to use a point estimate from the posterior instead of the learned parameters in GPBoost with individual GPs

# %%
np.random.seed(1)
rho_post_mean = gp_fit.to_dataframe()['rho'].mean()
sigma_sq_post_mean = gp_fit.to_dataframe()['sigma_sq'].mean()

gp_model = gpb.GPModel(group_data=train_X['ID'], gp_coords=train_X['times'], cluster_ids=train_X['ID'].values.astype(int))
gp_model.set_optim_params(params={'optimizer_cov': 'gradient_descent', 'use_nesterov_acc': True})

params = {'objective': 'regression_l2',
          'learning_rate': 1.5,
          'max_depth': 5,
          'min_data_in_leaf': 100,
          'verbose': 0}

bst = gpb.train(params=params,
                train_set=data_train_full_gpb,
                gp_model=gp_model,
                num_boost_round=1350,
                train_gp_model_cov_pars=True)

# Use posterior means for rho and sigma_sq during prediction time
gp_params = np.concatenate([gp_model.get_cov_pars().values[0][:2] , np.array([sigma_sq_post_mean, rho_post_mean])])


pred_interpolation = bst.predict(data=test_interpolation_X_features,
                                 group_data_pred=test_interpolation_X['ID'],
                                 gp_coords_pred=test_interpolation_X['times'],
                                 cluster_ids_pred=test_interpolation_X['ID'].values.astype(int), pred_latent=True)

y_pred_interpolation = pred_interpolation['fixed_effect'] + gp_model.predict(group_data_pred=test_interpolation_X['ID'], gp_coords_pred=test_interpolation_X['times'], 
                                                                                            predict_var=True, cov_pars=gp_params, cluster_ids_pred=test_interpolation_X['ID'].values.astype(int))['mu']

print(np.sqrt(np.mean((test_interpolation_y-y_pred_interpolation)**2)))

pred_extrapolation = bst.predict(data=test_extrapolation_X_features,
                                 group_data_pred=test_extrapolation_X['ID'],
                                 gp_coords_pred=test_extrapolation_X['times'],
                                 cluster_ids_pred=test_extrapolation_X['ID'].values.astype(int), pred_latent=True)

y_pred_extrapolation = pred_extrapolation['fixed_effect'] + gp_model.predict(group_data_pred=test_extrapolation_X['ID'], gp_coords_pred=test_extrapolation_X['times'], 
                                                                                            predict_var=True, cov_pars=gp_params, cluster_ids_pred=test_extrapolation_X['ID'].values.astype(int))['mu']

print(np.sqrt(np.mean((test_extrapolation_y-y_pred_extrapolation)**2)))
# Out:
# 10.736785053294106
# 19.645369728026925

# %%
results
# Out:
#                                                    RMSE_interpolation  \
# Linear Mixed Effects Model with no fixed featur...          13.247823
# Linear Mixed Effects Model with Random Intercept            10.833203
# Linear Mixed Effects Model with Shared Gaussian...          10.827012
# Linear Mixed Effects Model with Independent Gau...           10.58029
# Gradient-boosted tree with group as categorical...          14.955562
# GPBoost with Random Intercept                               10.787687
# GPBoost with Shared Gaussian Process using Vecchia          13.933796
# GPBoost with Independent Gaussian Process                   10.613937
#
#                                                    RMSE_extrapolation  \
# Linear Mixed Effects Model with no fixed featur...          26.455168
# Linear Mixed Effects Model with Random Intercept             20.23939
# Linear Mixed Effects Model with Shared Gaussian...          19.978539
# Linear Mixed Effects Model with Independent Gau...          21.671387
# Gradient-boosted tree with group as categorical...          17.878521
# GPBoost with Random Intercept                               19.662098
# GPBoost with Shared Gaussian Process using Vecchia          17.693776
# GPBoost with Independent Gaussian Process                   19.775157
#
#                                                          Time
# Linear Mixed Effects Model with no fixed featur...   0.788998
# Linear Mixed Effects Model with Random Intercept     2.566871
# Linear Mixed Effects Model with Shared Gaussian...  77.074547
# Linear Mixed Effects Model with Independent Gau...   0.065443
# Gradient-boosted tree with group as categorical...   0.040436
# GPBoost with Random Intercept                       24.096764
# GPBoost with Shared Gaussian Process using Vecchia  46.124753
# GPBoost with Independent Gaussian Process           21.224172

# %% [markdown]
# No improvement in performance really.

# %% [markdown]
# ## Let's also see what would happen if we were to use posterior point estimates as initialisation points in the optimization algorithm

# %%
# 8. GPBoost with Independent Gaussian Process
np.random.seed(1)
gp_model = gpb.GPModel(group_data=train_X['ID'], gp_coords=train_X['times'], cluster_ids=train_X['ID'].values.astype(int))
gp_model.set_optim_params(params={'optimizer_cov': 'gradient_descent', 'use_nesterov_acc': True, 'init_cov_pars':np.array([1, 1, sigma_sq_post_mean, rho_post_mean])})

params = {'objective': 'regression_l2',
          'learning_rate': 1.5,
          'max_depth': 5,
          'min_data_in_leaf': 100,
          'verbose': 0}

start_time = time.time()
bst = gpb.train(params=params,
                train_set=data_train_full_gpb,
                gp_model=gp_model,
                num_boost_round=1350,
                train_gp_model_cov_pars=True)

pred_interpolation = bst.predict(data=test_interpolation_X_features,
                                 group_data_pred=test_interpolation_X['ID'],
                                 gp_coords_pred=test_interpolation_X['times'],
                                 cluster_ids_pred=test_interpolation_X['ID'].values.astype(int), pred_latent=True)

y_pred_interpolation = pred_interpolation['fixed_effect'] + pred_interpolation['random_effect_mean']
print(np.sqrt(np.mean((test_interpolation_y-y_pred_interpolation)**2)))


pred_extrapolation = bst.predict(data=test_extrapolation_X_features,
                                 group_data_pred=test_extrapolation_X['ID'],
                                 gp_coords_pred=test_extrapolation_X['times'],
                                 cluster_ids_pred=test_extrapolation_X['ID'].values.astype(int), pred_latent=True)

y_pred_extrapolation = pred_extrapolation['fixed_effect'] + pred_extrapolation['random_effect_mean']
print(np.sqrt(np.mean((test_extrapolation_y-y_pred_extrapolation)**2)))
# Out:
# 10.47486492689509
# 19.621200838186148

# %%
# 8. GPBoost with Independent Gaussian Process
np.random.seed(1)
gp_model = gpb.GPModel(group_data=train_X['ID'], gp_coords=train_X['times'], cluster_ids=train_X['ID'].values.astype(int))
gp_model.set_optim_params(params={'optimizer_cov': 'gradient_descent', 'use_nesterov_acc': True, 'init_cov_pars':np.array([1, 1, sigma_sq_post_mean, rho_post_mean])})

params = {'objective': 'regression_l2',
          'learning_rate': 1.5,
          'max_depth': 5,
          'min_data_in_leaf': 100,
          'verbose': 0}

start_time = time.time()
bst = gpb.train(params=params,
                train_set=data_train_full_gpb,
                gp_model=gp_model,
                num_boost_round=1350,
                train_gp_model_cov_pars=True)

pred_interpolation = bst.predict(data=test_interpolation_X_features,
                                 group_data_pred=test_interpolation_X['ID'],
                                 gp_coords_pred=test_interpolation_X['times'],
                                 cluster_ids_pred=test_interpolation_X['ID'].values.astype(int), pred_latent=True)

y_pred_interpolation = pred_interpolation['fixed_effect'] + pred_interpolation['random_effect_mean']
print(np.sqrt(np.mean((test_interpolation_y-y_pred_interpolation)**2)))


pred_extrapolation = bst.predict(data=test_extrapolation_X_features,
                                 group_data_pred=test_extrapolation_X['ID'],
                                 gp_coords_pred=test_extrapolation_X['times'],
                                 cluster_ids_pred=test_extrapolation_X['ID'].values.astype(int), pred_latent=True)

y_pred_extrapolation = pred_extrapolation['fixed_effect'] + pred_extrapolation['random_effect_mean']
print(np.sqrt(np.mean((test_extrapolation_y-y_pred_extrapolation)**2)))
# Out:
# 10.474864928482154
# 19.621319154553902

# %%
results
# Out:
#                                                    RMSE_interpolation  \
# Linear Mixed Effects Model with no fixed featur...          13.247823
# Linear Mixed Effects Model with Random Intercept            10.833203
# Linear Mixed Effects Model with Shared Gaussian...          10.827012
# Linear Mixed Effects Model with Independent Gau...           10.58029
# Gradient-boosted tree with group as categorical...          14.955562
# GPBoost with Random Intercept                               10.787687
# GPBoost with Shared Gaussian Process using Vecchia          13.933796
# GPBoost with Independent Gaussian Process                   10.613937
#
#                                                    RMSE_extrapolation  \
# Linear Mixed Effects Model with no fixed featur...          26.455168
# Linear Mixed Effects Model with Random Intercept             20.23939
# Linear Mixed Effects Model with Shared Gaussian...          19.978539
# Linear Mixed Effects Model with Independent Gau...          21.671387
# Gradient-boosted tree with group as categorical...          17.878521
# GPBoost with Random Intercept                               19.662098
# GPBoost with Shared Gaussian Process using Vecchia          17.693776
# GPBoost with Independent Gaussian Process                   19.775157
#
#                                                          Time
# Linear Mixed Effects Model with no fixed featur...   0.788998
# Linear Mixed Effects Model with Random Intercept     2.566871
# Linear Mixed Effects Model with Shared Gaussian...  77.074547
# Linear Mixed Effects Model with Independent Gau...   0.065443
# Gradient-boosted tree with group as categorical...   0.040436
# GPBoost with Random Intercept                       24.096764
# GPBoost with Shared Gaussian Process using Vecchia  46.124753
# GPBoost with Independent Gaussian Process           21.224172

# %% [markdown]
# ### We can actually observe that using the posterior means as initialisation points in the optimization process improves performance on both the interpolation and extrapolation test sets.

# %% [markdown]
# ## Let's also visualize some of the individual GPs for specific groups with different numbers of test interpolation points

# %%
np.random.seed(1)
gp_model = gpb.GPModel(group_data=train_X['ID'], gp_coords=train_X['times'], cluster_ids=train_X['ID'].values.astype(int))
gp_model.set_optim_params(params={'optimizer_cov': 'gradient_descent', 'use_nesterov_acc': True})

params = {'objective': 'regression_l2',
          'learning_rate': 1.5,
          'max_depth': 10,
          'min_data_in_leaf': 120,
          'verbose': 0}

bst = gpb.train(params=params,
                train_set=data_train_full_gpb,
                gp_model=gp_model,
                num_boost_round=1238)

# %%
#for n in test_interpolation['ID'].value_counts(sort=False).index[test_interpolation['ID'].value_counts(sort=False).values == 4]:
    #get_indGP_plot(data_train_full, test_interpolation, bst, rho=15140, sigma2=335, sigma_n=3, group_no=n)

# %%
get_indGP_plot(data_train_full, test_interpolation, bst, rho=15140, sigma2=335, group_no=8)

# %%
get_indGP_plot(data_train_full, test_interpolation, bst, rho=15140, sigma2=335, group_no=148)

# %%
get_indGP_plot(data_train_full, test_interpolation, bst, rho=15140, sigma2=335, group_no=406)
