# %%
# !pip install GPBoost -U 
import os
import csv
from google.colab import drive 
drive.mount('/content/drive')
my_path = "/content/drive/My Drive/Thesis/simulations_new/full_data_setting"
os.chdir(my_path)

from simulation_utils import * 
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm
import statsmodels.formula.api as smf
import gpboost as gpb
#import pdpbox
#from pdpbox import pdp
sns.set()
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting GPBoost
#   Downloading gpboost-0.7.7-py3-none-manylinux1_x86_64.whl (3.0 MB)
#      |████████████████████████████████| 3.0 MB 656 kB/s
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from GPBoost) (1.4.1)
# Requirement already satisfied: wheel in /usr/local/lib/python3.7/dist-packages (from GPBoost) (0.37.1)
# Requirement already satisfied: scikit-learn!=0.22.0 in /usr/local/lib/python3.7/dist-packages (from GPBoost) (1.0.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from GPBoost) (1.21.6)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from GPBoost) (1.3.5)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn!=0.22.0->GPBoost) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn!=0.22.0->GPBoost) (3.1.0)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas->GPBoost) (2022.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->GPBoost) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas->GPBoost) (1.15.0)
# Installing collected packages: GPBoost
# Successfully installed GPBoost-0.7.7
# Mounted at /content/drive
# /usr/local/lib/python3.7/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %% [markdown]
# # Initial experiments - Full data setting (40 observations per group)

# %% [markdown]
# ## Non-linear function; Shared GP in data generating process

# %%
# Generate data
n, m = 2000, 50  # Number of observations and groups
p = int(n/m) # Number of observations per group
n_datasets = 20 
n_valid = 5
datasets, validation_datasets = generate_datasets(n, m, p, n_datasets, n_valid, func='make_friedman3', random_state=60, shared_gp=True)

# Create groups
groups = np.arange(n)
for i in range(m):
    groups[i*p:(i+1)*p] = i

# Create times for validation datasets
times = np.tile(np.arange(p)*10+10, m)

# %% [markdown]
# ## GPBoost hyperparameter tuning

# %% [markdown]
# ### Random Intercept model

# %%
# Random slope
gp_model = gpb.GPModel(group_data=np.column_stack((groups, times)))
# Candidate parameter grid
param_grid = {'learning_rate': [0.01, 0.1, 0.5, 1], 
              'max_depth': [1, 2, 3, 4, 5, 10, 50],
              'min_data_in_leaf': [1, 10, 20, 50]}

# Other parameters not contained in the grid of tuning parameters
params = {'objective': 'regression_l2',
          'verbose': 0,
          'num_leaves': 2**10}

opt_params = grid_search_tune_parameters_multiple(param_grid=param_grid,
                                                  params=params,
                                                  nfold=5,
                                                  gp_model=gp_model,
                                                  use_gp_model_for_validation=True,
                                                  train_sets=validation_datasets['data_train'],
                                                  verbose_eval=0,
                                                  num_boost_round=400, 
                                                  early_stopping_rounds=10,
                                                  shuffle=False,
                                                  seed=1,
                                                  metrics='rmse')

print('Best number of iterations: ', opt_params['best_iter'])
print('Best score: ', opt_params['best_score'])
print('Best parameters: ', opt_params['best_params'])
# Out:
# Starting deterministic grid search with 112 parameter combinations...
#
#
#  |--------------------------------------------------| 0.8929%
#
#
#
#  |█-------------------------------------------------| 1.7857%
#
#
#
#  |█-------------------------------------------------| 2.6786%
#
#
#
#  |██------------------------------------------------| 3.5714%
#
#
#
#  |██------------------------------------------------| 4.4643%
#
#
#
#  |███-----------------------------------------------| 5.3571%
#
#
#
#  |███-----------------------------------------------| 6.2500%
#
#
#
#  |████----------------------------------------------| 7.1429%
#
#
#
#  |████----------------------------------------------| 8.0357%
#
#
#
#  |████----------------------------------------------| 8.9286%
#
#
#
#  |█████---------------------------------------------| 9.8214%
#
#
#
#  |█████---------------------------------------------| 10.7143%
#
#
#
#  |██████--------------------------------------------| 11.6071%
#
#
#
#  |██████--------------------------------------------| 12.5000%
#
#
#
#  |███████-------------------------------------------| 13.3929%
#
#
#
#  |███████-------------------------------------------| 14.2857%
#
#
#
#  |████████------------------------------------------| 15.1786%
#
#
#
#  |████████------------------------------------------| 16.0714%
#
#
#
#  |████████------------------------------------------| 16.9643%
#
#
#
#  |█████████-----------------------------------------| 17.8571%
#
#
#
#  |█████████-----------------------------------------| 18.7500%
#
#
#
#  |██████████----------------------------------------| 19.6429%
#
#
#
#  |██████████----------------------------------------| 20.5357%
#
#
#
#  |███████████---------------------------------------| 21.4286%
#
#
#
#  |███████████---------------------------------------| 22.3214%
#
#
#
#  |████████████--------------------------------------| 23.2143%
#
# [GPBoost] [Warning] NaN or Inf occurred in covariance parameter optimization using 'gradient_descent'. The optimization will be started a second time using 'nelder_mead'. If you want to avoid this, try directly using a different optimizer. If you have used 'gradient_descent', you can also consider using a smaller learning rate. The following optimizers are currently implemented: 'adam' 'bfgs' 'fisher_scoring' 'gradient_descent' 'nelder_mead'
# [GPBoost] [Warning] NaN or Inf occurred in covariance parameter optimization using 'gradient_descent'. The optimization will be started a second time using 'nelder_mead'. If you want to avoid this, try directly using a different optimizer. If you have used 'gradient_descent', you can also consider using a smaller learning rate. The following optimizers are currently implemented: 'adam' 'bfgs' 'fisher_scoring' 'gradient_descent' 'nelder_mead'
# [GPBoost] [Warning] NaN or Inf occurred in covariance parameter optimization using 'gradient_descent'. The optimization will be started a second time using 'nelder_mead'. If you want to avoid this, try directly using a different optimizer. If you have used 'gradient_descent', you can also consider using a smaller learning rate. The following optimizers are currently implemented: 'adam' 'bfgs' 'fisher_scoring' 'gradient_descent' 'nelder_mead'
# [GPBoost] [Warning] NaN or Inf occurred in covariance parameter optimization using 'gradient_descent'. The optimization will be started a second time using 'nelder_mead'. If you want to avoid this, try directly using a different optimizer. If you have used 'gradient_descent', you can also consider using a smaller learning rate. The following optimizers are currently implemented: 'adam' 'bfgs' 'fisher_scoring' 'gradient_descent' 'nelder_mead'
# [GPBoost] [Warning] NaN or Inf occurred in covariance parameter optimization using 'gradient_descent'. The optimization will be started a second time using 'nelder_mead'. If you want to avoid this, try directly using a different optimizer. If you have used 'gradient_descent', you can also consider using a smaller learning rate. The following optimizers are currently implemented: 'adam' 'bfgs' 'fisher_scoring' 'gradient_descent' 'nelder_mead'
#
#
#  |████████████--------------------------------------| 24.1071%
#
# [GPBoost] [Warning] NaN or Inf occurred in covariance parameter optimization using 'gradient_descent'. The optimization will be started a second time using 'nelder_mead'. If you want to avoid this, try directly using a different optimizer. If you have used 'gradient_descent', you can also consider using a smaller learning rate. The following optimizers are currently implemented: 'adam' 'bfgs' 'fisher_scoring' 'gradient_descent' 'nelder_mead'
# [GPBoost] [Warning] NaN or Inf occurred in covariance parameter optimization using 'gradient_descent'. The optimization will be started a second time using 'nelder_mead'. If you want to avoid this, try directly using a different optimizer. If you have used 'gradient_descent', you can also consider using a smaller learning rate. The following optimizers are currently implemented: 'adam' 'bfgs' 'fisher_scoring' 'gradient_descent' 'nelder_mead'
# [GPBoost] [Warning] NaN or Inf occurred in covariance parameter optimization using 'gradient_descent'. The optimization will be started a second time using 'nelder_mead'. If you want to avoid this, try directly using a different optimizer. If you have used 'gradient_descent', you can also consider using a smaller learning rate. The following optimizers are currently implemented: 'adam' 'bfgs' 'fisher_scoring' 'gradient_descent' 'nelder_mead'
#
#
#  |████████████--------------------------------------| 25.0000%
#
# [GPBoost] [Warning] NaN or Inf occurred in covariance parameter optimization using 'gradient_descent'. The optimization will be started a second time using 'nelder_mead'. If you want to avoid this, try directly using a different optimizer. If you have used 'gradient_descent', you can also consider using a smaller learning rate. The following optimizers are currently implemented: 'adam' 'bfgs' 'fisher_scoring' 'gradient_descent' 'nelder_mead'
#
#
#  |█████████████-------------------------------------| 25.8929%
#
#
#
#  |█████████████-------------------------------------| 26.7857%
#
#
#
#  |██████████████------------------------------------| 27.6786%
#
#
#
#  |██████████████------------------------------------| 28.5714%
#
#
#
#  |███████████████-----------------------------------| 29.4643%
#
#
#
#  |███████████████-----------------------------------| 30.3571%
#
#
#
#  |████████████████----------------------------------| 31.2500%
#
#
#
#  |████████████████----------------------------------| 32.1429%
#
#
#
#  |█████████████████---------------------------------| 33.0357%
#
#
#
#  |█████████████████---------------------------------| 33.9286%
#
#
#
#  |█████████████████---------------------------------| 34.8214%
#
#
#
#  |██████████████████--------------------------------| 35.7143%
#
#
#
#  |██████████████████--------------------------------| 36.6071%
#
#
#
#  |███████████████████-------------------------------| 37.5000%
#
#
#
#  |███████████████████-------------------------------| 38.3929%
#
#
#
#  |████████████████████------------------------------| 39.2857%
#
#
#
#  |████████████████████------------------------------| 40.1786%
#
#
#
#  |█████████████████████-----------------------------| 41.0714%
#
#
#
#  |█████████████████████-----------------------------| 41.9643%
#
#
#
#  |█████████████████████-----------------------------| 42.8571%
#
#
#
#  |██████████████████████----------------------------| 43.7500%
#
#
#
#  |██████████████████████----------------------------| 44.6429%
#
#
#
#  |███████████████████████---------------------------| 45.5357%
#
#
#
#  |███████████████████████---------------------------| 46.4286%
#
#
#
#  |████████████████████████--------------------------| 47.3214%
#
#
#
#  |████████████████████████--------------------------| 48.2143%
#
#
#
#  |█████████████████████████-------------------------| 49.1071%
#
#
#
#  |█████████████████████████-------------------------| 50.0000%
#
#
#
#  |█████████████████████████-------------------------| 50.8929%
#
#
#
#  |██████████████████████████------------------------| 51.7857%
#
#
#
#  |██████████████████████████------------------------| 52.6786%
#
#
#
#  |███████████████████████████-----------------------| 53.5714%
#
#
#
#  |███████████████████████████-----------------------| 54.4643%
#
#
#
#  |████████████████████████████----------------------| 55.3571%
#
#
#
#  |████████████████████████████----------------------| 56.2500%
#
#
#
#  |█████████████████████████████---------------------| 57.1429%
#
#
#
#  |█████████████████████████████---------------------| 58.0357%
#
#
#
#  |█████████████████████████████---------------------| 58.9286%
#
#
#
#  |██████████████████████████████--------------------| 59.8214%
#
#
#
#  |██████████████████████████████--------------------| 60.7143%
#
#
#
#  |███████████████████████████████-------------------| 61.6071%
#
#
#
#  |███████████████████████████████-------------------| 62.5000%
#
#
#
#  |████████████████████████████████------------------| 63.3929%
#
#
#
#  |████████████████████████████████------------------| 64.2857%
#
#
#
#  |█████████████████████████████████-----------------| 65.1786%
#
#
#
#  |█████████████████████████████████-----------------| 66.0714%
#
#
#
#  |█████████████████████████████████-----------------| 66.9643%
#
#
#
#  |██████████████████████████████████----------------| 67.8571%
#
#
#
#  |██████████████████████████████████----------------| 68.7500%
#
#
#
#  |███████████████████████████████████---------------| 69.6429%
#
#
#
#  |███████████████████████████████████---------------| 70.5357%
#
#
#
#  |████████████████████████████████████--------------| 71.4286%
#
#
#
#  |████████████████████████████████████--------------| 72.3214%
#
#
#
#  |█████████████████████████████████████-------------| 73.2143%
#
#
#
#  |█████████████████████████████████████-------------| 74.1071%
#
#
#
#  |██████████████████████████████████████------------| 75.0000%
#
#
#
#  |██████████████████████████████████████------------| 75.8929%
#
#
#
#  |██████████████████████████████████████------------| 76.7857%
#
#
#
#  |███████████████████████████████████████-----------| 77.6786%
#
#
#
#  |███████████████████████████████████████-----------| 78.5714%
#
#
#
#  |████████████████████████████████████████----------| 79.4643%
#
#
#
#  |████████████████████████████████████████----------| 80.3571%
#
#
#
#  |█████████████████████████████████████████---------| 81.2500%
#
#
#
#  |█████████████████████████████████████████---------| 82.1429%
#
#
#
#  |██████████████████████████████████████████--------| 83.0357%
#
#
#
#  |██████████████████████████████████████████--------| 83.9286%
#
#
#
#  |██████████████████████████████████████████--------| 84.8214%
#
#
#
#  |███████████████████████████████████████████-------| 85.7143%
#
#
#
#  |███████████████████████████████████████████-------| 86.6071%
#
#
#
#  |████████████████████████████████████████████------| 87.5000%
#
#
#
#  |████████████████████████████████████████████------| 88.3929%
#
#
#
#  |█████████████████████████████████████████████-----| 89.2857%
#
#
#
#  |█████████████████████████████████████████████-----| 90.1786%
#
#
#
#  |██████████████████████████████████████████████----| 91.0714%
#
#
#
#  |██████████████████████████████████████████████----| 91.9643%
#
#
#
#  |██████████████████████████████████████████████----| 92.8571%
#
#
#
#  |███████████████████████████████████████████████---| 93.7500%
#
#
#
#  |███████████████████████████████████████████████---| 94.6429%
#
#
#
#  |████████████████████████████████████████████████--| 95.5357%
#
#
#
#  |████████████████████████████████████████████████--| 96.4286%
#
#
#
#  |█████████████████████████████████████████████████-| 97.3214%
#
#
#
#  |█████████████████████████████████████████████████-| 98.2143%
#
#
#
#  |██████████████████████████████████████████████████| 99.1071%
#
#
#
#  |██████████████████████████████████████████████████| 100.0000%
#
#
# Best number of iterations:  50.2
# Best score:  1.5351070427455524
# Best parameters:  {'learning_rate': 0.1, 'max_depth': 4, 'min_data_in_leaf': 20}

# %% [markdown]
# ### GPBoost with independent GPs

# %%
# Independent GP
gp_model = gpb.GPModel(group_data=groups, gp_coords=times, cluster_ids=groups, cov_function='exponential', cov_fct_shape=2.5)

# Candidate parameter grid
param_grid = {'learning_rate': [0.01, 0.1, 0.5, 1], 
              'max_depth': [1, 2, 3, 4, 5, 10, 50],
              'min_data_in_leaf': [1, 10, 20, 50]}

# Other parameters not contained in the grid of tuning parameters
params = {'objective': 'regression_l2',
          'verbose': 0,
          'num_leaves': 2**10}

opt_params = grid_search_tune_parameters_multiple(param_grid=param_grid,
                                                  params=params,
                                                  nfold=5,
                                                  gp_model=gp_model,
                                                  use_gp_model_for_validation=True,
                                                  train_sets=validation_datasets['data_train'],
                                                  verbose_eval=1,
                                                  num_boost_round=400, 
                                                  early_stopping_rounds=10,
                                                  shuffle=False,
                                                  seed=1,
                                                  metrics='rmse')
                                                  
print('Best number of iterations: ', opt_params['best_iter'])
print('Best score: ', opt_params['best_score'])
print('Best parameters: ', opt_params['best_params'])
# Out:
# Starting deterministic grid search with 112 parameter combinations...
#
#
#  |--------------------------------------------------| 0.8929%
#
# Trying parameter combination 1 of 112: {'learning_rate': 0.01, 'max_depth': 1, 'min_data_in_leaf': 1} ...
# ***** New best score (1.921168581642359) found for the following parameter combination:
# {'learning_rate': 0.01, 'max_depth': 1, 'min_data_in_leaf': 1, 'num_boost_round': 399.0}
#
#
#  |█-------------------------------------------------| 1.7857%
#
# Trying parameter combination 2 of 112: {'learning_rate': 0.1, 'max_depth': 1, 'min_data_in_leaf': 1} ...
# ***** New best score (1.8425603326264028) found for the following parameter combination:
# {'learning_rate': 0.1, 'max_depth': 1, 'min_data_in_leaf': 1, 'num_boost_round': 209.4}
#
#
#  |█-------------------------------------------------| 2.6786%
#
# Trying parameter combination 3 of 112: {'learning_rate': 0.5, 'max_depth': 1, 'min_data_in_leaf': 1} ...
# ***** New best score (1.8420639022187326) found for the following parameter combination:
# {'learning_rate': 0.5, 'max_depth': 1, 'min_data_in_leaf': 1, 'num_boost_round': 43.2}
#
#
#  |██------------------------------------------------| 3.5714%
#
# Trying parameter combination 4 of 112: {'learning_rate': 1.0, 'max_depth': 1, 'min_data_in_leaf': 1} ...
#
#
#  |██------------------------------------------------| 4.4643%
#
# Trying parameter combination 5 of 112: {'learning_rate': 0.01, 'max_depth': 2, 'min_data_in_leaf': 1} ...
#
#
#  |███-----------------------------------------------| 5.3571%
#
# Trying parameter combination 6 of 112: {'learning_rate': 0.1, 'max_depth': 2, 'min_data_in_leaf': 1} ...
# ***** New best score (1.8217113063658001) found for the following parameter combination:
# {'learning_rate': 0.1, 'max_depth': 2, 'min_data_in_leaf': 1, 'num_boost_round': 106.8}
#
#
#  |███-----------------------------------------------| 6.2500%
#
# Trying parameter combination 7 of 112: {'learning_rate': 0.5, 'max_depth': 2, 'min_data_in_leaf': 1} ...
#
#
#  |████----------------------------------------------| 7.1429%
#
# Trying parameter combination 8 of 112: {'learning_rate': 1.0, 'max_depth': 2, 'min_data_in_leaf': 1} ...
#
#
#  |████----------------------------------------------| 8.0357%
#
# Trying parameter combination 9 of 112: {'learning_rate': 0.01, 'max_depth': 3, 'min_data_in_leaf': 1} ...
#
#
#  |████----------------------------------------------| 8.9286%
#
# Trying parameter combination 10 of 112: {'learning_rate': 0.1, 'max_depth': 3, 'min_data_in_leaf': 1} ...
# ***** New best score (1.818420099809428) found for the following parameter combination:
# {'learning_rate': 0.1, 'max_depth': 3, 'min_data_in_leaf': 1, 'num_boost_round': 58.0}
#
#
#  |█████---------------------------------------------| 9.8214%
#
# Trying parameter combination 11 of 112: {'learning_rate': 0.5, 'max_depth': 3, 'min_data_in_leaf': 1} ...
#
#
#  |█████---------------------------------------------| 10.7143%
#
# Trying parameter combination 12 of 112: {'learning_rate': 1.0, 'max_depth': 3, 'min_data_in_leaf': 1} ...
#
#
#  |██████--------------------------------------------| 11.6071%
#
# Trying parameter combination 13 of 112: {'learning_rate': 0.01, 'max_depth': 4, 'min_data_in_leaf': 1} ...
#
#
#  |██████--------------------------------------------| 12.5000%
#
# Trying parameter combination 14 of 112: {'learning_rate': 0.1, 'max_depth': 4, 'min_data_in_leaf': 1} ...
#
#
#  |███████-------------------------------------------| 13.3929%
#
# Trying parameter combination 15 of 112: {'learning_rate': 0.5, 'max_depth': 4, 'min_data_in_leaf': 1} ...
#
#
#  |███████-------------------------------------------| 14.2857%
#
# Trying parameter combination 16 of 112: {'learning_rate': 1.0, 'max_depth': 4, 'min_data_in_leaf': 1} ...
#
#
#  |████████------------------------------------------| 15.1786%
#
# Trying parameter combination 17 of 112: {'learning_rate': 0.01, 'max_depth': 5, 'min_data_in_leaf': 1} ...
#
#
#  |████████------------------------------------------| 16.0714%
#
# Trying parameter combination 18 of 112: {'learning_rate': 0.1, 'max_depth': 5, 'min_data_in_leaf': 1} ...
#
#
#  |████████------------------------------------------| 16.9643%
#
# Trying parameter combination 19 of 112: {'learning_rate': 0.5, 'max_depth': 5, 'min_data_in_leaf': 1} ...
#
#
#  |█████████-----------------------------------------| 17.8571%
#
# Trying parameter combination 20 of 112: {'learning_rate': 1.0, 'max_depth': 5, 'min_data_in_leaf': 1} ...
#
#
#  |█████████-----------------------------------------| 18.7500%
#
# Trying parameter combination 21 of 112: {'learning_rate': 0.01, 'max_depth': 10, 'min_data_in_leaf': 1} ...
#
#
#  |██████████----------------------------------------| 19.6429%
#
# Trying parameter combination 22 of 112: {'learning_rate': 0.1, 'max_depth': 10, 'min_data_in_leaf': 1} ...
#
#
#  |██████████----------------------------------------| 20.5357%
#
# Trying parameter combination 23 of 112: {'learning_rate': 0.5, 'max_depth': 10, 'min_data_in_leaf': 1} ...
#
#
#  |███████████---------------------------------------| 21.4286%
#
# Trying parameter combination 24 of 112: {'learning_rate': 1.0, 'max_depth': 10, 'min_data_in_leaf': 1} ...
#
#
#  |███████████---------------------------------------| 22.3214%
#
# Trying parameter combination 25 of 112: {'learning_rate': 0.01, 'max_depth': 50, 'min_data_in_leaf': 1} ...
#
#
#  |████████████--------------------------------------| 23.2143%
#
# Trying parameter combination 26 of 112: {'learning_rate': 0.1, 'max_depth': 50, 'min_data_in_leaf': 1} ...
#
#
#  |████████████--------------------------------------| 24.1071%
#
# Trying parameter combination 27 of 112: {'learning_rate': 0.5, 'max_depth': 50, 'min_data_in_leaf': 1} ...
#
#
#  |████████████--------------------------------------| 25.0000%
#
# Trying parameter combination 28 of 112: {'learning_rate': 1.0, 'max_depth': 50, 'min_data_in_leaf': 1} ...
#
#
#  |█████████████-------------------------------------| 25.8929%
#
# Trying parameter combination 29 of 112: {'learning_rate': 0.01, 'max_depth': 1, 'min_data_in_leaf': 10} ...
#
#
#  |█████████████-------------------------------------| 26.7857%
#
# Trying parameter combination 30 of 112: {'learning_rate': 0.1, 'max_depth': 1, 'min_data_in_leaf': 10} ...
#
#
#  |██████████████------------------------------------| 27.6786%
#
# Trying parameter combination 31 of 112: {'learning_rate': 0.5, 'max_depth': 1, 'min_data_in_leaf': 10} ...
#
#
#  |██████████████------------------------------------| 28.5714%
#
# Trying parameter combination 32 of 112: {'learning_rate': 1.0, 'max_depth': 1, 'min_data_in_leaf': 10} ...
#
#
#  |███████████████-----------------------------------| 29.4643%
#
# Trying parameter combination 33 of 112: {'learning_rate': 0.01, 'max_depth': 2, 'min_data_in_leaf': 10} ...
#
#
#  |███████████████-----------------------------------| 30.3571%
#
# Trying parameter combination 34 of 112: {'learning_rate': 0.1, 'max_depth': 2, 'min_data_in_leaf': 10} ...
#
#
#  |████████████████----------------------------------| 31.2500%
#
# Trying parameter combination 35 of 112: {'learning_rate': 0.5, 'max_depth': 2, 'min_data_in_leaf': 10} ...
#
#
#  |████████████████----------------------------------| 32.1429%
#
# Trying parameter combination 36 of 112: {'learning_rate': 1.0, 'max_depth': 2, 'min_data_in_leaf': 10} ...
#
#
#  |█████████████████---------------------------------| 33.0357%
#
# Trying parameter combination 37 of 112: {'learning_rate': 0.01, 'max_depth': 3, 'min_data_in_leaf': 10} ...
#
#
#  |█████████████████---------------------------------| 33.9286%
#
# Trying parameter combination 38 of 112: {'learning_rate': 0.1, 'max_depth': 3, 'min_data_in_leaf': 10} ...
#
#
#  |█████████████████---------------------------------| 34.8214%
#
# Trying parameter combination 39 of 112: {'learning_rate': 0.5, 'max_depth': 3, 'min_data_in_leaf': 10} ...
#
#
#  |██████████████████--------------------------------| 35.7143%
#
# Trying parameter combination 40 of 112: {'learning_rate': 1.0, 'max_depth': 3, 'min_data_in_leaf': 10} ...
#
#
#  |██████████████████--------------------------------| 36.6071%
#
# Trying parameter combination 41 of 112: {'learning_rate': 0.01, 'max_depth': 4, 'min_data_in_leaf': 10} ...
#
#
#  |███████████████████-------------------------------| 37.5000%
#
# Trying parameter combination 42 of 112: {'learning_rate': 0.1, 'max_depth': 4, 'min_data_in_leaf': 10} ...
# ***** New best score (1.8175780912904318) found for the following parameter combination:
# {'learning_rate': 0.1, 'max_depth': 4, 'min_data_in_leaf': 10, 'num_boost_round': 49.8}
#
#
#  |███████████████████-------------------------------| 38.3929%
#
# Trying parameter combination 43 of 112: {'learning_rate': 0.5, 'max_depth': 4, 'min_data_in_leaf': 10} ...
#
#
#  |████████████████████------------------------------| 39.2857%
#
# Trying parameter combination 44 of 112: {'learning_rate': 1.0, 'max_depth': 4, 'min_data_in_leaf': 10} ...
#
#
#  |████████████████████------------------------------| 40.1786%
#
# Trying parameter combination 45 of 112: {'learning_rate': 0.01, 'max_depth': 5, 'min_data_in_leaf': 10} ...
#
#
#  |█████████████████████-----------------------------| 41.0714%
#
# Trying parameter combination 46 of 112: {'learning_rate': 0.1, 'max_depth': 5, 'min_data_in_leaf': 10} ...
#
#
#  |█████████████████████-----------------------------| 41.9643%
#
# Trying parameter combination 47 of 112: {'learning_rate': 0.5, 'max_depth': 5, 'min_data_in_leaf': 10} ...
#
#
#  |█████████████████████-----------------------------| 42.8571%
#
# Trying parameter combination 48 of 112: {'learning_rate': 1.0, 'max_depth': 5, 'min_data_in_leaf': 10} ...
#
#
#  |██████████████████████----------------------------| 43.7500%
#
# Trying parameter combination 49 of 112: {'learning_rate': 0.01, 'max_depth': 10, 'min_data_in_leaf': 10} ...
#
#
#  |██████████████████████----------------------------| 44.6429%
#
# Trying parameter combination 50 of 112: {'learning_rate': 0.1, 'max_depth': 10, 'min_data_in_leaf': 10} ...
#
#
#  |███████████████████████---------------------------| 45.5357%
#
# Trying parameter combination 51 of 112: {'learning_rate': 0.5, 'max_depth': 10, 'min_data_in_leaf': 10} ...
#
#
#  |███████████████████████---------------------------| 46.4286%
#
# Trying parameter combination 52 of 112: {'learning_rate': 1.0, 'max_depth': 10, 'min_data_in_leaf': 10} ...
#
#
#  |████████████████████████--------------------------| 47.3214%
#
# Trying parameter combination 53 of 112: {'learning_rate': 0.01, 'max_depth': 50, 'min_data_in_leaf': 10} ...
#
#
#  |████████████████████████--------------------------| 48.2143%
#
# Trying parameter combination 54 of 112: {'learning_rate': 0.1, 'max_depth': 50, 'min_data_in_leaf': 10} ...
#
#
#  |█████████████████████████-------------------------| 49.1071%
#
# Trying parameter combination 55 of 112: {'learning_rate': 0.5, 'max_depth': 50, 'min_data_in_leaf': 10} ...
#
#
#  |█████████████████████████-------------------------| 50.0000%
#
# Trying parameter combination 56 of 112: {'learning_rate': 1.0, 'max_depth': 50, 'min_data_in_leaf': 10} ...
#
#
#  |█████████████████████████-------------------------| 50.8929%
#
# Trying parameter combination 57 of 112: {'learning_rate': 0.01, 'max_depth': 1, 'min_data_in_leaf': 20} ...
#
#
#  |██████████████████████████------------------------| 51.7857%
#
# Trying parameter combination 58 of 112: {'learning_rate': 0.1, 'max_depth': 1, 'min_data_in_leaf': 20} ...
#
#
#  |██████████████████████████------------------------| 52.6786%
#
# Trying parameter combination 59 of 112: {'learning_rate': 0.5, 'max_depth': 1, 'min_data_in_leaf': 20} ...
#
#
#  |███████████████████████████-----------------------| 53.5714%
#
# Trying parameter combination 60 of 112: {'learning_rate': 1.0, 'max_depth': 1, 'min_data_in_leaf': 20} ...
#
#
#  |███████████████████████████-----------------------| 54.4643%
#
# Trying parameter combination 61 of 112: {'learning_rate': 0.01, 'max_depth': 2, 'min_data_in_leaf': 20} ...
#
#
#  |████████████████████████████----------------------| 55.3571%
#
# Trying parameter combination 62 of 112: {'learning_rate': 0.1, 'max_depth': 2, 'min_data_in_leaf': 20} ...
#
#
#  |████████████████████████████----------------------| 56.2500%
#
# Trying parameter combination 63 of 112: {'learning_rate': 0.5, 'max_depth': 2, 'min_data_in_leaf': 20} ...
#
#
#  |█████████████████████████████---------------------| 57.1429%
#
# Trying parameter combination 64 of 112: {'learning_rate': 1.0, 'max_depth': 2, 'min_data_in_leaf': 20} ...
#
#
#  |█████████████████████████████---------------------| 58.0357%
#
# Trying parameter combination 65 of 112: {'learning_rate': 0.01, 'max_depth': 3, 'min_data_in_leaf': 20} ...
#
#
#  |█████████████████████████████---------------------| 58.9286%
#
# Trying parameter combination 66 of 112: {'learning_rate': 0.1, 'max_depth': 3, 'min_data_in_leaf': 20} ...
# ***** New best score (1.8165155698267381) found for the following parameter combination:
# {'learning_rate': 0.1, 'max_depth': 3, 'min_data_in_leaf': 20, 'num_boost_round': 68.6}
#
#
#  |██████████████████████████████--------------------| 59.8214%
#
# Trying parameter combination 67 of 112: {'learning_rate': 0.5, 'max_depth': 3, 'min_data_in_leaf': 20} ...
#
#
#  |██████████████████████████████--------------------| 60.7143%
#
# Trying parameter combination 68 of 112: {'learning_rate': 1.0, 'max_depth': 3, 'min_data_in_leaf': 20} ...
#
#
#  |███████████████████████████████-------------------| 61.6071%
#
# Trying parameter combination 69 of 112: {'learning_rate': 0.01, 'max_depth': 4, 'min_data_in_leaf': 20} ...
#
#
#  |███████████████████████████████-------------------| 62.5000%
#
# Trying parameter combination 70 of 112: {'learning_rate': 0.1, 'max_depth': 4, 'min_data_in_leaf': 20} ...
# ***** New best score (1.8151854543819463) found for the following parameter combination:
# {'learning_rate': 0.1, 'max_depth': 4, 'min_data_in_leaf': 20, 'num_boost_round': 56.4}
#
#
#  |████████████████████████████████------------------| 63.3929%
#
# Trying parameter combination 71 of 112: {'learning_rate': 0.5, 'max_depth': 4, 'min_data_in_leaf': 20} ...
#
#
#  |████████████████████████████████------------------| 64.2857%
#
# Trying parameter combination 72 of 112: {'learning_rate': 1.0, 'max_depth': 4, 'min_data_in_leaf': 20} ...
#
#
#  |█████████████████████████████████-----------------| 65.1786%
#
# Trying parameter combination 73 of 112: {'learning_rate': 0.01, 'max_depth': 5, 'min_data_in_leaf': 20} ...
#
#
#  |█████████████████████████████████-----------------| 66.0714%
#
# Trying parameter combination 74 of 112: {'learning_rate': 0.1, 'max_depth': 5, 'min_data_in_leaf': 20} ...
#
#
#  |█████████████████████████████████-----------------| 66.9643%
#
# Trying parameter combination 75 of 112: {'learning_rate': 0.5, 'max_depth': 5, 'min_data_in_leaf': 20} ...
#
#
#  |██████████████████████████████████----------------| 67.8571%
#
# Trying parameter combination 76 of 112: {'learning_rate': 1.0, 'max_depth': 5, 'min_data_in_leaf': 20} ...
#
#
#  |██████████████████████████████████----------------| 68.7500%
#
# Trying parameter combination 77 of 112: {'learning_rate': 0.01, 'max_depth': 10, 'min_data_in_leaf': 20} ...
#
#
#  |███████████████████████████████████---------------| 69.6429%
#
# Trying parameter combination 78 of 112: {'learning_rate': 0.1, 'max_depth': 10, 'min_data_in_leaf': 20} ...
#
#
#  |███████████████████████████████████---------------| 70.5357%
#
# Trying parameter combination 79 of 112: {'learning_rate': 0.5, 'max_depth': 10, 'min_data_in_leaf': 20} ...
#
#
#  |████████████████████████████████████--------------| 71.4286%
#
# Trying parameter combination 80 of 112: {'learning_rate': 1.0, 'max_depth': 10, 'min_data_in_leaf': 20} ...
#
#
#  |████████████████████████████████████--------------| 72.3214%
#
# Trying parameter combination 81 of 112: {'learning_rate': 0.01, 'max_depth': 50, 'min_data_in_leaf': 20} ...
#
#
#  |█████████████████████████████████████-------------| 73.2143%
#
# Trying parameter combination 82 of 112: {'learning_rate': 0.1, 'max_depth': 50, 'min_data_in_leaf': 20} ...
#
#
#  |█████████████████████████████████████-------------| 74.1071%
#
# Trying parameter combination 83 of 112: {'learning_rate': 0.5, 'max_depth': 50, 'min_data_in_leaf': 20} ...
#
#
#  |██████████████████████████████████████------------| 75.0000%
#
# Trying parameter combination 84 of 112: {'learning_rate': 1.0, 'max_depth': 50, 'min_data_in_leaf': 20} ...
#
#
#  |██████████████████████████████████████------------| 75.8929%
#
# Trying parameter combination 85 of 112: {'learning_rate': 0.01, 'max_depth': 1, 'min_data_in_leaf': 50} ...
#
#
#  |██████████████████████████████████████------------| 76.7857%
#
# Trying parameter combination 86 of 112: {'learning_rate': 0.1, 'max_depth': 1, 'min_data_in_leaf': 50} ...
#
#
#  |███████████████████████████████████████-----------| 77.6786%
#
# Trying parameter combination 87 of 112: {'learning_rate': 0.5, 'max_depth': 1, 'min_data_in_leaf': 50} ...
#
#
#  |███████████████████████████████████████-----------| 78.5714%
#
# Trying parameter combination 88 of 112: {'learning_rate': 1.0, 'max_depth': 1, 'min_data_in_leaf': 50} ...
#
#
#  |████████████████████████████████████████----------| 79.4643%
#
# Trying parameter combination 89 of 112: {'learning_rate': 0.01, 'max_depth': 2, 'min_data_in_leaf': 50} ...
#
#
#  |████████████████████████████████████████----------| 80.3571%
#
# Trying parameter combination 90 of 112: {'learning_rate': 0.1, 'max_depth': 2, 'min_data_in_leaf': 50} ...
#
#
#  |█████████████████████████████████████████---------| 81.2500%
#
# Trying parameter combination 91 of 112: {'learning_rate': 0.5, 'max_depth': 2, 'min_data_in_leaf': 50} ...
#
#
#  |█████████████████████████████████████████---------| 82.1429%
#
# Trying parameter combination 92 of 112: {'learning_rate': 1.0, 'max_depth': 2, 'min_data_in_leaf': 50} ...
#
#
#  |██████████████████████████████████████████--------| 83.0357%
#
# Trying parameter combination 93 of 112: {'learning_rate': 0.01, 'max_depth': 3, 'min_data_in_leaf': 50} ...
#
#
#  |██████████████████████████████████████████--------| 83.9286%
#
# Trying parameter combination 94 of 112: {'learning_rate': 0.1, 'max_depth': 3, 'min_data_in_leaf': 50} ...
#
#
#  |██████████████████████████████████████████--------| 84.8214%
#
# Trying parameter combination 95 of 112: {'learning_rate': 0.5, 'max_depth': 3, 'min_data_in_leaf': 50} ...
#
#
#  |███████████████████████████████████████████-------| 85.7143%
#
# Trying parameter combination 96 of 112: {'learning_rate': 1.0, 'max_depth': 3, 'min_data_in_leaf': 50} ...
#
#
#  |███████████████████████████████████████████-------| 86.6071%
#
# Trying parameter combination 97 of 112: {'learning_rate': 0.01, 'max_depth': 4, 'min_data_in_leaf': 50} ...
#
#
#  |████████████████████████████████████████████------| 87.5000%
#
# Trying parameter combination 98 of 112: {'learning_rate': 0.1, 'max_depth': 4, 'min_data_in_leaf': 50} ...
#
#
#  |████████████████████████████████████████████------| 88.3929%
#
# Trying parameter combination 99 of 112: {'learning_rate': 0.5, 'max_depth': 4, 'min_data_in_leaf': 50} ...
#
#
#  |█████████████████████████████████████████████-----| 89.2857%
#
# Trying parameter combination 100 of 112: {'learning_rate': 1.0, 'max_depth': 4, 'min_data_in_leaf': 50} ...
#
#
#  |█████████████████████████████████████████████-----| 90.1786%
#
# Trying parameter combination 101 of 112: {'learning_rate': 0.01, 'max_depth': 5, 'min_data_in_leaf': 50} ...
#
#
#  |██████████████████████████████████████████████----| 91.0714%
#
# Trying parameter combination 102 of 112: {'learning_rate': 0.1, 'max_depth': 5, 'min_data_in_leaf': 50} ...
#
#
#  |██████████████████████████████████████████████----| 91.9643%
#
# Trying parameter combination 103 of 112: {'learning_rate': 0.5, 'max_depth': 5, 'min_data_in_leaf': 50} ...
#
#
#  |██████████████████████████████████████████████----| 92.8571%
#
# Trying parameter combination 104 of 112: {'learning_rate': 1.0, 'max_depth': 5, 'min_data_in_leaf': 50} ...
#
#
#  |███████████████████████████████████████████████---| 93.7500%
#
# Trying parameter combination 105 of 112: {'learning_rate': 0.01, 'max_depth': 10, 'min_data_in_leaf': 50} ...
#
#
#  |███████████████████████████████████████████████---| 94.6429%
#
# Trying parameter combination 106 of 112: {'learning_rate': 0.1, 'max_depth': 10, 'min_data_in_leaf': 50} ...
#
#
#  |████████████████████████████████████████████████--| 95.5357%
#
# Trying parameter combination 107 of 112: {'learning_rate': 0.5, 'max_depth': 10, 'min_data_in_leaf': 50} ...
#
#
#  |████████████████████████████████████████████████--| 96.4286%
#
# Trying parameter combination 108 of 112: {'learning_rate': 1.0, 'max_depth': 10, 'min_data_in_leaf': 50} ...
#
#
#  |█████████████████████████████████████████████████-| 97.3214%
#
# Trying parameter combination 109 of 112: {'learning_rate': 0.01, 'max_depth': 50, 'min_data_in_leaf': 50} ...
#
#
#  |█████████████████████████████████████████████████-| 98.2143%
#
# Trying parameter combination 110 of 112: {'learning_rate': 0.1, 'max_depth': 50, 'min_data_in_leaf': 50} ...
#
#
#  |██████████████████████████████████████████████████| 99.1071%
#
# Trying parameter combination 111 of 112: {'learning_rate': 0.5, 'max_depth': 50, 'min_data_in_leaf': 50} ...
#
#
#  |██████████████████████████████████████████████████| 100.0000%
#
#
# Trying parameter combination 112 of 112: {'learning_rate': 1.0, 'max_depth': 50, 'min_data_in_leaf': 50} ...
# Best number of iterations:  56.4
# Best score:  1.8151854543819463
# Best parameters:  {'learning_rate': 0.1, 'max_depth': 4, 'min_data_in_leaf': 20}

# %% [markdown]
# ### GPBoost with shared GPs

# %%
# Shared GP
gp_model = gpb.GPModel(group_data=groups, gp_coords=times, cov_function='exponential', cov_fct_shape=2.5)

# Use the same hyperparameters as for Independent GP and only cross-validate to find num_boost_round
params = {'learning_rate': 0.1,
          'max_depth': 4,
          'min_data_in_leaf': 20,
          'objective': 'regression_l2',
          'verbose': 0,
          'num_leaves': 2**10}

opt_params = grid_search_tune_parameters_multiple(param_grid={},
                                                  params=params,
                                                  nfold=5,
                                                  gp_model=gp_model,
                                                  use_gp_model_for_validation=True,
                                                  train_sets=validation_datasets['data_train'],
                                                  verbose_eval=1,
                                                  num_boost_round=200, 
                                                  early_stopping_rounds=10,
                                                  shuffle=False,
                                                  seed=1,
                                                  metrics='rmse')
                                                  
print('Best number of iterations: ', opt_params['best_iter'])
print('Best score: ', opt_params['best_score'])
print('Best parameters: ', opt_params['best_params'])
# Out:
# Starting deterministic grid search with 1 parameter combinations...
#
#
#  |██████████████████████████████████████████████████| 100.0000%
#
#
# Trying parameter combination 1 of 1: {} ...
# ***** New best score (1.5268680551635434) found for the following parameter combination:
# {'num_boost_round': 52.4}
# Best number of iterations:  52.4
# Best score:  1.5268680551635434
# Best parameters:  {}

# %% [markdown]
# ### Gradient-boosted trees including groups as a categorical variable

# %%
# GBT with grouping variable as a categorical feature
datasets_cat, validation_datasets_cat = generate_datasets(n, m, p, n_datasets, n_valid, func='make_friedman3', 
                                                            shared_gp=True, random_state=60, include_cat_feature=True)

# Candidate parameter grid
param_grid = {'num_leaves': [10, 20, 50, 200, 500, 1000, 5000, 2**10], 
              'max_depth': [1, 2, 3, 4, 5, 10, 50],
              'min_data_in_leaf': [1, 5, 10, 20, 30, 50]}

# Other parameters not contained in the grid of tuning parameters
params = {'objective': 'regression_l2',
          'verbose': 0,
          'learning_rate' : 0.10}
          #'device_type' : 'gpu'}

opt_params = grid_search_tune_parameters_multiple(param_grid=param_grid,
                                                  params=params,
                                                  nfold=5,
                                                  gp_model=None,
                                                  use_gp_model_for_validation=True,
                                                  train_sets=validation_datasets_cat['data_train'],
                                                  verbose_eval=1,
                                                  num_boost_round=400, 
                                                  early_stopping_rounds=10,
                                                  shuffle=False,
                                                  seed=1,
                                                  metrics='rmse')
                                                  
print('Best number of iterations: ', opt_params['best_iter'])
print('Best score: ', opt_params['best_score'])
print('Best parameters: ', opt_params['best_params'])
# Out:
# Starting deterministic grid search with 336 parameter combinations...
#
#
#  |--------------------------------------------------| 0.2976%
#
# Trying parameter combination 1 of 336: {'num_leaves': 10, 'max_depth': 1, 'min_data_in_leaf': 1} ...
# /usr/local/lib/python3.7/dist-packages/gpboost/basic.py:1822: UserWarning: Using categorical_feature in Dataset.
#   _log_warning('Using categorical_feature in Dataset.')
# /usr/local/lib/python3.7/dist-packages/gpboost/basic.py:1339: UserWarning: categorical_column in param dict is overridden.
#   _log_warning('{} in param dict is overridden.'.format(cat_alias))
# ***** New best score (1.5639096832318025) found for the following parameter combination:
# {'num_leaves': 10, 'max_depth': 1, 'min_data_in_leaf': 1, 'num_boost_round': 234.6}
#
#
#  |--------------------------------------------------| 0.5952%
#
# Trying parameter combination 2 of 336: {'num_leaves': 20, 'max_depth': 1, 'min_data_in_leaf': 1} ...
#
#
#  |--------------------------------------------------| 0.8929%
#
# Trying parameter combination 3 of 336: {'num_leaves': 50, 'max_depth': 1, 'min_data_in_leaf': 1} ...
#
#
#  |█-------------------------------------------------| 1.1905%
#
# Trying parameter combination 4 of 336: {'num_leaves': 200, 'max_depth': 1, 'min_data_in_leaf': 1} ...
#
#
#  |█-------------------------------------------------| 1.4881%
#
# Trying parameter combination 5 of 336: {'num_leaves': 500, 'max_depth': 1, 'min_data_in_leaf': 1} ...
#
#
#  |█-------------------------------------------------| 1.7857%
#
# Trying parameter combination 6 of 336: {'num_leaves': 1000, 'max_depth': 1, 'min_data_in_leaf': 1} ...
#
#
#  |█-------------------------------------------------| 2.0833%
#
# Trying parameter combination 7 of 336: {'num_leaves': 5000, 'max_depth': 1, 'min_data_in_leaf': 1} ...
#
#
#  |█-------------------------------------------------| 2.3810%
#
# Trying parameter combination 8 of 336: {'num_leaves': 1024, 'max_depth': 1, 'min_data_in_leaf': 1} ...
#
#
#  |█-------------------------------------------------| 2.6786%
#
# Trying parameter combination 9 of 336: {'num_leaves': 10, 'max_depth': 2, 'min_data_in_leaf': 1} ...
# ***** New best score (1.5439244980827929) found for the following parameter combination:
# {'num_leaves': 10, 'max_depth': 2, 'min_data_in_leaf': 1, 'num_boost_round': 124.8}
#
#
#  |█-------------------------------------------------| 2.9762%
#
# Trying parameter combination 10 of 336: {'num_leaves': 20, 'max_depth': 2, 'min_data_in_leaf': 1} ...
#
#
#  |██------------------------------------------------| 3.2738%
#
# Trying parameter combination 11 of 336: {'num_leaves': 50, 'max_depth': 2, 'min_data_in_leaf': 1} ...
# ***** New best score (1.5436611292675564) found for the following parameter combination:
# {'num_leaves': 50, 'max_depth': 2, 'min_data_in_leaf': 1, 'num_boost_round': 124.8}
#
#
#  |██------------------------------------------------| 3.5714%
#
# Trying parameter combination 12 of 336: {'num_leaves': 200, 'max_depth': 2, 'min_data_in_leaf': 1} ...
#
#
#  |██------------------------------------------------| 3.8690%
#
# Trying parameter combination 13 of 336: {'num_leaves': 500, 'max_depth': 2, 'min_data_in_leaf': 1} ...
#
#
#  |██------------------------------------------------| 4.1667%
#
# Trying parameter combination 14 of 336: {'num_leaves': 1000, 'max_depth': 2, 'min_data_in_leaf': 1} ...
#
#
#  |██------------------------------------------------| 4.4643%
#
# Trying parameter combination 15 of 336: {'num_leaves': 5000, 'max_depth': 2, 'min_data_in_leaf': 1} ...
# ***** New best score (1.543445486988826) found for the following parameter combination:
# {'num_leaves': 5000, 'max_depth': 2, 'min_data_in_leaf': 1, 'num_boost_round': 124.8}
#
#
#  |██------------------------------------------------| 4.7619%
#
# Trying parameter combination 16 of 336: {'num_leaves': 1024, 'max_depth': 2, 'min_data_in_leaf': 1} ...
#
#
#  |███-----------------------------------------------| 5.0595%
#
# Trying parameter combination 17 of 336: {'num_leaves': 10, 'max_depth': 3, 'min_data_in_leaf': 1} ...
#
#
#  |███-----------------------------------------------| 5.3571%
#
# Trying parameter combination 18 of 336: {'num_leaves': 20, 'max_depth': 3, 'min_data_in_leaf': 1} ...
#
#
#  |███-----------------------------------------------| 5.6548%
#
# Trying parameter combination 19 of 336: {'num_leaves': 50, 'max_depth': 3, 'min_data_in_leaf': 1} ...
#
#
#  |███-----------------------------------------------| 5.9524%
#
# Trying parameter combination 20 of 336: {'num_leaves': 200, 'max_depth': 3, 'min_data_in_leaf': 1} ...
#
#
#  |███-----------------------------------------------| 6.2500%
#
# Trying parameter combination 21 of 336: {'num_leaves': 500, 'max_depth': 3, 'min_data_in_leaf': 1} ...
#
#
#  |███-----------------------------------------------| 6.5476%
#
# Trying parameter combination 22 of 336: {'num_leaves': 1000, 'max_depth': 3, 'min_data_in_leaf': 1} ...
#
#
#  |███-----------------------------------------------| 6.8452%
#
# Trying parameter combination 23 of 336: {'num_leaves': 5000, 'max_depth': 3, 'min_data_in_leaf': 1} ...
#
#
#  |████----------------------------------------------| 7.1429%
#
# Trying parameter combination 24 of 336: {'num_leaves': 1024, 'max_depth': 3, 'min_data_in_leaf': 1} ...
#
#
#  |████----------------------------------------------| 7.4405%
#
# Trying parameter combination 25 of 336: {'num_leaves': 10, 'max_depth': 4, 'min_data_in_leaf': 1} ...
#
#
#  |████----------------------------------------------| 7.7381%
#
# Trying parameter combination 26 of 336: {'num_leaves': 20, 'max_depth': 4, 'min_data_in_leaf': 1} ...
#
#
#  |████----------------------------------------------| 8.0357%
#
# Trying parameter combination 27 of 336: {'num_leaves': 50, 'max_depth': 4, 'min_data_in_leaf': 1} ...
#
#
#  |████----------------------------------------------| 8.3333%
#
# Trying parameter combination 28 of 336: {'num_leaves': 200, 'max_depth': 4, 'min_data_in_leaf': 1} ...
#
#
#  |████----------------------------------------------| 8.6310%
#
# Trying parameter combination 29 of 336: {'num_leaves': 500, 'max_depth': 4, 'min_data_in_leaf': 1} ...
#
#
#  |████----------------------------------------------| 8.9286%
#
# Trying parameter combination 30 of 336: {'num_leaves': 1000, 'max_depth': 4, 'min_data_in_leaf': 1} ...
#
#
#  |█████---------------------------------------------| 9.2262%
#
# Trying parameter combination 31 of 336: {'num_leaves': 5000, 'max_depth': 4, 'min_data_in_leaf': 1} ...
#
#
#  |█████---------------------------------------------| 9.5238%
#
# Trying parameter combination 32 of 336: {'num_leaves': 1024, 'max_depth': 4, 'min_data_in_leaf': 1} ...
#
#
#  |█████---------------------------------------------| 9.8214%
#
# Trying parameter combination 33 of 336: {'num_leaves': 10, 'max_depth': 5, 'min_data_in_leaf': 1} ...
#
#
#  |█████---------------------------------------------| 10.1190%
#
# Trying parameter combination 34 of 336: {'num_leaves': 20, 'max_depth': 5, 'min_data_in_leaf': 1} ...
#
#
#  |█████---------------------------------------------| 10.4167%
#
# Trying parameter combination 35 of 336: {'num_leaves': 50, 'max_depth': 5, 'min_data_in_leaf': 1} ...
#
#
#  |█████---------------------------------------------| 10.7143%
#
# Trying parameter combination 36 of 336: {'num_leaves': 200, 'max_depth': 5, 'min_data_in_leaf': 1} ...
#
#
#  |██████--------------------------------------------| 11.0119%
#
# Trying parameter combination 37 of 336: {'num_leaves': 500, 'max_depth': 5, 'min_data_in_leaf': 1} ...
#
#
#  |██████--------------------------------------------| 11.3095%
#
# Trying parameter combination 38 of 336: {'num_leaves': 1000, 'max_depth': 5, 'min_data_in_leaf': 1} ...
#
#
#  |██████--------------------------------------------| 11.6071%
#
# Trying parameter combination 39 of 336: {'num_leaves': 5000, 'max_depth': 5, 'min_data_in_leaf': 1} ...
#
#
#  |██████--------------------------------------------| 11.9048%
#
# Trying parameter combination 40 of 336: {'num_leaves': 1024, 'max_depth': 5, 'min_data_in_leaf': 1} ...
#
#
#  |██████--------------------------------------------| 12.2024%
#
# Trying parameter combination 41 of 336: {'num_leaves': 10, 'max_depth': 10, 'min_data_in_leaf': 1} ...
#
#
#  |██████--------------------------------------------| 12.5000%
#
# Trying parameter combination 42 of 336: {'num_leaves': 20, 'max_depth': 10, 'min_data_in_leaf': 1} ...
#
#
#  |██████--------------------------------------------| 12.7976%
#
# Trying parameter combination 43 of 336: {'num_leaves': 50, 'max_depth': 10, 'min_data_in_leaf': 1} ...
#
#
#  |███████-------------------------------------------| 13.0952%
#
# Trying parameter combination 44 of 336: {'num_leaves': 200, 'max_depth': 10, 'min_data_in_leaf': 1} ...
#
#
#  |███████-------------------------------------------| 13.3929%
#
# Trying parameter combination 45 of 336: {'num_leaves': 500, 'max_depth': 10, 'min_data_in_leaf': 1} ...
#
#
#  |███████-------------------------------------------| 13.6905%
#
# Trying parameter combination 46 of 336: {'num_leaves': 1000, 'max_depth': 10, 'min_data_in_leaf': 1} ...
#
#
#  |███████-------------------------------------------| 13.9881%
#
# Trying parameter combination 47 of 336: {'num_leaves': 5000, 'max_depth': 10, 'min_data_in_leaf': 1} ...
#
#
#  |███████-------------------------------------------| 14.2857%
#
# Trying parameter combination 48 of 336: {'num_leaves': 1024, 'max_depth': 10, 'min_data_in_leaf': 1} ...
#
#
#  |███████-------------------------------------------| 14.5833%
#
# Trying parameter combination 49 of 336: {'num_leaves': 10, 'max_depth': 50, 'min_data_in_leaf': 1} ...
#
#
#  |███████-------------------------------------------| 14.8810%
#
# Trying parameter combination 50 of 336: {'num_leaves': 20, 'max_depth': 50, 'min_data_in_leaf': 1} ...
#
#
#  |████████------------------------------------------| 15.1786%
#
# Trying parameter combination 51 of 336: {'num_leaves': 50, 'max_depth': 50, 'min_data_in_leaf': 1} ...
#
#
#  |████████------------------------------------------| 15.4762%
#
# Trying parameter combination 52 of 336: {'num_leaves': 200, 'max_depth': 50, 'min_data_in_leaf': 1} ...
#
#
#  |████████------------------------------------------| 15.7738%
#
# Trying parameter combination 53 of 336: {'num_leaves': 500, 'max_depth': 50, 'min_data_in_leaf': 1} ...
#
#
#  |████████------------------------------------------| 16.0714%
#
# Trying parameter combination 54 of 336: {'num_leaves': 1000, 'max_depth': 50, 'min_data_in_leaf': 1} ...
#
#
#  |████████------------------------------------------| 16.3690%
#
# Trying parameter combination 55 of 336: {'num_leaves': 5000, 'max_depth': 50, 'min_data_in_leaf': 1} ...
#
#
#  |████████------------------------------------------| 16.6667%
#
# Trying parameter combination 56 of 336: {'num_leaves': 1024, 'max_depth': 50, 'min_data_in_leaf': 1} ...
#
#
#  |████████------------------------------------------| 16.9643%
#
# Trying parameter combination 57 of 336: {'num_leaves': 10, 'max_depth': 1, 'min_data_in_leaf': 5} ...
#
#
#  |█████████-----------------------------------------| 17.2619%
#
# Trying parameter combination 58 of 336: {'num_leaves': 20, 'max_depth': 1, 'min_data_in_leaf': 5} ...
#
#
#  |█████████-----------------------------------------| 17.5595%
#
# Trying parameter combination 59 of 336: {'num_leaves': 50, 'max_depth': 1, 'min_data_in_leaf': 5} ...
#
#
#  |█████████-----------------------------------------| 17.8571%
#
# Trying parameter combination 60 of 336: {'num_leaves': 200, 'max_depth': 1, 'min_data_in_leaf': 5} ...
#
#
#  |█████████-----------------------------------------| 18.1548%
#
# Trying parameter combination 61 of 336: {'num_leaves': 500, 'max_depth': 1, 'min_data_in_leaf': 5} ...
#
#
#  |█████████-----------------------------------------| 18.4524%
#
# Trying parameter combination 62 of 336: {'num_leaves': 1000, 'max_depth': 1, 'min_data_in_leaf': 5} ...
#
#
#  |█████████-----------------------------------------| 18.7500%
#
# Trying parameter combination 63 of 336: {'num_leaves': 5000, 'max_depth': 1, 'min_data_in_leaf': 5} ...
#
#
#  |██████████----------------------------------------| 19.0476%
#
# Trying parameter combination 64 of 336: {'num_leaves': 1024, 'max_depth': 1, 'min_data_in_leaf': 5} ...
#
#
#  |██████████----------------------------------------| 19.3452%
#
# Trying parameter combination 65 of 336: {'num_leaves': 10, 'max_depth': 2, 'min_data_in_leaf': 5} ...
#
#
#  |██████████----------------------------------------| 19.6429%
#
# Trying parameter combination 66 of 336: {'num_leaves': 20, 'max_depth': 2, 'min_data_in_leaf': 5} ...
#
#
#  |██████████----------------------------------------| 19.9405%
#
# Trying parameter combination 67 of 336: {'num_leaves': 50, 'max_depth': 2, 'min_data_in_leaf': 5} ...
#
#
#  |██████████----------------------------------------| 20.2381%
#
# Trying parameter combination 68 of 336: {'num_leaves': 200, 'max_depth': 2, 'min_data_in_leaf': 5} ...
#
#
#  |██████████----------------------------------------| 20.5357%
#
# Trying parameter combination 69 of 336: {'num_leaves': 500, 'max_depth': 2, 'min_data_in_leaf': 5} ...
#
#
#  |██████████----------------------------------------| 20.8333%
#
# Trying parameter combination 70 of 336: {'num_leaves': 1000, 'max_depth': 2, 'min_data_in_leaf': 5} ...
#
#
#  |███████████---------------------------------------| 21.1310%
#
# Trying parameter combination 71 of 336: {'num_leaves': 5000, 'max_depth': 2, 'min_data_in_leaf': 5} ...
#
#
#  |███████████---------------------------------------| 21.4286%
#
# Trying parameter combination 72 of 336: {'num_leaves': 1024, 'max_depth': 2, 'min_data_in_leaf': 5} ...
#
#
#  |███████████---------------------------------------| 21.7262%
#
# Trying parameter combination 73 of 336: {'num_leaves': 10, 'max_depth': 3, 'min_data_in_leaf': 5} ...
#
#
#  |███████████---------------------------------------| 22.0238%
#
# Trying parameter combination 74 of 336: {'num_leaves': 20, 'max_depth': 3, 'min_data_in_leaf': 5} ...
#
#
#  |███████████---------------------------------------| 22.3214%
#
# Trying parameter combination 75 of 336: {'num_leaves': 50, 'max_depth': 3, 'min_data_in_leaf': 5} ...
#
#
#  |███████████---------------------------------------| 22.6190%
#
# Trying parameter combination 76 of 336: {'num_leaves': 200, 'max_depth': 3, 'min_data_in_leaf': 5} ...
#
#
#  |███████████---------------------------------------| 22.9167%
#
# Trying parameter combination 77 of 336: {'num_leaves': 500, 'max_depth': 3, 'min_data_in_leaf': 5} ...
#
#
#  |████████████--------------------------------------| 23.2143%
#
# Trying parameter combination 78 of 336: {'num_leaves': 1000, 'max_depth': 3, 'min_data_in_leaf': 5} ...
#
#
#  |████████████--------------------------------------| 23.5119%
#
# Trying parameter combination 79 of 336: {'num_leaves': 5000, 'max_depth': 3, 'min_data_in_leaf': 5} ...
#
#
#  |████████████--------------------------------------| 23.8095%
#
# Trying parameter combination 80 of 336: {'num_leaves': 1024, 'max_depth': 3, 'min_data_in_leaf': 5} ...
#
#
#  |████████████--------------------------------------| 24.1071%
#
# Trying parameter combination 81 of 336: {'num_leaves': 10, 'max_depth': 4, 'min_data_in_leaf': 5} ...
#
#
#  |████████████--------------------------------------| 24.4048%
#
# Trying parameter combination 82 of 336: {'num_leaves': 20, 'max_depth': 4, 'min_data_in_leaf': 5} ...
#
#
#  |████████████--------------------------------------| 24.7024%
#
# Trying parameter combination 83 of 336: {'num_leaves': 50, 'max_depth': 4, 'min_data_in_leaf': 5} ...
#
#
#  |████████████--------------------------------------| 25.0000%
#
# Trying parameter combination 84 of 336: {'num_leaves': 200, 'max_depth': 4, 'min_data_in_leaf': 5} ...
#
#
#  |█████████████-------------------------------------| 25.2976%
#
# Trying parameter combination 85 of 336: {'num_leaves': 500, 'max_depth': 4, 'min_data_in_leaf': 5} ...
#
#
#  |█████████████-------------------------------------| 25.5952%
#
# Trying parameter combination 86 of 336: {'num_leaves': 1000, 'max_depth': 4, 'min_data_in_leaf': 5} ...
#
#
#  |█████████████-------------------------------------| 25.8929%
#
# Trying parameter combination 87 of 336: {'num_leaves': 5000, 'max_depth': 4, 'min_data_in_leaf': 5} ...
#
#
#  |█████████████-------------------------------------| 26.1905%
#
# Trying parameter combination 88 of 336: {'num_leaves': 1024, 'max_depth': 4, 'min_data_in_leaf': 5} ...
#
#
#  |█████████████-------------------------------------| 26.4881%
#
# Trying parameter combination 89 of 336: {'num_leaves': 10, 'max_depth': 5, 'min_data_in_leaf': 5} ...
#
#
#  |█████████████-------------------------------------| 26.7857%
#
# Trying parameter combination 90 of 336: {'num_leaves': 20, 'max_depth': 5, 'min_data_in_leaf': 5} ...
#
#
#  |██████████████------------------------------------| 27.0833%
#
# Trying parameter combination 91 of 336: {'num_leaves': 50, 'max_depth': 5, 'min_data_in_leaf': 5} ...
#
#
#  |██████████████------------------------------------| 27.3810%
#
# Trying parameter combination 92 of 336: {'num_leaves': 200, 'max_depth': 5, 'min_data_in_leaf': 5} ...
#
#
#  |██████████████------------------------------------| 27.6786%
#
# Trying parameter combination 93 of 336: {'num_leaves': 500, 'max_depth': 5, 'min_data_in_leaf': 5} ...
#
#
#  |██████████████------------------------------------| 27.9762%
#
# Trying parameter combination 94 of 336: {'num_leaves': 1000, 'max_depth': 5, 'min_data_in_leaf': 5} ...
#
#
#  |██████████████------------------------------------| 28.2738%
#
# Trying parameter combination 95 of 336: {'num_leaves': 5000, 'max_depth': 5, 'min_data_in_leaf': 5} ...
#
#
#  |██████████████------------------------------------| 28.5714%
#
# Trying parameter combination 96 of 336: {'num_leaves': 1024, 'max_depth': 5, 'min_data_in_leaf': 5} ...
#
#
#  |██████████████------------------------------------| 28.8690%
#
# Trying parameter combination 97 of 336: {'num_leaves': 10, 'max_depth': 10, 'min_data_in_leaf': 5} ...
#
#
#  |███████████████-----------------------------------| 29.1667%
#
# Trying parameter combination 98 of 336: {'num_leaves': 20, 'max_depth': 10, 'min_data_in_leaf': 5} ...
#
#
#  |███████████████-----------------------------------| 29.4643%
#
# Trying parameter combination 99 of 336: {'num_leaves': 50, 'max_depth': 10, 'min_data_in_leaf': 5} ...
#
#
#  |███████████████-----------------------------------| 29.7619%
#
# Trying parameter combination 100 of 336: {'num_leaves': 200, 'max_depth': 10, 'min_data_in_leaf': 5} ...
#
#
#  |███████████████-----------------------------------| 30.0595%
#
# Trying parameter combination 101 of 336: {'num_leaves': 500, 'max_depth': 10, 'min_data_in_leaf': 5} ...
#
#
#  |███████████████-----------------------------------| 30.3571%
#
# Trying parameter combination 102 of 336: {'num_leaves': 1000, 'max_depth': 10, 'min_data_in_leaf': 5} ...
#
#
#  |███████████████-----------------------------------| 30.6548%
#
# Trying parameter combination 103 of 336: {'num_leaves': 5000, 'max_depth': 10, 'min_data_in_leaf': 5} ...
#
#
#  |███████████████-----------------------------------| 30.9524%
#
# Trying parameter combination 104 of 336: {'num_leaves': 1024, 'max_depth': 10, 'min_data_in_leaf': 5} ...
#
#
#  |████████████████----------------------------------| 31.2500%
#
# Trying parameter combination 105 of 336: {'num_leaves': 10, 'max_depth': 50, 'min_data_in_leaf': 5} ...
#
#
#  |████████████████----------------------------------| 31.5476%
#
# Trying parameter combination 106 of 336: {'num_leaves': 20, 'max_depth': 50, 'min_data_in_leaf': 5} ...
#
#
#  |████████████████----------------------------------| 31.8452%
#
# Trying parameter combination 107 of 336: {'num_leaves': 50, 'max_depth': 50, 'min_data_in_leaf': 5} ...
#
#
#  |████████████████----------------------------------| 32.1429%
#
# Trying parameter combination 108 of 336: {'num_leaves': 200, 'max_depth': 50, 'min_data_in_leaf': 5} ...
#
#
#  |████████████████----------------------------------| 32.4405%
#
# Trying parameter combination 109 of 336: {'num_leaves': 500, 'max_depth': 50, 'min_data_in_leaf': 5} ...
#
#
#  |████████████████----------------------------------| 32.7381%
#
# Trying parameter combination 110 of 336: {'num_leaves': 1000, 'max_depth': 50, 'min_data_in_leaf': 5} ...
#
#
#  |█████████████████---------------------------------| 33.0357%
#
# Trying parameter combination 111 of 336: {'num_leaves': 5000, 'max_depth': 50, 'min_data_in_leaf': 5} ...
#
#
#  |█████████████████---------------------------------| 33.3333%
#
# Trying parameter combination 112 of 336: {'num_leaves': 1024, 'max_depth': 50, 'min_data_in_leaf': 5} ...
#
#
#  |█████████████████---------------------------------| 33.6310%
#
# Trying parameter combination 113 of 336: {'num_leaves': 10, 'max_depth': 1, 'min_data_in_leaf': 10} ...
#
#
#  |█████████████████---------------------------------| 33.9286%
#
# Trying parameter combination 114 of 336: {'num_leaves': 20, 'max_depth': 1, 'min_data_in_leaf': 10} ...
#
#
#  |█████████████████---------------------------------| 34.2262%
#
# Trying parameter combination 115 of 336: {'num_leaves': 50, 'max_depth': 1, 'min_data_in_leaf': 10} ...
#
#
#  |█████████████████---------------------------------| 34.5238%
#
# Trying parameter combination 116 of 336: {'num_leaves': 200, 'max_depth': 1, 'min_data_in_leaf': 10} ...
#
#
#  |█████████████████---------------------------------| 34.8214%
#
# Trying parameter combination 117 of 336: {'num_leaves': 500, 'max_depth': 1, 'min_data_in_leaf': 10} ...
#
#
#  |██████████████████--------------------------------| 35.1190%
#
# Trying parameter combination 118 of 336: {'num_leaves': 1000, 'max_depth': 1, 'min_data_in_leaf': 10} ...
#
#
#  |██████████████████--------------------------------| 35.4167%
#
# Trying parameter combination 119 of 336: {'num_leaves': 5000, 'max_depth': 1, 'min_data_in_leaf': 10} ...
#
#
#  |██████████████████--------------------------------| 35.7143%
#
# Trying parameter combination 120 of 336: {'num_leaves': 1024, 'max_depth': 1, 'min_data_in_leaf': 10} ...
#
#
#  |██████████████████--------------------------------| 36.0119%
#
# Trying parameter combination 121 of 336: {'num_leaves': 10, 'max_depth': 2, 'min_data_in_leaf': 10} ...
#
#
#  |██████████████████--------------------------------| 36.3095%
#
# Trying parameter combination 122 of 336: {'num_leaves': 20, 'max_depth': 2, 'min_data_in_leaf': 10} ...
#
#
#  |██████████████████--------------------------------| 36.6071%
#
# Trying parameter combination 123 of 336: {'num_leaves': 50, 'max_depth': 2, 'min_data_in_leaf': 10} ...
#
#
#  |██████████████████--------------------------------| 36.9048%
#
# Trying parameter combination 124 of 336: {'num_leaves': 200, 'max_depth': 2, 'min_data_in_leaf': 10} ...
#
#
#  |███████████████████-------------------------------| 37.2024%
#
# Trying parameter combination 125 of 336: {'num_leaves': 500, 'max_depth': 2, 'min_data_in_leaf': 10} ...
#
#
#  |███████████████████-------------------------------| 37.5000%
#
# Trying parameter combination 126 of 336: {'num_leaves': 1000, 'max_depth': 2, 'min_data_in_leaf': 10} ...
#
#
#  |███████████████████-------------------------------| 37.7976%
#
# Trying parameter combination 127 of 336: {'num_leaves': 5000, 'max_depth': 2, 'min_data_in_leaf': 10} ...
#
#
#  |███████████████████-------------------------------| 38.0952%
#
# Trying parameter combination 128 of 336: {'num_leaves': 1024, 'max_depth': 2, 'min_data_in_leaf': 10} ...
#
#
#  |███████████████████-------------------------------| 38.3929%
#
# Trying parameter combination 129 of 336: {'num_leaves': 10, 'max_depth': 3, 'min_data_in_leaf': 10} ...
#
#
#  |███████████████████-------------------------------| 38.6905%
#
# Trying parameter combination 130 of 336: {'num_leaves': 20, 'max_depth': 3, 'min_data_in_leaf': 10} ...
#
#
#  |███████████████████-------------------------------| 38.9881%
#
# Trying parameter combination 131 of 336: {'num_leaves': 50, 'max_depth': 3, 'min_data_in_leaf': 10} ...
#
#
#  |████████████████████------------------------------| 39.2857%
#
# Trying parameter combination 132 of 336: {'num_leaves': 200, 'max_depth': 3, 'min_data_in_leaf': 10} ...
#
#
#  |████████████████████------------------------------| 39.5833%
#
# Trying parameter combination 133 of 336: {'num_leaves': 500, 'max_depth': 3, 'min_data_in_leaf': 10} ...
#
#
#  |████████████████████------------------------------| 39.8810%
#
# Trying parameter combination 134 of 336: {'num_leaves': 1000, 'max_depth': 3, 'min_data_in_leaf': 10} ...
#
#
#  |████████████████████------------------------------| 40.1786%
#
# Trying parameter combination 135 of 336: {'num_leaves': 5000, 'max_depth': 3, 'min_data_in_leaf': 10} ...
#
#
#  |████████████████████------------------------------| 40.4762%
#
# Trying parameter combination 136 of 336: {'num_leaves': 1024, 'max_depth': 3, 'min_data_in_leaf': 10} ...
#
#
#  |████████████████████------------------------------| 40.7738%
#
# Trying parameter combination 137 of 336: {'num_leaves': 10, 'max_depth': 4, 'min_data_in_leaf': 10} ...
#
#
#  |█████████████████████-----------------------------| 41.0714%
#
# Trying parameter combination 138 of 336: {'num_leaves': 20, 'max_depth': 4, 'min_data_in_leaf': 10} ...
#
#
#  |█████████████████████-----------------------------| 41.3690%
#
# Trying parameter combination 139 of 336: {'num_leaves': 50, 'max_depth': 4, 'min_data_in_leaf': 10} ...
#
#
#  |█████████████████████-----------------------------| 41.6667%
#
# Trying parameter combination 140 of 336: {'num_leaves': 200, 'max_depth': 4, 'min_data_in_leaf': 10} ...
#
#
#  |█████████████████████-----------------------------| 41.9643%
#
# Trying parameter combination 141 of 336: {'num_leaves': 500, 'max_depth': 4, 'min_data_in_leaf': 10} ...
#
#
#  |█████████████████████-----------------------------| 42.2619%
#
# Trying parameter combination 142 of 336: {'num_leaves': 1000, 'max_depth': 4, 'min_data_in_leaf': 10} ...
#
#
#  |█████████████████████-----------------------------| 42.5595%
#
# Trying parameter combination 143 of 336: {'num_leaves': 5000, 'max_depth': 4, 'min_data_in_leaf': 10} ...
#
#
#  |█████████████████████-----------------------------| 42.8571%
#
# Trying parameter combination 144 of 336: {'num_leaves': 1024, 'max_depth': 4, 'min_data_in_leaf': 10} ...
#
#
#  |██████████████████████----------------------------| 43.1548%
#
# Trying parameter combination 145 of 336: {'num_leaves': 10, 'max_depth': 5, 'min_data_in_leaf': 10} ...
#
#
#  |██████████████████████----------------------------| 43.4524%
#
# Trying parameter combination 146 of 336: {'num_leaves': 20, 'max_depth': 5, 'min_data_in_leaf': 10} ...
#
#
#  |██████████████████████----------------------------| 43.7500%
#
# Trying parameter combination 147 of 336: {'num_leaves': 50, 'max_depth': 5, 'min_data_in_leaf': 10} ...
#
#
#  |██████████████████████----------------------------| 44.0476%
#
# Trying parameter combination 148 of 336: {'num_leaves': 200, 'max_depth': 5, 'min_data_in_leaf': 10} ...
#
#
#  |██████████████████████----------------------------| 44.3452%
#
# Trying parameter combination 149 of 336: {'num_leaves': 500, 'max_depth': 5, 'min_data_in_leaf': 10} ...
#
#
#  |██████████████████████----------------------------| 44.6429%
#
# Trying parameter combination 150 of 336: {'num_leaves': 1000, 'max_depth': 5, 'min_data_in_leaf': 10} ...
#
#
#  |██████████████████████----------------------------| 44.9405%
#
# Trying parameter combination 151 of 336: {'num_leaves': 5000, 'max_depth': 5, 'min_data_in_leaf': 10} ...
#
#
#  |███████████████████████---------------------------| 45.2381%
#
# Trying parameter combination 152 of 336: {'num_leaves': 1024, 'max_depth': 5, 'min_data_in_leaf': 10} ...
#
#
#  |███████████████████████---------------------------| 45.5357%
#
# Trying parameter combination 153 of 336: {'num_leaves': 10, 'max_depth': 10, 'min_data_in_leaf': 10} ...
#
#
#  |███████████████████████---------------------------| 45.8333%
#
# Trying parameter combination 154 of 336: {'num_leaves': 20, 'max_depth': 10, 'min_data_in_leaf': 10} ...
#
#
#  |███████████████████████---------------------------| 46.1310%
#
# Trying parameter combination 155 of 336: {'num_leaves': 50, 'max_depth': 10, 'min_data_in_leaf': 10} ...
#
#
#  |███████████████████████---------------------------| 46.4286%
#
# Trying parameter combination 156 of 336: {'num_leaves': 200, 'max_depth': 10, 'min_data_in_leaf': 10} ...
#
#
#  |███████████████████████---------------------------| 46.7262%
#
# Trying parameter combination 157 of 336: {'num_leaves': 500, 'max_depth': 10, 'min_data_in_leaf': 10} ...
#
#
#  |████████████████████████--------------------------| 47.0238%
#
# Trying parameter combination 158 of 336: {'num_leaves': 1000, 'max_depth': 10, 'min_data_in_leaf': 10} ...
#
#
#  |████████████████████████--------------------------| 47.3214%
#
# Trying parameter combination 159 of 336: {'num_leaves': 5000, 'max_depth': 10, 'min_data_in_leaf': 10} ...
#
#
#  |████████████████████████--------------------------| 47.6190%
#
# Trying parameter combination 160 of 336: {'num_leaves': 1024, 'max_depth': 10, 'min_data_in_leaf': 10} ...
#
#
#  |████████████████████████--------------------------| 47.9167%
#
# Trying parameter combination 161 of 336: {'num_leaves': 10, 'max_depth': 50, 'min_data_in_leaf': 10} ...
#
#
#  |████████████████████████--------------------------| 48.2143%
#
# Trying parameter combination 162 of 336: {'num_leaves': 20, 'max_depth': 50, 'min_data_in_leaf': 10} ...
#
#
#  |████████████████████████--------------------------| 48.5119%
#
# Trying parameter combination 163 of 336: {'num_leaves': 50, 'max_depth': 50, 'min_data_in_leaf': 10} ...
#
#
#  |████████████████████████--------------------------| 48.8095%
#
# Trying parameter combination 164 of 336: {'num_leaves': 200, 'max_depth': 50, 'min_data_in_leaf': 10} ...
#
#
#  |█████████████████████████-------------------------| 49.1071%
#
# Trying parameter combination 165 of 336: {'num_leaves': 500, 'max_depth': 50, 'min_data_in_leaf': 10} ...
#
#
#  |█████████████████████████-------------------------| 49.4048%
#
# Trying parameter combination 166 of 336: {'num_leaves': 1000, 'max_depth': 50, 'min_data_in_leaf': 10} ...
#
#
#  |█████████████████████████-------------------------| 49.7024%
#
# Trying parameter combination 167 of 336: {'num_leaves': 5000, 'max_depth': 50, 'min_data_in_leaf': 10} ...
#
#
#  |█████████████████████████-------------------------| 50.0000%
#
# Trying parameter combination 168 of 336: {'num_leaves': 1024, 'max_depth': 50, 'min_data_in_leaf': 10} ...
#
#
#  |█████████████████████████-------------------------| 50.2976%
#
# Trying parameter combination 169 of 336: {'num_leaves': 10, 'max_depth': 1, 'min_data_in_leaf': 20} ...
#
#
#  |█████████████████████████-------------------------| 50.5952%
#
# Trying parameter combination 170 of 336: {'num_leaves': 20, 'max_depth': 1, 'min_data_in_leaf': 20} ...
#
#
#  |█████████████████████████-------------------------| 50.8929%
#
# Trying parameter combination 171 of 336: {'num_leaves': 50, 'max_depth': 1, 'min_data_in_leaf': 20} ...
#
#
#  |██████████████████████████------------------------| 51.1905%
#
# Trying parameter combination 172 of 336: {'num_leaves': 200, 'max_depth': 1, 'min_data_in_leaf': 20} ...
#
#
#  |██████████████████████████------------------------| 51.4881%
#
# Trying parameter combination 173 of 336: {'num_leaves': 500, 'max_depth': 1, 'min_data_in_leaf': 20} ...
#
#
#  |██████████████████████████------------------------| 51.7857%
#
# Trying parameter combination 174 of 336: {'num_leaves': 1000, 'max_depth': 1, 'min_data_in_leaf': 20} ...
#
#
#  |██████████████████████████------------------------| 52.0833%
#
# Trying parameter combination 175 of 336: {'num_leaves': 5000, 'max_depth': 1, 'min_data_in_leaf': 20} ...
#
#
#  |██████████████████████████------------------------| 52.3810%
#
# Trying parameter combination 176 of 336: {'num_leaves': 1024, 'max_depth': 1, 'min_data_in_leaf': 20} ...
#
#
#  |██████████████████████████------------------------| 52.6786%
#
# Trying parameter combination 177 of 336: {'num_leaves': 10, 'max_depth': 2, 'min_data_in_leaf': 20} ...
#
#
#  |██████████████████████████------------------------| 52.9762%
#
# Trying parameter combination 178 of 336: {'num_leaves': 20, 'max_depth': 2, 'min_data_in_leaf': 20} ...
#
#
#  |███████████████████████████-----------------------| 53.2738%
#
# Trying parameter combination 179 of 336: {'num_leaves': 50, 'max_depth': 2, 'min_data_in_leaf': 20} ...
#
#
#  |███████████████████████████-----------------------| 53.5714%
#
# Trying parameter combination 180 of 336: {'num_leaves': 200, 'max_depth': 2, 'min_data_in_leaf': 20} ...
#
#
#  |███████████████████████████-----------------------| 53.8690%
#
# Trying parameter combination 181 of 336: {'num_leaves': 500, 'max_depth': 2, 'min_data_in_leaf': 20} ...
#
#
#  |███████████████████████████-----------------------| 54.1667%
#
# Trying parameter combination 182 of 336: {'num_leaves': 1000, 'max_depth': 2, 'min_data_in_leaf': 20} ...
#
#
#  |███████████████████████████-----------------------| 54.4643%
#
# Trying parameter combination 183 of 336: {'num_leaves': 5000, 'max_depth': 2, 'min_data_in_leaf': 20} ...
#
#
#  |███████████████████████████-----------------------| 54.7619%
#
# Trying parameter combination 184 of 336: {'num_leaves': 1024, 'max_depth': 2, 'min_data_in_leaf': 20} ...
#
#
#  |████████████████████████████----------------------| 55.0595%
#
# Trying parameter combination 185 of 336: {'num_leaves': 10, 'max_depth': 3, 'min_data_in_leaf': 20} ...
#
#
#  |████████████████████████████----------------------| 55.3571%
#
# Trying parameter combination 186 of 336: {'num_leaves': 20, 'max_depth': 3, 'min_data_in_leaf': 20} ...
#
#
#  |████████████████████████████----------------------| 55.6548%
#
# Trying parameter combination 187 of 336: {'num_leaves': 50, 'max_depth': 3, 'min_data_in_leaf': 20} ...
#
#
#  |████████████████████████████----------------------| 55.9524%
#
# Trying parameter combination 188 of 336: {'num_leaves': 200, 'max_depth': 3, 'min_data_in_leaf': 20} ...
#
#
#  |████████████████████████████----------------------| 56.2500%
#
# Trying parameter combination 189 of 336: {'num_leaves': 500, 'max_depth': 3, 'min_data_in_leaf': 20} ...
#
#
#  |████████████████████████████----------------------| 56.5476%
#
# Trying parameter combination 190 of 336: {'num_leaves': 1000, 'max_depth': 3, 'min_data_in_leaf': 20} ...
#
#
#  |████████████████████████████----------------------| 56.8452%
#
# Trying parameter combination 191 of 336: {'num_leaves': 5000, 'max_depth': 3, 'min_data_in_leaf': 20} ...
#
#
#  |█████████████████████████████---------------------| 57.1429%
#
# Trying parameter combination 192 of 336: {'num_leaves': 1024, 'max_depth': 3, 'min_data_in_leaf': 20} ...
#
#
#  |█████████████████████████████---------------------| 57.4405%
#
# Trying parameter combination 193 of 336: {'num_leaves': 10, 'max_depth': 4, 'min_data_in_leaf': 20} ...
#
#
#  |█████████████████████████████---------------------| 57.7381%
#
# Trying parameter combination 194 of 336: {'num_leaves': 20, 'max_depth': 4, 'min_data_in_leaf': 20} ...
#
#
#  |█████████████████████████████---------------------| 58.0357%
#
# Trying parameter combination 195 of 336: {'num_leaves': 50, 'max_depth': 4, 'min_data_in_leaf': 20} ...
#
#
#  |█████████████████████████████---------------------| 58.3333%
#
# Trying parameter combination 196 of 336: {'num_leaves': 200, 'max_depth': 4, 'min_data_in_leaf': 20} ...
#
#
#  |█████████████████████████████---------------------| 58.6310%
#
# Trying parameter combination 197 of 336: {'num_leaves': 500, 'max_depth': 4, 'min_data_in_leaf': 20} ...
#
#
#  |█████████████████████████████---------------------| 58.9286%
#
# Trying parameter combination 198 of 336: {'num_leaves': 1000, 'max_depth': 4, 'min_data_in_leaf': 20} ...
#
#
#  |██████████████████████████████--------------------| 59.2262%
#
# Trying parameter combination 199 of 336: {'num_leaves': 5000, 'max_depth': 4, 'min_data_in_leaf': 20} ...
#
#
#  |██████████████████████████████--------------------| 59.5238%
#
# Trying parameter combination 200 of 336: {'num_leaves': 1024, 'max_depth': 4, 'min_data_in_leaf': 20} ...
#
#
#  |██████████████████████████████--------------------| 59.8214%
#
# Trying parameter combination 201 of 336: {'num_leaves': 10, 'max_depth': 5, 'min_data_in_leaf': 20} ...
#
#
#  |██████████████████████████████--------------------| 60.1190%
#
# Trying parameter combination 202 of 336: {'num_leaves': 20, 'max_depth': 5, 'min_data_in_leaf': 20} ...
#
#
#  |██████████████████████████████--------------------| 60.4167%
#
# Trying parameter combination 203 of 336: {'num_leaves': 50, 'max_depth': 5, 'min_data_in_leaf': 20} ...
#
#
#  |██████████████████████████████--------------------| 60.7143%
#
# Trying parameter combination 204 of 336: {'num_leaves': 200, 'max_depth': 5, 'min_data_in_leaf': 20} ...
#
#
#  |███████████████████████████████-------------------| 61.0119%
#
# Trying parameter combination 205 of 336: {'num_leaves': 500, 'max_depth': 5, 'min_data_in_leaf': 20} ...
#
#
#  |███████████████████████████████-------------------| 61.3095%
#
# Trying parameter combination 206 of 336: {'num_leaves': 1000, 'max_depth': 5, 'min_data_in_leaf': 20} ...
#
#
#  |███████████████████████████████-------------------| 61.6071%
#
# Trying parameter combination 207 of 336: {'num_leaves': 5000, 'max_depth': 5, 'min_data_in_leaf': 20} ...
#
#
#  |███████████████████████████████-------------------| 61.9048%
#
# Trying parameter combination 208 of 336: {'num_leaves': 1024, 'max_depth': 5, 'min_data_in_leaf': 20} ...
#
#
#  |███████████████████████████████-------------------| 62.2024%
#
# Trying parameter combination 209 of 336: {'num_leaves': 10, 'max_depth': 10, 'min_data_in_leaf': 20} ...
#
#
#  |███████████████████████████████-------------------| 62.5000%
#
# Trying parameter combination 210 of 336: {'num_leaves': 20, 'max_depth': 10, 'min_data_in_leaf': 20} ...
#
#
#  |███████████████████████████████-------------------| 62.7976%
#
# Trying parameter combination 211 of 336: {'num_leaves': 50, 'max_depth': 10, 'min_data_in_leaf': 20} ...
#
#
#  |████████████████████████████████------------------| 63.0952%
#
# Trying parameter combination 212 of 336: {'num_leaves': 200, 'max_depth': 10, 'min_data_in_leaf': 20} ...
#
#
#  |████████████████████████████████------------------| 63.3929%
#
# Trying parameter combination 213 of 336: {'num_leaves': 500, 'max_depth': 10, 'min_data_in_leaf': 20} ...
#
#
#  |████████████████████████████████------------------| 63.6905%
#
# Trying parameter combination 214 of 336: {'num_leaves': 1000, 'max_depth': 10, 'min_data_in_leaf': 20} ...
#
#
#  |████████████████████████████████------------------| 63.9881%
#
# Trying parameter combination 215 of 336: {'num_leaves': 5000, 'max_depth': 10, 'min_data_in_leaf': 20} ...
#
#
#  |████████████████████████████████------------------| 64.2857%
#
# Trying parameter combination 216 of 336: {'num_leaves': 1024, 'max_depth': 10, 'min_data_in_leaf': 20} ...
#
#
#  |████████████████████████████████------------------| 64.5833%
#
# Trying parameter combination 217 of 336: {'num_leaves': 10, 'max_depth': 50, 'min_data_in_leaf': 20} ...
#
#
#  |████████████████████████████████------------------| 64.8810%
#
# Trying parameter combination 218 of 336: {'num_leaves': 20, 'max_depth': 50, 'min_data_in_leaf': 20} ...
#
#
#  |█████████████████████████████████-----------------| 65.1786%
#
# Trying parameter combination 219 of 336: {'num_leaves': 50, 'max_depth': 50, 'min_data_in_leaf': 20} ...
#
#
#  |█████████████████████████████████-----------------| 65.4762%
#
# Trying parameter combination 220 of 336: {'num_leaves': 200, 'max_depth': 50, 'min_data_in_leaf': 20} ...
#
#
#  |█████████████████████████████████-----------------| 65.7738%
#
# Trying parameter combination 221 of 336: {'num_leaves': 500, 'max_depth': 50, 'min_data_in_leaf': 20} ...
#
#
#  |█████████████████████████████████-----------------| 66.0714%
#
# Trying parameter combination 222 of 336: {'num_leaves': 1000, 'max_depth': 50, 'min_data_in_leaf': 20} ...
#
#
#  |█████████████████████████████████-----------------| 66.3690%
#
# Trying parameter combination 223 of 336: {'num_leaves': 5000, 'max_depth': 50, 'min_data_in_leaf': 20} ...
#
#
#  |█████████████████████████████████-----------------| 66.6667%
#
# Trying parameter combination 224 of 336: {'num_leaves': 1024, 'max_depth': 50, 'min_data_in_leaf': 20} ...
#
#
#  |█████████████████████████████████-----------------| 66.9643%
#
# Trying parameter combination 225 of 336: {'num_leaves': 10, 'max_depth': 1, 'min_data_in_leaf': 30} ...
#
#
#  |██████████████████████████████████----------------| 67.2619%
#
# Trying parameter combination 226 of 336: {'num_leaves': 20, 'max_depth': 1, 'min_data_in_leaf': 30} ...
#
#
#  |██████████████████████████████████----------------| 67.5595%
#
# Trying parameter combination 227 of 336: {'num_leaves': 50, 'max_depth': 1, 'min_data_in_leaf': 30} ...
#
#
#  |██████████████████████████████████----------------| 67.8571%
#
# Trying parameter combination 228 of 336: {'num_leaves': 200, 'max_depth': 1, 'min_data_in_leaf': 30} ...
#
#
#  |██████████████████████████████████----------------| 68.1548%
#
# Trying parameter combination 229 of 336: {'num_leaves': 500, 'max_depth': 1, 'min_data_in_leaf': 30} ...
#
#
#  |██████████████████████████████████----------------| 68.4524%
#
# Trying parameter combination 230 of 336: {'num_leaves': 1000, 'max_depth': 1, 'min_data_in_leaf': 30} ...
#
#
#  |██████████████████████████████████----------------| 68.7500%
#
# Trying parameter combination 231 of 336: {'num_leaves': 5000, 'max_depth': 1, 'min_data_in_leaf': 30} ...
#
#
#  |███████████████████████████████████---------------| 69.0476%
#
# Trying parameter combination 232 of 336: {'num_leaves': 1024, 'max_depth': 1, 'min_data_in_leaf': 30} ...
#
#
#  |███████████████████████████████████---------------| 69.3452%
#
# Trying parameter combination 233 of 336: {'num_leaves': 10, 'max_depth': 2, 'min_data_in_leaf': 30} ...
#
#
#  |███████████████████████████████████---------------| 69.6429%
#
# Trying parameter combination 234 of 336: {'num_leaves': 20, 'max_depth': 2, 'min_data_in_leaf': 30} ...
#
#
#  |███████████████████████████████████---------------| 69.9405%
#
# Trying parameter combination 235 of 336: {'num_leaves': 50, 'max_depth': 2, 'min_data_in_leaf': 30} ...
#
#
#  |███████████████████████████████████---------------| 70.2381%
#
# Trying parameter combination 236 of 336: {'num_leaves': 200, 'max_depth': 2, 'min_data_in_leaf': 30} ...
#
#
#  |███████████████████████████████████---------------| 70.5357%
#
# Trying parameter combination 237 of 336: {'num_leaves': 500, 'max_depth': 2, 'min_data_in_leaf': 30} ...
#
#
#  |███████████████████████████████████---------------| 70.8333%
#
# Trying parameter combination 238 of 336: {'num_leaves': 1000, 'max_depth': 2, 'min_data_in_leaf': 30} ...
#
#
#  |████████████████████████████████████--------------| 71.1310%
#
# Trying parameter combination 239 of 336: {'num_leaves': 5000, 'max_depth': 2, 'min_data_in_leaf': 30} ...
#
#
#  |████████████████████████████████████--------------| 71.4286%
#
# Trying parameter combination 240 of 336: {'num_leaves': 1024, 'max_depth': 2, 'min_data_in_leaf': 30} ...
#
#
#  |████████████████████████████████████--------------| 71.7262%
#
# Trying parameter combination 241 of 336: {'num_leaves': 10, 'max_depth': 3, 'min_data_in_leaf': 30} ...
#
#
#  |████████████████████████████████████--------------| 72.0238%
#
# Trying parameter combination 242 of 336: {'num_leaves': 20, 'max_depth': 3, 'min_data_in_leaf': 30} ...
#
#
#  |████████████████████████████████████--------------| 72.3214%
#
# Trying parameter combination 243 of 336: {'num_leaves': 50, 'max_depth': 3, 'min_data_in_leaf': 30} ...
#
#
#  |████████████████████████████████████--------------| 72.6190%
#
# Trying parameter combination 244 of 336: {'num_leaves': 200, 'max_depth': 3, 'min_data_in_leaf': 30} ...
#
#
#  |████████████████████████████████████--------------| 72.9167%
#
# Trying parameter combination 245 of 336: {'num_leaves': 500, 'max_depth': 3, 'min_data_in_leaf': 30} ...
#
#
#  |█████████████████████████████████████-------------| 73.2143%
#
# Trying parameter combination 246 of 336: {'num_leaves': 1000, 'max_depth': 3, 'min_data_in_leaf': 30} ...
#
#
#  |█████████████████████████████████████-------------| 73.5119%
#
# Trying parameter combination 247 of 336: {'num_leaves': 5000, 'max_depth': 3, 'min_data_in_leaf': 30} ...
#
#
#  |█████████████████████████████████████-------------| 73.8095%
#
# Trying parameter combination 248 of 336: {'num_leaves': 1024, 'max_depth': 3, 'min_data_in_leaf': 30} ...
#
#
#  |█████████████████████████████████████-------------| 74.1071%
#
# Trying parameter combination 249 of 336: {'num_leaves': 10, 'max_depth': 4, 'min_data_in_leaf': 30} ...
#
#
#  |█████████████████████████████████████-------------| 74.4048%
#
# Trying parameter combination 250 of 336: {'num_leaves': 20, 'max_depth': 4, 'min_data_in_leaf': 30} ...
#
#
#  |█████████████████████████████████████-------------| 74.7024%
#
# Trying parameter combination 251 of 336: {'num_leaves': 50, 'max_depth': 4, 'min_data_in_leaf': 30} ...
#
#
#  |██████████████████████████████████████------------| 75.0000%
#
# Trying parameter combination 252 of 336: {'num_leaves': 200, 'max_depth': 4, 'min_data_in_leaf': 30} ...
#
#
#  |██████████████████████████████████████------------| 75.2976%
#
# Trying parameter combination 253 of 336: {'num_leaves': 500, 'max_depth': 4, 'min_data_in_leaf': 30} ...
#
#
#  |██████████████████████████████████████------------| 75.5952%
#
# Trying parameter combination 254 of 336: {'num_leaves': 1000, 'max_depth': 4, 'min_data_in_leaf': 30} ...
#
#
#  |██████████████████████████████████████------------| 75.8929%
#
# Trying parameter combination 255 of 336: {'num_leaves': 5000, 'max_depth': 4, 'min_data_in_leaf': 30} ...
#
#
#  |██████████████████████████████████████------------| 76.1905%
#
# Trying parameter combination 256 of 336: {'num_leaves': 1024, 'max_depth': 4, 'min_data_in_leaf': 30} ...
#
#
#  |██████████████████████████████████████------------| 76.4881%
#
# Trying parameter combination 257 of 336: {'num_leaves': 10, 'max_depth': 5, 'min_data_in_leaf': 30} ...
#
#
#  |██████████████████████████████████████------------| 76.7857%
#
# Trying parameter combination 258 of 336: {'num_leaves': 20, 'max_depth': 5, 'min_data_in_leaf': 30} ...
#
#
#  |███████████████████████████████████████-----------| 77.0833%
#
# Trying parameter combination 259 of 336: {'num_leaves': 50, 'max_depth': 5, 'min_data_in_leaf': 30} ...
#
#
#  |███████████████████████████████████████-----------| 77.3810%
#
# Trying parameter combination 260 of 336: {'num_leaves': 200, 'max_depth': 5, 'min_data_in_leaf': 30} ...
#
#
#  |███████████████████████████████████████-----------| 77.6786%
#
# Trying parameter combination 261 of 336: {'num_leaves': 500, 'max_depth': 5, 'min_data_in_leaf': 30} ...
#
#
#  |███████████████████████████████████████-----------| 77.9762%
#
# Trying parameter combination 262 of 336: {'num_leaves': 1000, 'max_depth': 5, 'min_data_in_leaf': 30} ...
#
#
#  |███████████████████████████████████████-----------| 78.2738%
#
# Trying parameter combination 263 of 336: {'num_leaves': 5000, 'max_depth': 5, 'min_data_in_leaf': 30} ...
#
#
#  |███████████████████████████████████████-----------| 78.5714%
#
# Trying parameter combination 264 of 336: {'num_leaves': 1024, 'max_depth': 5, 'min_data_in_leaf': 30} ...
#
#
#  |███████████████████████████████████████-----------| 78.8690%
#
# Trying parameter combination 265 of 336: {'num_leaves': 10, 'max_depth': 10, 'min_data_in_leaf': 30} ...
#
#
#  |████████████████████████████████████████----------| 79.1667%
#
# Trying parameter combination 266 of 336: {'num_leaves': 20, 'max_depth': 10, 'min_data_in_leaf': 30} ...
#
#
#  |████████████████████████████████████████----------| 79.4643%
#
# Trying parameter combination 267 of 336: {'num_leaves': 50, 'max_depth': 10, 'min_data_in_leaf': 30} ...
#
#
#  |████████████████████████████████████████----------| 79.7619%
#
# Trying parameter combination 268 of 336: {'num_leaves': 200, 'max_depth': 10, 'min_data_in_leaf': 30} ...
#
#
#  |████████████████████████████████████████----------| 80.0595%
#
# Trying parameter combination 269 of 336: {'num_leaves': 500, 'max_depth': 10, 'min_data_in_leaf': 30} ...
#
#
#  |████████████████████████████████████████----------| 80.3571%
#
# Trying parameter combination 270 of 336: {'num_leaves': 1000, 'max_depth': 10, 'min_data_in_leaf': 30} ...
#
#
#  |████████████████████████████████████████----------| 80.6548%
#
# Trying parameter combination 271 of 336: {'num_leaves': 5000, 'max_depth': 10, 'min_data_in_leaf': 30} ...
#
#
#  |████████████████████████████████████████----------| 80.9524%
#
# Trying parameter combination 272 of 336: {'num_leaves': 1024, 'max_depth': 10, 'min_data_in_leaf': 30} ...
#
#
#  |█████████████████████████████████████████---------| 81.2500%
#
# Trying parameter combination 273 of 336: {'num_leaves': 10, 'max_depth': 50, 'min_data_in_leaf': 30} ...
#
#
#  |█████████████████████████████████████████---------| 81.5476%
#
# Trying parameter combination 274 of 336: {'num_leaves': 20, 'max_depth': 50, 'min_data_in_leaf': 30} ...
#
#
#  |█████████████████████████████████████████---------| 81.8452%
#
# Trying parameter combination 275 of 336: {'num_leaves': 50, 'max_depth': 50, 'min_data_in_leaf': 30} ...
#
#
#  |█████████████████████████████████████████---------| 82.1429%
#
# Trying parameter combination 276 of 336: {'num_leaves': 200, 'max_depth': 50, 'min_data_in_leaf': 30} ...
#
#
#  |█████████████████████████████████████████---------| 82.4405%
#
# Trying parameter combination 277 of 336: {'num_leaves': 500, 'max_depth': 50, 'min_data_in_leaf': 30} ...
#
#
#  |█████████████████████████████████████████---------| 82.7381%
#
# Trying parameter combination 278 of 336: {'num_leaves': 1000, 'max_depth': 50, 'min_data_in_leaf': 30} ...
#
#
#  |██████████████████████████████████████████--------| 83.0357%
#
# Trying parameter combination 279 of 336: {'num_leaves': 5000, 'max_depth': 50, 'min_data_in_leaf': 30} ...
#
#
#  |██████████████████████████████████████████--------| 83.3333%
#
# Trying parameter combination 280 of 336: {'num_leaves': 1024, 'max_depth': 50, 'min_data_in_leaf': 30} ...
#
#
#  |██████████████████████████████████████████--------| 83.6310%
#
# Trying parameter combination 281 of 336: {'num_leaves': 10, 'max_depth': 1, 'min_data_in_leaf': 50} ...
#
#
#  |██████████████████████████████████████████--------| 83.9286%
#
# Trying parameter combination 282 of 336: {'num_leaves': 20, 'max_depth': 1, 'min_data_in_leaf': 50} ...
#
#
#  |██████████████████████████████████████████--------| 84.2262%
#
# Trying parameter combination 283 of 336: {'num_leaves': 50, 'max_depth': 1, 'min_data_in_leaf': 50} ...
#
#
#  |██████████████████████████████████████████--------| 84.5238%
#
# Trying parameter combination 284 of 336: {'num_leaves': 200, 'max_depth': 1, 'min_data_in_leaf': 50} ...
#
#
#  |██████████████████████████████████████████--------| 84.8214%
#
# Trying parameter combination 285 of 336: {'num_leaves': 500, 'max_depth': 1, 'min_data_in_leaf': 50} ...
#
#
#  |███████████████████████████████████████████-------| 85.1190%
#
# Trying parameter combination 286 of 336: {'num_leaves': 1000, 'max_depth': 1, 'min_data_in_leaf': 50} ...
#
#
#  |███████████████████████████████████████████-------| 85.4167%
#
# Trying parameter combination 287 of 336: {'num_leaves': 5000, 'max_depth': 1, 'min_data_in_leaf': 50} ...
#
#
#  |███████████████████████████████████████████-------| 85.7143%
#
# Trying parameter combination 288 of 336: {'num_leaves': 1024, 'max_depth': 1, 'min_data_in_leaf': 50} ...
#
#
#  |███████████████████████████████████████████-------| 86.0119%
#
# Trying parameter combination 289 of 336: {'num_leaves': 10, 'max_depth': 2, 'min_data_in_leaf': 50} ...
#
#
#  |███████████████████████████████████████████-------| 86.3095%
#
# Trying parameter combination 290 of 336: {'num_leaves': 20, 'max_depth': 2, 'min_data_in_leaf': 50} ...
#
#
#  |███████████████████████████████████████████-------| 86.6071%
#
# Trying parameter combination 291 of 336: {'num_leaves': 50, 'max_depth': 2, 'min_data_in_leaf': 50} ...
#
#
#  |███████████████████████████████████████████-------| 86.9048%
#
# Trying parameter combination 292 of 336: {'num_leaves': 200, 'max_depth': 2, 'min_data_in_leaf': 50} ...
#
#
#  |████████████████████████████████████████████------| 87.2024%
#
# Trying parameter combination 293 of 336: {'num_leaves': 500, 'max_depth': 2, 'min_data_in_leaf': 50} ...
#
#
#  |████████████████████████████████████████████------| 87.5000%
#
# Trying parameter combination 294 of 336: {'num_leaves': 1000, 'max_depth': 2, 'min_data_in_leaf': 50} ...
#
#
#  |████████████████████████████████████████████------| 87.7976%
#
# Trying parameter combination 295 of 336: {'num_leaves': 5000, 'max_depth': 2, 'min_data_in_leaf': 50} ...
#
#
#  |████████████████████████████████████████████------| 88.0952%
#
# Trying parameter combination 296 of 336: {'num_leaves': 1024, 'max_depth': 2, 'min_data_in_leaf': 50} ...
#
#
#  |████████████████████████████████████████████------| 88.3929%
#
# Trying parameter combination 297 of 336: {'num_leaves': 10, 'max_depth': 3, 'min_data_in_leaf': 50} ...
#
#
#  |████████████████████████████████████████████------| 88.6905%
#
# Trying parameter combination 298 of 336: {'num_leaves': 20, 'max_depth': 3, 'min_data_in_leaf': 50} ...
#
#
#  |████████████████████████████████████████████------| 88.9881%
#
# Trying parameter combination 299 of 336: {'num_leaves': 50, 'max_depth': 3, 'min_data_in_leaf': 50} ...
#
#
#  |█████████████████████████████████████████████-----| 89.2857%
#
# Trying parameter combination 300 of 336: {'num_leaves': 200, 'max_depth': 3, 'min_data_in_leaf': 50} ...
#
#
#  |█████████████████████████████████████████████-----| 89.5833%
#
# Trying parameter combination 301 of 336: {'num_leaves': 500, 'max_depth': 3, 'min_data_in_leaf': 50} ...
#
#
#  |█████████████████████████████████████████████-----| 89.8810%
#
# Trying parameter combination 302 of 336: {'num_leaves': 1000, 'max_depth': 3, 'min_data_in_leaf': 50} ...
#
#
#  |█████████████████████████████████████████████-----| 90.1786%
#
# Trying parameter combination 303 of 336: {'num_leaves': 5000, 'max_depth': 3, 'min_data_in_leaf': 50} ...
#
#
#  |█████████████████████████████████████████████-----| 90.4762%
#
# Trying parameter combination 304 of 336: {'num_leaves': 1024, 'max_depth': 3, 'min_data_in_leaf': 50} ...
#
#
#  |█████████████████████████████████████████████-----| 90.7738%
#
# Trying parameter combination 305 of 336: {'num_leaves': 10, 'max_depth': 4, 'min_data_in_leaf': 50} ...
#
#
#  |██████████████████████████████████████████████----| 91.0714%
#
# Trying parameter combination 306 of 336: {'num_leaves': 20, 'max_depth': 4, 'min_data_in_leaf': 50} ...
#
#
#  |██████████████████████████████████████████████----| 91.3690%
#
# Trying parameter combination 307 of 336: {'num_leaves': 50, 'max_depth': 4, 'min_data_in_leaf': 50} ...
#
#
#  |██████████████████████████████████████████████----| 91.6667%
#
# Trying parameter combination 308 of 336: {'num_leaves': 200, 'max_depth': 4, 'min_data_in_leaf': 50} ...
#
#
#  |██████████████████████████████████████████████----| 91.9643%
#
# Trying parameter combination 309 of 336: {'num_leaves': 500, 'max_depth': 4, 'min_data_in_leaf': 50} ...
#
#
#  |██████████████████████████████████████████████----| 92.2619%
#
# Trying parameter combination 310 of 336: {'num_leaves': 1000, 'max_depth': 4, 'min_data_in_leaf': 50} ...
#
#
#  |██████████████████████████████████████████████----| 92.5595%
#
# Trying parameter combination 311 of 336: {'num_leaves': 5000, 'max_depth': 4, 'min_data_in_leaf': 50} ...
#
#
#  |██████████████████████████████████████████████----| 92.8571%
#
# Trying parameter combination 312 of 336: {'num_leaves': 1024, 'max_depth': 4, 'min_data_in_leaf': 50} ...
#
#
#  |███████████████████████████████████████████████---| 93.1548%
#
# Trying parameter combination 313 of 336: {'num_leaves': 10, 'max_depth': 5, 'min_data_in_leaf': 50} ...
#
#
#  |███████████████████████████████████████████████---| 93.4524%
#
# Trying parameter combination 314 of 336: {'num_leaves': 20, 'max_depth': 5, 'min_data_in_leaf': 50} ...
#
#
#  |███████████████████████████████████████████████---| 93.7500%
#
# Trying parameter combination 315 of 336: {'num_leaves': 50, 'max_depth': 5, 'min_data_in_leaf': 50} ...
#
#
#  |███████████████████████████████████████████████---| 94.0476%
#
# Trying parameter combination 316 of 336: {'num_leaves': 200, 'max_depth': 5, 'min_data_in_leaf': 50} ...
#
#
#  |███████████████████████████████████████████████---| 94.3452%
#
# Trying parameter combination 317 of 336: {'num_leaves': 500, 'max_depth': 5, 'min_data_in_leaf': 50} ...
#
#
#  |███████████████████████████████████████████████---| 94.6429%
#
# Trying parameter combination 318 of 336: {'num_leaves': 1000, 'max_depth': 5, 'min_data_in_leaf': 50} ...
#
#
#  |███████████████████████████████████████████████---| 94.9405%
#
# Trying parameter combination 319 of 336: {'num_leaves': 5000, 'max_depth': 5, 'min_data_in_leaf': 50} ...
#
#
#  |████████████████████████████████████████████████--| 95.2381%
#
# Trying parameter combination 320 of 336: {'num_leaves': 1024, 'max_depth': 5, 'min_data_in_leaf': 50} ...
#
#
#  |████████████████████████████████████████████████--| 95.5357%
#
# Trying parameter combination 321 of 336: {'num_leaves': 10, 'max_depth': 10, 'min_data_in_leaf': 50} ...
#
#
#  |████████████████████████████████████████████████--| 95.8333%
#
# Trying parameter combination 322 of 336: {'num_leaves': 20, 'max_depth': 10, 'min_data_in_leaf': 50} ...
#
#
#  |████████████████████████████████████████████████--| 96.1310%
#
# Trying parameter combination 323 of 336: {'num_leaves': 50, 'max_depth': 10, 'min_data_in_leaf': 50} ...
#
#
#  |████████████████████████████████████████████████--| 96.4286%
#
# Trying parameter combination 324 of 336: {'num_leaves': 200, 'max_depth': 10, 'min_data_in_leaf': 50} ...
#
#
#  |████████████████████████████████████████████████--| 96.7262%
#
# Trying parameter combination 325 of 336: {'num_leaves': 500, 'max_depth': 10, 'min_data_in_leaf': 50} ...
#
#
#  |█████████████████████████████████████████████████-| 97.0238%
#
# Trying parameter combination 326 of 336: {'num_leaves': 1000, 'max_depth': 10, 'min_data_in_leaf': 50} ...
#
#
#  |█████████████████████████████████████████████████-| 97.3214%
#
# Trying parameter combination 327 of 336: {'num_leaves': 5000, 'max_depth': 10, 'min_data_in_leaf': 50} ...
#
#
#  |█████████████████████████████████████████████████-| 97.6190%
#
# Trying parameter combination 328 of 336: {'num_leaves': 1024, 'max_depth': 10, 'min_data_in_leaf': 50} ...
#
#
#  |█████████████████████████████████████████████████-| 97.9167%
#
# Trying parameter combination 329 of 336: {'num_leaves': 10, 'max_depth': 50, 'min_data_in_leaf': 50} ...
#
#
#  |█████████████████████████████████████████████████-| 98.2143%
#
# Trying parameter combination 330 of 336: {'num_leaves': 20, 'max_depth': 50, 'min_data_in_leaf': 50} ...
#
#
#  |█████████████████████████████████████████████████-| 98.5119%
#
# Trying parameter combination 331 of 336: {'num_leaves': 50, 'max_depth': 50, 'min_data_in_leaf': 50} ...
#
#
#  |█████████████████████████████████████████████████-| 98.8095%
#
# Trying parameter combination 332 of 336: {'num_leaves': 200, 'max_depth': 50, 'min_data_in_leaf': 50} ...
#
#
#  |██████████████████████████████████████████████████| 99.1071%
#
# Trying parameter combination 333 of 336: {'num_leaves': 500, 'max_depth': 50, 'min_data_in_leaf': 50} ...
#
#
#  |██████████████████████████████████████████████████| 99.4048%
#
# Trying parameter combination 334 of 336: {'num_leaves': 1000, 'max_depth': 50, 'min_data_in_leaf': 50} ...
#
#
#  |██████████████████████████████████████████████████| 99.7024%
#
# Trying parameter combination 335 of 336: {'num_leaves': 5000, 'max_depth': 50, 'min_data_in_leaf': 50} ...
#
#
#  |██████████████████████████████████████████████████| 100.0000%
#
#
# Trying parameter combination 336 of 336: {'num_leaves': 1024, 'max_depth': 50, 'min_data_in_leaf': 50} ...
# Best number of iterations:  124.8
# Best score:  1.543445486988826
# Best parameters:  {'num_leaves': 5000, 'max_depth': 2, 'min_data_in_leaf': 1}

# %%
# Create results dataframe
results_1 = pd.DataFrame(columns=["RMSE Interpolation (mean)", "RMSE Interpolation (std)", "RMSE Extrapolation (mean)", "RMSE Extrapolation (std)", "RMSE_F (mean)", "RMSE_F (std)", "Time"],
                         index=['Linear Mixed Effects Model with no fixed features (random intercept)',
                                   'Linear Mixed Effects Model with Random Intercept',
                                   'Linear Mixed Effects Model with Shared Gaussian Process',
                                   'Linear Mixed Effects Model with Independent Gaussian Process',
                                   'Gradient-boosted tree with group as categorical variable (no random effects)',
                                   'GPBoost with Random Intercept',
                                   'GPBoost with Shared Gaussian Process',
                                   'GPBoost with Independent Gaussian Process'])

# %%
# 1. Linear Mixed Effects Model with no fixed features (random intercept)
time_list, RMSE_list1, RMSE_list2 = train_and_test(datasets, n_datasets, merf=False, linear=True, GP=False, no_features=True)

results_1.loc["Linear Mixed Effects Model with no fixed features (random intercept)", "Time"] = np.mean(time_list)
results_1.loc["Linear Mixed Effects Model with no fixed features (random intercept)", "RMSE Extrapolation (mean)"] = np.mean(RMSE_list1)
results_1.loc["Linear Mixed Effects Model with no fixed features (random intercept)", "RMSE Extrapolation (std)"] = np.std(RMSE_list1)
results_1.loc["Linear Mixed Effects Model with no fixed features (random intercept)", "RMSE Interpolation (mean)"] = np.mean(RMSE_list2)
results_1.loc["Linear Mixed Effects Model with no fixed features (random intercept)", "RMSE Interpolation (std)"] = np.std(RMSE_list2)
# Out:
#   0%|          | 0/20 [00:00<?, ?it/s]

# %%
# 2. Linear Mixed Effects Model with Random Intercept
time_list, RMSE_list1, RMSE_list2, F_list = train_and_test(datasets, n_datasets, merf=False, linear=True, GP=False)

results_1.loc["Linear Mixed Effects Model with Random Intercept", "Time"] = np.mean(time_list)
results_1.loc["Linear Mixed Effects Model with Random Intercept", "RMSE Extrapolation (mean)"] = np.mean(RMSE_list1)
results_1.loc["Linear Mixed Effects Model with Random Intercept", "RMSE Extrapolation (std)"] = np.std(RMSE_list1)
results_1.loc["Linear Mixed Effects Model with Random Intercept", "RMSE Interpolation (mean)"] = np.mean(RMSE_list2)
results_1.loc["Linear Mixed Effects Model with Random Intercept", "RMSE Interpolation (std)"] = np.std(RMSE_list2)
results_1.loc["Linear Mixed Effects Model with Random Intercept", "RMSE_F (mean)"] = np.mean(F_list)
results_1.loc["Linear Mixed Effects Model with Random Intercept", "RMSE_F (std)"] = np.std(F_list)
# Out:
#   0%|          | 0/20 [00:00<?, ?it/s]

# %%
# 3. Linear Mixed Effects Model with Shared Gaussian Process
mod_name = 'Linear Mixed Effects Model with Shared Gaussian Process'
time_list, RMSE_list1, RMSE_list2, F_list = train_and_test(datasets, n_datasets, merf=False, linear=True, GP=True, shared=True, kernel='exponential', matern_param=2.5)

results_1.loc[mod_name, "Time"] = np.mean(time_list)
results_1.loc[mod_name, "RMSE Extrapolation (mean)"] = np.mean(RMSE_list1)
results_1.loc[mod_name, "RMSE Extrapolation (std)"] = np.std(RMSE_list1)
results_1.loc[mod_name, "RMSE Interpolation (mean)"] = np.mean(RMSE_list2)
results_1.loc[mod_name, "RMSE Interpolation (std)"] = np.std(RMSE_list2)
results_1.loc[mod_name, "RMSE_F (mean)"] = np.mean(F_list)
results_1.loc[mod_name, "RMSE_F (std)"] = np.std(F_list)
# Out:
#   0%|          | 0/20 [00:00<?, ?it/s]

# %%
# 4. Linear Mixed Effects Model with Individual Gaussian Process
mod_name = 'Linear Mixed Effects Model with Independent Gaussian Process'
time_list, RMSE_list1, RMSE_list2, F_list = train_and_test(datasets, n_datasets, merf=False, linear=True, GP=True, shared=False, kernel='exponential', matern_param=2.5)

results_1.loc[mod_name, "Time"] = np.mean(time_list)
results_1.loc[mod_name, "RMSE Extrapolation (mean)"] = np.mean(RMSE_list1)
results_1.loc[mod_name, "RMSE Extrapolation (std)"] = np.std(RMSE_list1)
results_1.loc[mod_name, "RMSE Interpolation (mean)"] = np.mean(RMSE_list2)
results_1.loc[mod_name, "RMSE Interpolation (std)"] = np.std(RMSE_list2)
results_1.loc[mod_name, "RMSE_F (mean)"] = np.mean(F_list)
results_1.loc[mod_name, "RMSE_F (std)"] = np.std(F_list)
# Out:
#   0%|          | 0/20 [00:00<?, ?it/s]
# Error encountered
# Error encountered

# %%
# 5. Gradient tree-boosting including the grouping variable as a categorical variable ('Boosting_Cat')
datasets_cat, validation_datasets_cat = generate_datasets(n, m, p, n_datasets, n_valid, func='make_friedman3', 
                                                          shared_gp=True, random_state=60, include_cat_feature=True)

params = {'num_leaves': 5000, 'max_depth': 2, 'min_data_in_leaf': 1}
time_list, RMSE_list1, RMSE_list2, _ = train_and_test(datasets_cat, n_datasets, merf=False, GPBoost_cat=True, linear=False, 
                                                      GP=False, num_boost_round=125, params=params)

results_1.loc["Gradient-boosted tree with group as categorical variable (no random effects)", "Time"] = np.mean(time_list)
results_1.loc["Gradient-boosted tree with group as categorical variable (no random effects)", "RMSE Extrapolation (mean)"] = np.mean(RMSE_list1)
results_1.loc["Gradient-boosted tree with group as categorical variable (no random effects)", "RMSE Extrapolation (std)"] = np.std(RMSE_list1)
results_1.loc["Gradient-boosted tree with group as categorical variable (no random effects)", "RMSE Interpolation (mean)"] = np.mean(RMSE_list2)
results_1.loc["Gradient-boosted tree with group as categorical variable (no random effects)", "RMSE Interpolation (std)"] = np.std(RMSE_list2)
# Out:
#   0%|          | 0/20 [00:00<?, ?it/s]
# [GPBoost] [Info] Total Bins 1314
# [GPBoost] [Info] Number of data points in the train set: 1200, number of used features: 6
# [GPBoost] [Info] Start training from score 5.616082
# Error encountered
# [GPBoost] [Info] Total Bins 1313
# [GPBoost] [Info] Number of data points in the train set: 1200, number of used features: 6
# [GPBoost] [Info] Start training from score 5.358582
# Error encountered
# [GPBoost] [Info] Total Bins 1314
# [GPBoost] [Info] Number of data points in the train set: 1200, number of used features: 6
# [GPBoost] [Info] Start training from score 5.468753
# Error encountered
# [GPBoost] [Info] Total Bins 1312
# [GPBoost] [Info] Number of data points in the train set: 1200, number of used features: 6
# [GPBoost] [Info] Start training from score 5.664630
# Error encountered
# [GPBoost] [Info] Total Bins 1312
# [GPBoost] [Info] Number of data points in the train set: 1200, number of used features: 6
# [GPBoost] [Info] Start training from score 5.246468
# Error encountered
# [GPBoost] [Info] Total Bins 1309
# [GPBoost] [Info] Number of data points in the train set: 1200, number of used features: 6
# [GPBoost] [Info] Start training from score 5.716311
# Error encountered
# [GPBoost] [Info] Total Bins 1312
# [GPBoost] [Info] Number of data points in the train set: 1200, number of used features: 6
# [GPBoost] [Info] Start training from score 5.792570
# Error encountered
# [GPBoost] [Info] Total Bins 1314
# [GPBoost] [Info] Number of data points in the train set: 1200, number of used features: 6
# [GPBoost] [Info] Start training from score 6.085613
# Error encountered
# [GPBoost] [Info] Total Bins 1311
# [GPBoost] [Info] Number of data points in the train set: 1200, number of used features: 6
# [GPBoost] [Info] Start training from score 5.456408
# Error encountered
# [GPBoost] [Info] Total Bins 1310
# [GPBoost] [Info] Number of data points in the train set: 1200, number of used features: 6
# [GPBoost] [Info] Start training from score 5.250980
# Error encountered
# [GPBoost] [Info] Total Bins 1311
# [GPBoost] [Info] Number of data points in the train set: 1200, number of used features: 6
# [GPBoost] [Info] Start training from score 5.559264
# Error encountered
# [GPBoost] [Info] Total Bins 1314
# [GPBoost] [Info] Number of data points in the train set: 1200, number of used features: 6
# [GPBoost] [Info] Start training from score 5.470633
# Error encountered
# [GPBoost] [Info] Total Bins 1313
# [GPBoost] [Info] Number of data points in the train set: 1200, number of used features: 6
# [GPBoost] [Info] Start training from score 5.778657
# Error encountered
# [GPBoost] [Info] Total Bins 1312
# [GPBoost] [Info] Number of data points in the train set: 1200, number of used features: 6
# [GPBoost] [Info] Start training from score 6.130309
# Error encountered
# [GPBoost] [Info] Total Bins 1313
# [GPBoost] [Info] Number of data points in the train set: 1200, number of used features: 6
# [GPBoost] [Info] Start training from score 5.708826
# Error encountered
# [GPBoost] [Info] Total Bins 1313
# [GPBoost] [Info] Number of data points in the train set: 1200, number of used features: 6
# [GPBoost] [Info] Start training from score 5.528928
# Error encountered
# [GPBoost] [Info] Total Bins 1312
# [GPBoost] [Info] Number of data points in the train set: 1200, number of used features: 6
# [GPBoost] [Info] Start training from score 6.046359
# Error encountered
# [GPBoost] [Info] Total Bins 1314
# [GPBoost] [Info] Number of data points in the train set: 1200, number of used features: 6
# [GPBoost] [Info] Start training from score 5.317721
# Error encountered
# [GPBoost] [Info] Total Bins 1312
# [GPBoost] [Info] Number of data points in the train set: 1200, number of used features: 6
# [GPBoost] [Info] Start training from score 5.688037
# Error encountered
# [GPBoost] [Info] Total Bins 1314
# [GPBoost] [Info] Number of data points in the train set: 1200, number of used features: 6
# [GPBoost] [Info] Start training from score 5.537526
# Error encountered

# %%
# 6. GPBoost with Random Intercept
params = {'learning_rate': 0.1, 'max_depth': 4, 'min_data_in_leaf': 20, 
            'objective': 'regression_l2',
            'verbose': 0,
            'num_leaves': 2**10}
          
time_list, RMSE_list1, RMSE_list2, F_list = train_and_test(datasets, n_datasets, num_boost_round=50, params=params, merf=False, linear=False, GP=False)
results_1.loc["GPBoost with Random Intercept", "Time"] = np.mean(time_list)
results_1.loc["GPBoost with Random Intercept", "RMSE Extrapolation (mean)"] = np.mean(RMSE_list1)
results_1.loc["GPBoost with Random Intercept", "RMSE Extrapolation (std)"] = np.std(RMSE_list1)
results_1.loc["GPBoost with Random Intercept", "RMSE Interpolation (mean)"] = np.mean(RMSE_list2)
results_1.loc["GPBoost with Random Intercept", "RMSE Interpolation (std)"] = np.std(RMSE_list2)
results_1.loc["GPBoost with Random Intercept", "RMSE_F (mean)"] = np.mean(F_list)
results_1.loc["GPBoost with Random Intercept", "RMSE_F (std)"] = np.std(F_list)
# Out:
#   0%|          | 0/20 [00:00<?, ?it/s]

# %%
# 7. GPBoost with Shared Gaussian Process
params = {'learning_rate': 0.1,
          'max_depth': 4,
          'min_data_in_leaf': 20,
          'objective': 'regression_l2',
          'verbose': 0,
          'num_leaves': 2**10}

time_list, RMSE_list1, RMSE_list2, F_list = train_and_test(datasets, n_datasets, num_boost_round=52, params=params, merf=False, 
                                                            linear=False, GP=True, shared=True, kernel='exponential', matern_param=2.5)
results_1.loc["GPBoost with Shared Gaussian Process", "Time"] = np.mean(time_list)
results_1.loc["GPBoost with Shared Gaussian Process", "RMSE Extrapolation (mean)"] = np.mean(RMSE_list1)
results_1.loc["GPBoost with Shared Gaussian Process", "RMSE Extrapolation (std)"] = np.std(RMSE_list1)
results_1.loc["GPBoost with Shared Gaussian Process", "RMSE Interpolation (mean)"] = np.mean(RMSE_list2)
results_1.loc["GPBoost with Shared Gaussian Process", "RMSE Interpolation (std)"] = np.std(RMSE_list2)
results_1.loc["GPBoost with Shared Gaussian Process", "RMSE_F (mean)"] = np.mean(F_list)
results_1.loc["GPBoost with Shared Gaussian Process", "RMSE_F (std)"] = np.std(F_list)
# Out:
#   0%|          | 0/20 [00:00<?, ?it/s]

# %%
# 8. GPBoost with Independent Gaussian Process
params = {'learning_rate': 0.1,
          'max_depth': 4,
          'min_data_in_leaf': 20,
          'objective': 'regression_l2',
          'verbose': 0,
          'num_leaves': 2**10}

time_list, RMSE_list1, RMSE_list2, F_list = train_and_test(datasets, n_datasets, num_boost_round=56, params=params,
                                         merf=False, linear=False, GP=True, shared=False, kernel='exponential', matern_param=2.5)
results_1.loc["GPBoost with Independent Gaussian Process", "Time"] = np.mean(time_list)
results_1.loc["GPBoost with Independent Gaussian Process", "RMSE Extrapolation (mean)"] = np.mean(RMSE_list1)
results_1.loc["GPBoost with Independent Gaussian Process", "RMSE Extrapolation (std)"] = np.std(RMSE_list1)
results_1.loc["GPBoost with Independent Gaussian Process", "RMSE Interpolation (mean)"] = np.mean(RMSE_list2)
results_1.loc["GPBoost with Independent Gaussian Process", "RMSE Interpolation (std)"] = np.std(RMSE_list2)
results_1.loc["GPBoost with Independent Gaussian Process", "RMSE_F (mean)"] = np.mean(F_list)
results_1.loc["GPBoost with Independent Gaussian Process", "RMSE_F (std)"] = np.std(F_list)
# Out:
#   0%|          | 0/20 [00:00<?, ?it/s]
# Error encountered
# Error encountered

# %%
results_1

# %%
results_1.to_csv('full_data_sharedGP_non_linear.csv')
